# %%
# Use this to play around with game feature generator features 
import pandas as pd
pd.set_option('mode.chained_assignment', None)
import numpy as np
import os
from tqdm import tqdm
from copy import deepcopy
from data_processing.utils.download_functions import *

# %%
os.chdir('esports-data')
os.listdir()
# Out:
# ['games',
#  'leagues.json',
#  'mapping_data.json',
#  'players.json',
#  'teams.json',
#  'tournaments.json']

# %%
with open("mapping_data.json", "r") as json_file:
   mappings_data = json.load(json_file)

mappings = {
   esports_game["esportsGameId"]: esports_game for esports_game in mappings_data
}

game_id = '110303581088331459'
game_mapping_data = mappings[game_id]
platform_game_id = game_mapping_data['platformGameId']
with open(f"games/{platform_game_id}.json", "r") as json_file:
    game_data = json.load(json_file)

# %%
from datetime import datetime
import pandas as pd
import numpy as np


class GameFeaturesGenerator:
    TIME_FORMAT = '%Y-%m-%dT%H:%M:%S.%fZ'

    @staticmethod
    def get_event_time(start_time, event_time):
        return (datetime.strptime(event_time, GameFeaturesGenerator.TIME_FORMAT) - start_time).total_seconds()

    @staticmethod
    def flip_team_id(team_id):
        """
        Flips team_id from 100 to 200 and vice versa. Needed for when processing turret fall events because we want to update the feature for the team that lost the turret
        """
        if team_id == 100:
            return 200
        elif team_id == 200:
            return 100
        else:
            print("Error: team_id is not 100 or 200")

    def __init__(self, game_data, mapping_data):
        self.game_data = game_data
        self.game_start_time = datetime.strptime(game_data[0]['eventTime'], GameFeaturesGenerator.TIME_FORMAT)
        self.team_id_mapping = {"100": mapping_data['teamMapping']['100'], "200": mapping_data['teamMapping']['200']}
        self.esports_game_id = mapping_data['esportsGameId']  # Looks like '110310652412257228'
        self.platform_game_id = mapping_data['platformGameId']  # Looks lik {'esportsGameId': '110310652412257228'
        # Create flags for first events (e.g. first turret kill, first dragon kill, etc.). These can only happen once (for both teams)
        self.first_herald_flag = True
        self.first_dragon_flag = True
        self.first_baron_flag = True
        self.first_turret_flag = True
        self.first_inhibitor_flag = True
        self.first_kill_flag = True

        # Create features for each team
        # EPIC MONSTER EVENT FEATURES
        self.IMPORTANT_MONSTER_TYPES = ["riftHerald", "dragon", "baron"]
        epic_monster_kill_event_features = [
            ["first_" + monster_type + "_ind", "first_" + monster_type + "_time", "num_" + monster_type] for
            monster_type
            in self.IMPORTANT_MONSTER_TYPES]
        epic_monster_kill_event_features = [item for sublist in epic_monster_kill_event_features for item in
                                            sublist]  # Flatten list of lists

        # BUILDING DESTROYED EVENT FEATURES
        self.IMPORTANT_BUILDING_TYPES = ["turret", "inhibitor"]
        building_destroyed_event_features = [
            ["first_" + building_type + "_ind", "first_" + building_type + "_time", "num_" + building_type] for
            building_type
            in self.IMPORTANT_BUILDING_TYPES]
        building_destroyed_event_features = [item for sublist in building_destroyed_event_features for item in
                                             sublist]  # Flatten list of lists

        # CHAMPION KILL EVENT FEATURES
        champion_kill_event_features = ["first_kill_ind", "first_kill_time", "num_kills"]

        # GAME METADATA FEATURES
        # TODO: Also need a feature for whether this was a domestic or international game (e.g. LCS vs. Worlds)
        game_metadata_features = ["game_end_time"]

        all_features = (["platformGameId", "esportsGameId", "team_id", "start_time", "outcome"] +
                        epic_monster_kill_event_features + building_destroyed_event_features + champion_kill_event_features + game_metadata_features)
        self.team_features = {"100": {feature: np.nan for feature in all_features},
                              "200": {feature: np.nan for feature in all_features}}
        # Set all "num_" features to 0
        for team_id in ["100", "200"]:
            for feature in all_features:
                if feature.startswith("num_"):
                    self.team_features[team_id][feature] = 0

    def process_epic_monster_kill_event(self, event, team_features):
        monster_type = event['monsterType']
        if monster_type in self.IMPORTANT_MONSTER_TYPES:
            event_time = event['eventTime']
            time_of_kill = GameFeaturesGenerator.get_event_time(self.game_start_time, event_time)
            killer_team_id = str(event['killerTeamID'])
            victim_team_id = str(GameFeaturesGenerator.flip_team_id(event['killerTeamID']))
            if self.first_herald_flag:
                team_features[killer_team_id]['first_riftHerald_ind'] = 1
                team_features[victim_team_id]['first_riftHerald_ind'] = 0
                team_features[killer_team_id]['first_riftHerald_time'] = time_of_kill
                self.first_herald_flag = False
            if self.first_dragon_flag:
                team_features[killer_team_id]['first_dragon_ind'] = 1
                team_features[victim_team_id]['first_dragon_ind'] = 0
                team_features[killer_team_id]['first_dragon_time'] = time_of_kill
                self.first_dragon_flag = False
            if self.first_baron_flag:
                team_features[killer_team_id]['first_baron_ind'] = 1
                team_features[victim_team_id]['first_baron_ind'] = 0
                team_features[killer_team_id]['first_baron_time'] = time_of_kill
                self.first_baron_flag = False
            team_features[killer_team_id]['num_' + monster_type] += 1

    def process_building_destroyed_event(self, event, team_features):
        building_type = event['buildingType']
        if building_type in self.IMPORTANT_BUILDING_TYPES:
            event_time = event['eventTime']
            time_of_event = GameFeaturesGenerator.get_event_time(self.game_start_time, event_time)
            team_id = str(GameFeaturesGenerator.flip_team_id(event['teamID']))
            victim_team_id = str(event['teamID'])
            if self.first_turret_flag:
                team_features[team_id]['first_turret_ind'] = 1
                team_features[victim_team_id]['first_turret_ind'] = 0
                team_features[team_id]['first_turret_time'] = time_of_event
                self.first_turret_flag = False
            if self.first_inhibitor_flag:
                team_features[team_id]['first_inhibitor_ind'] = 1
                team_features[victim_team_id]['first_inhibitor_ind'] = 0
                team_features[team_id]['first_inhibitor_time'] = time_of_event
                self.first_inhibitor_flag = False
            team_features[team_id]['num_' + building_type] += 1

    def process_champion_kill_event(self, event, team_features):
        event_time = event['eventTime']
        time_of_event = GameFeaturesGenerator.get_event_time(self.game_start_time, event_time)
        killer_team_id = str(event['killerTeamID'])
        victim_team_id = str(GameFeaturesGenerator.flip_team_id(event['killerTeamID']))
        if self.first_kill_flag:
            team_features[killer_team_id]['first_kill_ind'] = 1
            team_features[victim_team_id]['first_kill_ind'] = 0
            team_features[killer_team_id]['first_kill_time'] = time_of_event
            self.first_kill_flag = False
        team_features[killer_team_id]['num_kills'] += 1

    def process_game_end_event(self, event, team_features):
        # We only call this method for the final event, so if for some reason there is no game_end event then discard the data
        if event['eventType'] == "game_end":
            event_time = event['eventTime']
            time_of_event = GameFeaturesGenerator.get_event_time(self.game_start_time, event_time)
            team_features['100']['game_end_time'] = time_of_event
            team_features['200']['game_end_time'] = time_of_event
            winning_team = event['winningTeam']
            losing_team = GameFeaturesGenerator.flip_team_id(winning_team)
            team_features[str(winning_team)]['outcome'] = 1
            team_features[str(losing_team)]['outcome'] = 0
        else:
            raise Exception("Error: event is not a game_end event")

    def process_game(self):
        """
        Loops through all events in the game and updates the team features as they occur
        :return: a pandas dataframe with the features for each team and label "outcome"
        """
        for event in self.game_data:
            if event['eventType'] == "epic_monster_kill":
                self.process_epic_monster_kill_event(event, self.team_features)
            elif event['eventType'] == "building_destroyed":
                self.process_building_destroyed_event(event, self.team_features)
            elif event['eventType'] == "champion_kill":
                self.process_champion_kill_event(event, self.team_features)
            elif event['eventType'] == "game_end":
                self.process_game_end_event(event, self.team_features)
            else:
                continue

        # Now we have all the datapoints, we can create a dataframe with the team ID, label, start_time, and features
        # First assign the rest of the metadata
        rows = []
        for team_id in ["100", "200"]:
            # Assign metadata (same for both teams)
            self.team_features[team_id]['platformGameId'] = self.platform_game_id
            self.team_features[team_id]['esportsGameId'] = self.esports_game_id
            self.team_features[team_id]['start_time'] = self.game_start_time

            # Assing team-specific data
            self.team_features[team_id]['team_id'] = self.team_id_mapping[team_id]
            rows.append(pd.DataFrame.from_dict(self.team_features[team_id], orient='index').transpose())
        return pd.concat(rows, ignore_index=True)

# %%
# Notes: 
# Participants 1-5 are on team 100 and 6-10 are on team 200
# participant_mapping = {
#     '1': '100_top',
#     '2': '100_jungle',
#     '3': '100_mid',
#     '4': '100_bot',
#     '5': '100_support',
#     '6': '200_top',
#     '7': '200_jungle',
#     '8': '200_mid',
#     '9': '200_bot',
#     '10': '200_support'
# }

# %%
participant_data
# Out:
# {'ability4CooldownRemaining': 0,
#  'magicPenetrationPercent': 0,
#  'alive': True,
#  'primaryAbilityResource': 955,
#  'spellVamp': 0,
#  'participantID': 10,
#  'lifeSteal': 0,
#  'primaryAbilityResourceRegen': 91,
#  'ability1CooldownRemaining': 1.8475341796875,
#  'XPForNextLevel': 7300,
#  'summonerSpell2CooldownRemaining': 0,
#  'healthMax': 1254,
#  'magicResist': 36,
#  'ability3CooldownRemaining': 0,
#  'ability3Level': 4,
#  'ability2CooldownRemaining': 0,
#  'summonerSpell1Name': 'SummonerHeal',
#  'teamID': 200,
#  'currentGold': 616,
#  'healthRegen': 18,
#  'ability4Level': 1,
#  'level': 10,
#  'ability1Level': 5,
#  'armorPenetration': 0,
#  'accountID': 2382277312029984,
#  'ability2Level': 1,
#  'health': 1254,
#  'ultimateName': 'YuumiR',
#  'summonerSpell2Name': 'SummonerExhaust',
#  'cooldownReduction': 0,
#  'goldStats': {'assist': 142,
#   'killPalisade': 262,
#   'killMinion': 21,
#   'killStructure': 416,
#   'misc': 170,
#   'itemSold': 20,
#   'killChampion': 600,
#   'supportItem': 680,
#   'ambient': 2438,
#   'starting': 500},
#  'magicPenetrationPercentBonus': 0,
#  'magicPenetration': 0,
#  'position': {'z': 3943, 'x': 6949},
#  'primaryAbilityResourceMax': 1038,
#  'armorPenetrationPercentBonus': 0,
#  'armorPenetrationPercent': 0,
#  'ability2Name': 'YuumiWEndWrapper',
#  'attackDamage': 76,
#  'ability3Name': 'YuumiE',
#  'championName': 'Yuumi',
#  'ccReduction': 0,
#  'shutdownValue': 150,
#  'playerName': 'C9 Zven',
#  'respawnTimer': 0,
#  'attackSpeed': 107,
#  'XP': 6884,
#  'ultimateCooldownRemaining': 0,
#  'stackingBuffs': [{'stacks': 2, 'id': 3810510983},
#   {'stacks': 954, 'id': 4124813883}],
#  'armor': 68,
#  'summonerSpell1CooldownRemaining': 0,
#  'ability1Name': 'YuumiQ',
#  'totalGold': 5281,
#  'items': [{'itemID': 1028, 'itemCooldown': 0},
#   {'itemID': 4005, 'itemCooldown': 0},
#   {'itemID': 1004, 'itemCooldown': 0},
#   {'itemID': 3851, 'itemStacks': 1, 'itemCooldown': 0},
#   {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#   {'itemID': 4642, 'itemCooldown': 0},
#   {'itemID': 3364, 'itemStacks': 1, 'itemCooldown': 0}],
#  'abilityPower': 121,
#  'ability4Name': 'YuumiR',
#  'stats': [{'value': 3, 'name': 'MINIONS_KILLED'},
#   {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#   {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#   {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#   {'value': 2, 'name': 'CHAMPIONS_KILLED'},
#   {'value': 0, 'name': 'NUM_DEATHS'},
#   {'value': 2, 'name': 'ASSISTS'},
#   {'value': 0, 'name': 'PERK0'},
#   {'value': 0, 'name': 'PERK0_VAR1'},
#   {'value': 0, 'name': 'PERK0_VAR2'},
#   {'value': 0, 'name': 'PERK0_VAR3'},
#   {'value': 0, 'name': 'PERK1'},
#   {'value': 0, 'name': 'PERK1_VAR1'},
#   {'value': 0, 'name': 'PERK1_VAR2'},
#   {'value': 0, 'name': 'PERK1_VAR3'},
#   {'value': 0, 'name': 'PERK2'},
#   {'value': 0, 'name': 'PERK2_VAR1'},
#   {'value': 0, 'name': 'PERK2_VAR2'},
#   {'value': 0, 'name': 'PERK2_VAR3'},
#   {'value': 0, 'name': 'PERK3'},
#   {'value': 0, 'name': 'PERK3_VAR1'},
#   {'value': 0, 'name': 'PERK3_VAR2'},
#   {'value': 0, 'name': 'PERK3_VAR3'},
#   {'value': 0, 'name': 'PERK4'},
#   {'value': 0, 'name': 'PERK4_VAR1'},
#   {'value': 0, 'name': 'PERK4_VAR2'},
#   {'value': 0, 'name': 'PERK4_VAR3'},
#   {'value': 0, 'name': 'PERK5'},
#   {'value': 0, 'name': 'PERK5_VAR1'},
#   {'value': 0, 'name': 'PERK5_VAR2'},
#   {'value': 0, 'name': 'PERK5_VAR3'},
#   {'value': 20, 'name': 'WARD_PLACED'},
#   {'value': 2, 'name': 'WARD_KILLED'},
#   {'value': 34.48716735839844, 'name': 'VISION_SCORE'},
#   {'value': 5768.42822265625, 'name': 'TOTAL_DAMAGE_DEALT'},
#   {'value': 572.8134155273438, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#   {'value': 5195.615234375, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#   {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#   {'value': 2817.63134765625, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#   {'value': 223.041015625, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#   {'value': 2594.59033203125, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#   {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#   {'value': 777.9525146484375, 'name': 'TOTAL_DAMAGE_TAKEN'},
#   {'value': 678.851806640625, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#   {'value': 99.10064697265625, 'name': 'MAGIC_DAMAGE_TAKEN'},
#   {'value': 0, 'name': 'TRUE_DAMAGE_TAKEN'},
#   {'value': 381.05999755859375, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#   {'value': 749.0155029296875, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#   {'value': 923.3621826171875, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#   {'value': 923.3621826171875, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#   {'value': 1051.0408935546875, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#   {'value': 78.76849365234375, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#   {'value': 73.90643310546875,
#    'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#   {'value': 494.76007080078125, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#   {'value': 7.7596893310546875, 'name': 'TIME_CCING_OTHERS'},
#   {'value': 0, 'name': 'BASIC_PINGS'},
#   {'value': 7, 'name': 'COMMAND_PINGS'},
#   {'value': 0, 'name': 'DANGER_PINGS'},
#   {'value': 1, 'name': 'GET_BACK_PINGS'},
#   {'value': 5, 'name': 'RETREAT_PINGS'},
#   {'value': 20, 'name': 'ON_MY_WAY_PINGS'},
#   {'value': 0, 'name': 'ASSIST_ME_PINGS'},
#   {'value': 3, 'name': 'ENEMY_MISSING_PINGS'},
#   {'value': 0, 'name': 'PUSH_PINGS'},
#   {'value': 0, 'name': 'ALL_IN_PINGS'},
#   {'value': 0, 'name': 'HOLD_PINGS'},
#   {'value': 0, 'name': 'BAIT_PINGS'},
#   {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#   {'value': 15, 'name': 'ENEMY_VISION_PINGS'},
#   {'value': 1, 'name': 'NEED_VISION_PINGS'}],
#  'goldPerSecond': 30}

# %%
event['teams'][0]
# Out:
# {'inhibKills': 0,
#  'towerKills': 0,
#  'teamID': 100,
#  'baronKills': 0,
#  'dragonKills': 0,
#  'assists': 3,
#  'championsKills': 1,
#  'totalGold': 31061,
#  'deaths': 5}

# %%
game_data[-3]
# Out:
# {'eventTime': '2023-06-22T23:09:39.168Z',
#  'eventType': 'stats_update',
#  'platformGameId': 'ESPORTSTMNT02:3207804',
#  'gameTime': 1606009,
#  'stageID': 1,
#  'participants': [{'ability4CooldownRemaining': 35.4078369140625,
#    'magicPenetrationPercent': 0,
#    'alive': False,
#    'primaryAbilityResource': 13,
#    'spellVamp': 0,
#    'participantID': 1,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 30,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 13020,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 3891,
#    'magicResist': 91,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 2,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'S12_SummonerTeleportUpgrade',
#    'teamID': 100,
#    'currentGold': 880,
#    'healthRegen': 34,
#    'ability4Level': 2,
#    'level': 14,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382277692401216,
#    'ability2Level': 5,
#    'health': 0,
#    'ultimateName': 'SionR',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 62,
#     'killPalisade': 350,
#     'ambient': 3051,
#     'itemSold': 455,
#     'killStructure': 100,
#     'killMinion': 4301,
#     'starting': 500,
#     'misc': 205},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 1754, 'x': 3716},
#    'primaryAbilityResourceMax': 1148,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'SionW',
#    'attackDamage': 116,
#    'ability3Name': 'SionE',
#    'championName': 'Sion',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': '100 Ssumday',
#    'respawnTimer': 11.736064910888672,
#    'attackSpeed': 125,
#    'XP': 12931,
#    'ultimateCooldownRemaining': 35.4078369140625,
#    'summonerSpell1CooldownRemaining': 0,
#    'armor': 199,
#    'stackingBuffs': [{'stacks': 974, 'id': 1911847746}],
#    'ability1Name': 'SionQ',
#    'totalGold': 8570,
#    'items': [{'itemID': 3047, 'itemCooldown': 0},
#     {'itemID': 6665, 'itemCooldown': 0},
#     {'itemID': 3068, 'itemStacks': 52, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 1, 'itemCooldown': 0}],
#    'abilityPower': 0,
#    'ability4Name': 'SionR',
#    'stats': [{'value': 210, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 3, 'name': 'NUM_DEATHS'},
#     {'value': 1, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 9, 'name': 'WARD_PLACED'},
#     {'value': 3, 'name': 'WARD_KILLED'},
#     {'value': 20.082462310791016, 'name': 'VISION_SCORE'},
#     {'value': 122274.53125, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 72700.71875, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 40343.890625, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 9230, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 7380.48583984375, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 4003.40771484375, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 3374.07958984375, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 3, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 23879.439453125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 13629.994140625, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 8797.216796875, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 1452.2276611328125, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 36924.55859375, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 2372.916259765625, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 2372.916259765625, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 7574.6328125, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 465.553466796875, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 65.73127746582031,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 21.273555755615234, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 30, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 5, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 3, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 0, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 2, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 0, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 44.9959716796875,
#    'magicPenetrationPercent': 0,
#    'alive': False,
#    'primaryAbilityResource': 884,
#    'spellVamp': 0,
#    'participantID': 2,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 28,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 9960,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 1980,
#    'magicResist': 108,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 1,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerFlash',
#    'teamID': 100,
#    'currentGold': 1410,
#    'healthRegen': 33,
#    'ability4Level': 2,
#    'level': 12,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382276651083040,
#    'ability2Level': 4,
#    'health': 0,
#    'ultimateName': 'MonkeyKingSpinToWin',
#    'summonerSpell2Name': 'SummonerSmiteAvatarUtility',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 205,
#     'killPalisade': 87,
#     'killNeutralMinion': 3393,
#     'starting': 500,
#     'ambient': 3051,
#     'killChampion': 300,
#     'killMinion': 133,
#     'killStructure': 100,
#     'misc': 360},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 577, 'x': 1312},
#    'primaryAbilityResourceMax': 939,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'monkeykingdecoy',
#    'attackDamage': 180,
#    'ability3Name': 'MonkeyKingNimbus',
#    'championName': 'MonkeyKing',
#    'ccReduction': 30,
#    'shutdownValue': 0,
#    'playerName': '100 Closer',
#    'respawnTimer': 1.1229133605957031,
#    'attackSpeed': 157,
#    'XP': 9656,
#    'ultimateCooldownRemaining': 44.9959716796875,
#    'summonerSpell1CooldownRemaining': 72.2940673828125,
#    'armor': 84,
#    'stackingBuffs': [{'stacks': 1200, 'id': 3805539831},
#     {'stacks': 3, 'id': 1476838120}],
#    'ability1Name': 'MonkeyKingDoubleAttack',
#    'totalGold': 8130,
#    'items': [{'itemID': 3111, 'itemCooldown': 0},
#     {'itemID': 6632, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 3155, 'itemCooldown': 0},
#     {'itemID': 1036, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 2, 'itemCooldown': 0}],
#    'abilityPower': 0,
#    'ability4Name': 'MonkeyKingSpinToWin',
#    'stats': [{'value': 13, 'name': 'MINIONS_KILLED'},
#     {'value': 128.00003051757812, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 104.5000228881836, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 2.5, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 1, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 2, 'name': 'NUM_DEATHS'},
#     {'value': 2, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 7, 'name': 'WARD_PLACED'},
#     {'value': 6, 'name': 'WARD_KILLED'},
#     {'value': 22.875398635864258, 'name': 'VISION_SCORE'},
#     {'value': 135854.234375, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 85882.0390625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 12808.32421875, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 37163.94140625, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 3513.58642578125, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 3052.799072265625, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 264.3168029785156, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 196.47059631347656, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 21368.19140625, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 12601.75, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 8188.66552734375, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 577.7566528320312, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 15028.1796875, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 11916.537109375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 123.77923583984375, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 6.91192626953125,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 3.965672731399536, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 36, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 7, 'name': 'GET_BACK_PINGS'},
#     {'value': 1, 'name': 'RETREAT_PINGS'},
#     {'value': 56, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 15, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 23, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 4, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 1, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 0, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 22.4564208984375,
#    'magicPenetrationPercent': 39,
#    'alive': False,
#    'primaryAbilityResource': 1004,
#    'spellVamp': 0,
#    'participantID': 3,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 30,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 13020,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 2187,
#    'magicResist': 45,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 5,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'S12_SummonerTeleportUpgrade',
#    'teamID': 100,
#    'currentGold': 367,
#    'healthRegen': 33,
#    'ability4Level': 2,
#    'level': 14,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2878373465278176,
#    'ability2Level': 2,
#    'health': 0,
#    'ultimateName': 'NeekoR',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 52,
#     'shutdownReward': 300,
#     'killPalisade': 262,
#     'ambient': 3051,
#     'itemSold': 775,
#     'killStructure': 100,
#     'killChampion': 600,
#     'killMinion': 4446,
#     'starting': 500,
#     'misc': 250},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 11,
#    'position': {'z': 801, 'x': 3101},
#    'primaryAbilityResourceMax': 1182,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'NeekoW',
#    'attackDamage': 78,
#    'ability3Name': 'NeekoE',
#    'championName': 'Neeko',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': '100 Quid',
#    'respawnTimer': 2.7061767578125,
#    'attackSpeed': 152,
#    'XP': 12152,
#    'ultimateCooldownRemaining': 22.4564208984375,
#    'summonerSpell1CooldownRemaining': 0,
#    'armor': 89,
#    'ability1Name': 'NeekoQ',
#    'totalGold': 9562,
#    'items': [{'itemID': 1056, 'itemCooldown': 0},
#     {'itemID': 3916, 'itemCooldown': 0},
#     {'itemID': 3152, 'itemCooldown': 0},
#     {'itemID': 3135, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 3158, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 0}],
#    'abilityPower': 209,
#    'ability4Name': 'NeekoR',
#    'stats': [{'value': 215, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 2, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 4, 'name': 'NUM_DEATHS'},
#     {'value': 1, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 14, 'name': 'WARD_PLACED'},
#     {'value': 4, 'name': 'WARD_KILLED'},
#     {'value': 27.381338119506836, 'name': 'VISION_SCORE'},
#     {'value': 119908.2421875, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 13847.1181640625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 102196.09375, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 3865, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 9135.1025390625, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 304.6264343261719, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 8830.474609375, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 14098.95703125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 5165.56689453125, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 8288.1982421875, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 645.1845703125, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 6052.31494140625, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 282.1368713378906, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 282.1368713378906, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 282.1368713378906, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 186.9076690673828, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 23.07025146484375,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 19.75640869140625, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 16, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 0, 'name': 'GET_BACK_PINGS'},
#     {'value': 2, 'name': 'RETREAT_PINGS'},
#     {'value': 19, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 1, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 4, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 1, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 50.575439453125,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 943,
#    'spellVamp': 0,
#    'participantID': 4,
#    'lifeSteal': 4,
#    'primaryAbilityResourceRegen': 35,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 13020,
#    'summonerSpell2CooldownRemaining': 157.1292724609375,
#    'healthMax': 1893,
#    'magicResist': 45,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 5,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerFlash',
#    'teamID': 100,
#    'currentGold': 37,
#    'healthRegen': 24,
#    'ability4Level': 2,
#    'level': 14,
#    'ability1Level': 2,
#    'armorPenetration': 0,
#    'accountID': 2991794322826336,
#    'ability2Level': 5,
#    'health': 1893,
#    'ultimateName': 'XayahR',
#    'summonerSpell2Name': 'SummonerHaste',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 122,
#     'killPalisade': 175,
#     'killNeutralMinion': 174,
#     'starting': 500,
#     'itemSold': 190,
#     'ambient': 3051,
#     'killMinion': 5824,
#     'killStructure': 350,
#     'misc': 815},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 461, 'x': 394},
#    'primaryAbilityResourceMax': 943,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 30,
#    'ability2Name': 'XayahW',
#    'attackDamage': 257,
#    'ability3Name': 'XayahE',
#    'championName': 'Xayah',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': '100 Doublelift',
#    'respawnTimer': 0,
#    'attackSpeed': 222,
#    'XP': 11683,
#    'ultimateCooldownRemaining': 50.575439453125,
#    'summonerSpell1CooldownRemaining': 134.7880859375,
#    'armor': 81,
#    'ability1Name': 'XayahQ',
#    'totalGold': 11012,
#    'items': [{'itemID': 6675},
#     {'itemID': 6672, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 3036, 'itemCooldown': 0},
#     {'itemID': 3006, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 0}],
#    'abilityPower': 0,
#    'ability4Name': 'XayahR',
#    'stats': [{'value': 275, 'name': 'MINIONS_KILLED'},
#     {'value': 8, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 4, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 1, 'name': 'NUM_DEATHS'},
#     {'value': 2, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 11, 'name': 'WARD_PLACED'},
#     {'value': 8, 'name': 'WARD_KILLED'},
#     {'value': 30.55048179626465, 'name': 'VISION_SCORE'},
#     {'value': 159262.046875, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 152906, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 645.9283447265625, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 5710, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 5102.24609375, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 5071.31787109375, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 30.928325653076172, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 10737.1328125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 5990.05908203125, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 4253.76611328125, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 493.3096618652344, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 4485.171875, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 2093.407958984375, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 2093.407958984375, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 3059.298095703125, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 13.452926635742188, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 5.4059295654296875,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 4.6019744873046875, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 7, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 0, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 16, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 4, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 0, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 3, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 30.1002197265625,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 702,
#    'spellVamp': 0,
#    'participantID': 5,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 63,
#    'ability1CooldownRemaining': 3.24267578125,
#    'XPForNextLevel': 7300,
#    'summonerSpell2CooldownRemaining': 8.0230712890625,
#    'healthMax': 1976,
#    'magicResist': 55,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 3,
#    'ability2CooldownRemaining': 0.3336181640625,
#    'summonerSpell1Name': 'SummonerDot',
#    'teamID': 100,
#    'currentGold': 421,
#    'healthRegen': 35,
#    'ability4Level': 1,
#    'level': 10,
#    'ability1Level': 1,
#    'armorPenetration': 0,
#    'accountID': 2770027483498048,
#    'ability2Level': 5,
#    'health': 1524,
#    'ultimateName': 'RakanR',
#    'summonerSpell2Name': 'SummonerFlashPerksHextechFlashtraptionV2',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 202,
#     'ambient': 3459,
#     'killStructure': 100,
#     'killMinion': 126,
#     'supportItem': 823,
#     'starting': 500,
#     'misc': 395},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 590, 'x': 636},
#    'primaryAbilityResourceMax': 702,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'RakanW',
#    'attackDamage': 89,
#    'ability3Name': 'RakanE',
#    'championName': 'Rakan',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': '100 Busio',
#    'respawnTimer': 0,
#    'attackSpeed': 123,
#    'XP': 6514,
#    'ultimateCooldownRemaining': 30.1002197265625,
#    'summonerSpell1CooldownRemaining': 90.1485595703125,
#    'armor': 73,
#    'ability1Name': 'RakanQ',
#    'totalGold': 5605,
#    'items': [{'itemID': 3158, 'itemCooldown': 0},
#     {'itemID': 2065, 'itemCooldown': 17.216064453125},
#     {'itemID': 1028, 'itemCooldown': 0},
#     {'itemID': 3860, 'itemStacks': 4, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 1004, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 2, 'itemCooldown': 0}],
#    'abilityPower': 64,
#    'ability4Name': 'RakanR',
#    'stats': [{'value': 30, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 2, 'name': 'NUM_DEATHS'},
#     {'value': 3, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 49, 'name': 'WARD_PLACED'},
#     {'value': 7, 'name': 'WARD_KILLED'},
#     {'value': 78.54584503173828, 'name': 'VISION_SCORE'},
#     {'value': 12317.9736328125, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 3264.603271484375, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 1617.82568359375, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 7435.54345703125, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 1339.772705078125, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 273.9239196777344, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 915.8488159179688, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 150, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 8588.015625, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 3841.699462890625, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 4530.845703125, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 215.46971130371094, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 6501.46923828125, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 450.3592224121094, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 64.0769271850586, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 31.208213806152344, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 23.702796936035156,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 1271.485107421875, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 6.4334397315979, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 16, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 0, 'name': 'GET_BACK_PINGS'},
#     {'value': 2, 'name': 'RETREAT_PINGS'},
#     {'value': 20, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 5, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 9, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 10, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 30},
#   {'ability4CooldownRemaining': 46.526611328125,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 937,
#    'spellVamp': 0,
#    'participantID': 6,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 40,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 14700,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 3336,
#    'magicResist': 94,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 3,
#    'ability2CooldownRemaining': 6.0792236328125,
#    'summonerSpell1Name': 'SummonerFlash',
#    'teamID': 200,
#    'currentGold': 1235,
#    'healthRegen': 41,
#    'ability4Level': 2,
#    'level': 15,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382277410637088,
#    'ability2Level': 5,
#    'health': 3319,
#    'ultimateName': 'KSanteR',
#    'summonerSpell2Name': 'S12_SummonerTeleportUpgrade',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 347,
#     'starting': 500,
#     'ambient': 3051,
#     'itemSold': 190,
#     'killStructure': 541,
#     'killChampion': 300,
#     'killMinion': 4764,
#     'globalTeam': 300,
#     'misc': 105},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 2128, 'x': 1472},
#    'primaryAbilityResourceMax': 1205,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'KSanteW',
#    'attackDamage': 115,
#    'ability3Name': 'KSanteE',
#    'championName': 'KSante',
#    'ccReduction': 5,
#    'shutdownValue': 0,
#    'playerName': 'C9 Fudge',
#    'respawnTimer': 0,
#    'attackSpeed': 143,
#    'XP': 13972,
#    'ultimateCooldownRemaining': 46.526611328125,
#    'summonerSpell1CooldownRemaining': 212.0572509765625,
#    'armor': 277,
#    'ability1Name': 'KSanteQ',
#    'totalGold': 9909,
#    'items': [{'itemID': 3047, 'itemCooldown': 0},
#     {'itemID': 3068, 'itemStacks': 36, 'itemCooldown': 0},
#     {'itemID': 6662, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 3105, 'itemCooldown': 0},
#     {'itemID': 3340, 'itemStacks': 1, 'itemCooldown': 0}],
#    'abilityPower': 0,
#    'ability4Name': 'KSanteR',
#    'stats': [{'value': 222, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 1, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 1, 'name': 'NUM_DEATHS'},
#     {'value': 7, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 12, 'name': 'WARD_PLACED'},
#     {'value': 4, 'name': 'WARD_KILLED'},
#     {'value': 29.877037048339844, 'name': 'VISION_SCORE'},
#     {'value': 125463.21875, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 109109.2421875, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 9382.1181640625, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 6971.73828125, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 9912.83984375, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 7399.85302734375, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 1333.59716796875, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 1179.3883056640625, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 18357.853515625, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 12230.4921875, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 5891.482421875, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 235.88235473632812, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 27589.84765625, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 145.5091094970703, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 3241.663330078125, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 3241.663330078125, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 4907.02880859375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 2684.205810546875, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 261.5623779296875,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 27.716890335083008, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 20, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 21, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 66, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 13, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 23, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 2, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 1, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 4.1373291015625,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 894,
#    'spellVamp': 0,
#    'participantID': 7,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 57,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 13020,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 2913,
#    'magicResist': 93,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 5,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerFlash',
#    'teamID': 200,
#    'currentGold': 32,
#    'healthRegen': 28,
#    'ability4Level': 2,
#    'level': 14,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382277187036448,
#    'ability2Level': 2,
#    'health': 2913,
#    'ultimateName': 'MaokaiR',
#    'summonerSpell2Name': 'SummonerSmiteAvatarDefensive',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 772,
#     'globalTeam': 300,
#     'misc': 599,
#     'starting': 500,
#     'killNeutralMinion': 4149,
#     'ambient': 3051,
#     'killMinion': 84,
#     'killStructure': 525,
#     'itemUndo': 400},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 14391, 'x': 14340},
#    'primaryAbilityResourceMax': 894,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'MaokaiW',
#    'attackDamage': 109,
#    'ability3Name': 'MaokaiE',
#    'championName': 'Maokai',
#    'ccReduction': 19,
#    'shutdownValue': 0,
#    'playerName': 'C9 Blaber',
#    'respawnTimer': 0,
#    'attackSpeed': 125,
#    'XP': 12897,
#    'ultimateCooldownRemaining': 4.1373291015625,
#    'summonerSpell1CooldownRemaining': 176.5294189453125,
#    'armor': 142,
#    'stackingBuffs': [{'stacks': 1200, 'id': 3805539831},
#     {'stacks': 1, 'id': 1476838120}],
#    'ability1Name': 'MaokaiQ',
#    'totalGold': 10232,
#    'items': [{'itemID': 6667, 'itemCooldown': 28.748046875},
#     {'itemID': 4005, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 2, 'itemCooldown': 0},
#     {'itemID': 3158, 'itemCooldown': 0},
#     {'itemID': 4637, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 1, 'itemCooldown': 0}],
#    'abilityPower': 166,
#    'ability4Name': 'MaokaiR',
#    'stats': [{'value': 16, 'name': 'MINIONS_KILLED'},
#     {'value': 179.99993896484375, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 107.50003814697266,
#      'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 22.499998092651367,
#      'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 1, 'name': 'NUM_DEATHS'},
#     {'value': 10, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 11, 'name': 'WARD_PLACED'},
#     {'value': 11, 'name': 'WARD_KILLED'},
#     {'value': 48.490570068359375, 'name': 'VISION_SCORE'},
#     {'value': 240248.390625, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 25631.2265625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 152562.421875, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 62053.875, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 9665.001953125, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 174.80728149414062,
#      'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 8564.947265625, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 925.2484130859375, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 24812.720703125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 18456.78515625, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 6245.3505859375, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 110.58824157714844, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 24409.81640625, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 137.3691864013672, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 137.3691864013672, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 50479.8046875, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 526.757568359375, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 76.93649291992188,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 304.0416259765625, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 38.644596099853516, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 47, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 0, 'name': 'GET_BACK_PINGS'},
#     {'value': 17, 'name': 'RETREAT_PINGS'},
#     {'value': 119, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 8, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 2, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 2, 'name': 'PUSH_PINGS'},
#     {'value': 8, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 2, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 0, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 2006,
#    'spellVamp': 0,
#    'participantID': 8,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 285,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 16480,
#    'summonerSpell2CooldownRemaining': 205.112060546875,
#    'healthMax': 2167,
#    'magicResist': 88,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 4,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'S12_SummonerTeleportUpgrade',
#    'teamID': 200,
#    'currentGold': 1940,
#    'healthRegen': 29,
#    'ability4Level': 1,
#    'level': 16,
#    'ability1Level': 6,
#    'armorPenetration': 0,
#    'accountID': 2383216168420736,
#    'ability2Level': 6,
#    'health': 2167,
#    'ultimateName': 'JayceStanceGtH',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 150,
#     'shutdownReward': 100,
#     'misc': 1058,
#     'starting': 500,
#     'killNeutralMinion': 255,
#     'itemSold': 240,
#     'ambient': 3051,
#     'killChampion': 1600,
#     'killMinion': 5128,
#     'killStructure': 1366,
#     'globalTeam': 300},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 1590, 'x': 1060},
#    'primaryAbilityResourceMax': 2006,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 30,
#    'ability2Name': 'JayceHyperCharge',
#    'attackDamage': 382,
#    'ability3Name': 'JayceAccelerationGate',
#    'championName': 'Jayce',
#    'ccReduction': 30,
#    'shutdownValue': 300,
#    'playerName': 'C9 EMENES',
#    'respawnTimer': 0,
#    'attackSpeed': 143,
#    'XP': 15954,
#    'ultimateCooldownRemaining': 0,
#    'summonerSpell1CooldownRemaining': 89.1336669921875,
#    'armor': 101,
#    'stackingBuffs': [{'stacks': 4, 'id': 2609129978}],
#    'ability1Name': 'JayceShockBlast',
#    'totalGold': 13509,
#    'items': [{'itemID': 3142, 'itemCooldown': 0},
#     {'itemID': 2420, 'itemCooldown': 0},
#     {'itemID': 6694, 'itemCooldown': 0},
#     {'itemID': 3042},
#     {'itemID': 3111, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 57.83203125}],
#    'abilityPower': 0,
#    'ability4Name': 'JayceStanceGtH',
#    'stats': [{'value': 246, 'name': 'MINIONS_KILLED'},
#     {'value': 12, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 4, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 8, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 5, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 1, 'name': 'NUM_DEATHS'},
#     {'value': 3, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 14, 'name': 'WARD_PLACED'},
#     {'value': 11, 'name': 'WARD_KILLED'},
#     {'value': 40.75944137573242, 'name': 'VISION_SCORE'},
#     {'value': 175447.34375, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 163005.90625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 9201.9169921875, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 3239.412841796875, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 18399.1953125, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 15097.8056640625, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 2367.538330078125, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 933.8516235351562, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 8239.298828125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 4312.14501953125, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 3927.15478515625, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 6622.3115234375, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 6735.45751953125, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 6735.45751953125, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 16483.595703125, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 114.07571411132812, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 24.314208984375,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 4.668706893920898, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 16, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 11, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 24, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 8, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 3, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 1, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 3, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 37.92724609375,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 715,
#    'spellVamp': 0,
#    'participantID': 9,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 31,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 13020,
#    'summonerSpell2CooldownRemaining': 255.5523681640625,
#    'healthMax': 2459,
#    'magicResist': 49,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 5,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerBoost',
#    'teamID': 200,
#    'currentGold': 1286,
#    'healthRegen': 23,
#    'ability4Level': 2,
#    'level': 14,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2615481136170368,
#    'ability2Level': 2,
#    'health': 2459,
#    'ultimateName': 'ZeriR',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 332,
#     'killPalisade': 87,
#     'killStructure': 1133,
#     'starting': 500,
#     'itemSold': 60,
#     'ambient': 3051,
#     'killChampion': 1200,
#     'killMinion': 5606,
#     'globalTeam': 300,
#     'misc': 375},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 18,
#    'position': {'z': 1538, 'x': 860},
#    'primaryAbilityResourceMax': 794,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'ZeriW',
#    'attackDamage': 119,
#    'ability3Name': 'ZeriE',
#    'championName': 'Zeri',
#    'ccReduction': 0,
#    'shutdownValue': 600,
#    'playerName': 'C9 Berserker',
#    'respawnTimer': 0,
#    'attackSpeed': 177,
#    'XP': 11623,
#    'ultimateCooldownRemaining': 37.92724609375,
#    'summonerSpell1CooldownRemaining': 162.090576171875,
#    'armor': 87,
#    'stackingBuffs': [{'stacks': 78, 'id': 3290852513}],
#    'ability1Name': 'ZeriQ',
#    'totalGold': 12685,
#    'items': [{'itemID': 2421, 'itemCooldown': 0},
#     {'itemID': 4636, 'itemCooldown': 0},
#     {'itemID': 3020, 'itemCooldown': 0},
#     {'itemID': 4645, 'itemCooldown': 0},
#     {'itemID': 3087, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 0}],
#    'abilityPower': 208,
#    'ability4Name': 'ZeriR',
#    'stats': [{'value': 280, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 4, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 0, 'name': 'NUM_DEATHS'},
#     {'value': 5, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 13, 'name': 'WARD_PLACED'},
#     {'value': 17, 'name': 'WARD_KILLED'},
#     {'value': 57.86272430419922, 'name': 'VISION_SCORE'},
#     {'value': 193003.375, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 60903.59765625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 124766.640625, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 7333.859375, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 17253.92578125, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 4169.2509765625, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 12942.2275390625, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 142.4599609375, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 6943.802734375, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 4837.9345703125, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 2105.86865234375, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 3825.11328125, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 9372.8828125, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 9372.8828125, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 23252.9453125, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 75.01016235351562, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 21.22528076171875,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 3.457256317138672, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 18, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 5, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 22, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 3, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 8, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 1, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 8, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 61.2691650390625,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 1057,
#    'spellVamp': 0,
#    'participantID': 10,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 166,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 11440,
#    'summonerSpell2CooldownRemaining': 142.1307373046875,
#    'healthMax': 1530,
#    'magicResist': 40,
#    'ability3CooldownRemaining': 0.904296875,
#    'ability3Level': 5,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerHeal',
#    'teamID': 200,
#    'currentGold': 625,
#    'healthRegen': 22,
#    'ability4Level': 2,
#    'level': 13,
#    'ability1Level': 6,
#    'armorPenetration': 0,
#    'accountID': 2382277312029984,
#    'ability2Level': 1,
#    'health': 1530,
#    'ultimateName': 'YuumiR',
#    'summonerSpell2Name': 'SummonerExhaust',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 502,
#     'killPalisade': 262,
#     'killChampion': 600,
#     'killStructure': 1133,
#     'starting': 500,
#     'itemSold': 20,
#     'ambient': 3456,
#     'killMinion': 56,
#     'supportItem': 760,
#     'globalTeam': 300,
#     'misc': 190},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 1224, 'x': 1544},
#    'primaryAbilityResourceMax': 1182,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'YuumiW',
#    'attackDamage': 87,
#    'ability3Name': 'YuumiE',
#    'championName': 'Yuumi',
#    'ccReduction': 0,
#    'shutdownValue': 150,
#    'playerName': 'C9 Zven',
#    'respawnTimer': 0,
#    'attackSpeed': 110,
#    'XP': 10378,
#    'ultimateCooldownRemaining': 61.2691650390625,
#    'summonerSpell1CooldownRemaining': 184.7423095703125,
#    'armor': 83,
#    'stackingBuffs': [{'stacks': 2, 'id': 3086459433}],
#    'ability1Name': 'YuumiQ',
#    'totalGold': 7910,
#    'items': [{'itemID': 1052, 'itemCooldown': 0},
#     {'itemID': 4005, 'itemCooldown': 0},
#     {'itemID': 3114, 'itemCooldown': 0},
#     {'itemID': 3853, 'itemCooldown': 0},
#     {'itemID': 6620, 'itemStacks': 2, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 0, 'itemCooldown': 88.9637451171875}],
#    'abilityPower': 296,
#    'ability4Name': 'YuumiR',
#    'stats': [{'value': 7, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 2, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 0, 'name': 'NUM_DEATHS'},
#     {'value': 9, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 33, 'name': 'WARD_PLACED'},
#     {'value': 4, 'name': 'WARD_KILLED'},
#     {'value': 64.16453552246094, 'name': 'VISION_SCORE'},
#     {'value': 13499.9736328125, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 808.1807250976562, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 12466.79296875, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 225, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 6536.8681640625, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 284.9861145019531, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 6051.88232421875, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 200, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 2073.35595703125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 1933.183349609375, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 140.17263793945312, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 1123.9217529296875, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 3593.337646484375, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 1392.4373779296875, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 1392.4373779296875, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 2258.228271484375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 134.00726318359375, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 119.60211181640625,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 5034.3740234375, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 13.313274383544922, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 8, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 1, 'name': 'GET_BACK_PINGS'},
#     {'value': 5, 'name': 'RETREAT_PINGS'},
#     {'value': 25, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 0, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 3, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 18, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 1, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 30}],
#  'gameName': '110303581088069312|game1',
#  'sequenceIndex': 5844,
#  'teams': [{'inhibKills': 0,
#    'towerKills': 1,
#    'teamID': 100,
#    'baronKills': 0,
#    'dragonKills': 0,
#    'assists': 9,
#    'championsKills': 3,
#    'totalGold': 42879,
#    'deaths': 12},
#   {'inhibKills': 1,
#    'towerKills': 9,
#    'teamID': 200,
#    'baronKills': 1,
#    'dragonKills': 4,
#    'assists': 34,
#    'championsKills': 12,
#    'totalGold': 54245,
#    'deaths': 3}],
#  'gameOver': False,
#  'playbackID': 1}

# %%
event = game_data[2001]

participant_data = event['participants'][0]


event_time = event['eventTime']
def extract_participant_stats(participant_data):
    """
    Extracts basic stats from participant data
    """
    participant_id = str(participant_data['participantID'])
    team_id = str(participant_data['teamID'])
    participant_stats_basic = {'XP': participant_data['XP'], 'totalGold': participant_data['totalGold'], 'currentGold':participant_data['currentGold']}
    participant_stats_frames = participant_data['stats']
    participant_stats_granular = extract_participants_granular_stats(participant_stats_frames)
    
    # Combine the basic and granular stats
    participant_stats = {'participant_id': participant_id, 'team_id': team_id, **participant_stats_basic, **participant_stats_granular}
    return participant_stats
    
def extract_participants_granular_stats(stats_frames):
    """
    Extracts granular stats from participant data (e.g. minions killed, jungle minions killed, KDA, etc.)
    :param stats_frame: the 'stats' item from the 'status_update' event 
    :return: a dictionary of granular stats
    """
    stat_record = {}
    stats_to_record = {'MINIONS_KILLED', 'NEUTRAL_MINIONS_KILLED', 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE', 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE', 'CHAMPIONS_KILLED','NUM_DEATHS','ASSISTS',
                       'WARD_PLACED','WARD_KILLED','VISION_SCORE','TOTAL_DAMAGE_DEALT_TO_CHAMPIONS', 'TOTAL_DAMAGE_TAKEN', 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS', 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'}
    # other stats to consider 
    # ['TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS', 'TOTAL_HEAL_ON_TEAMMATES', 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES']
    for stat in stats_frames:
        stat_name = stat['name']
        if stat_name in stats_to_record:
            stat_record[stat_name] = stat['value']
    return stat_record

# Now need to convert frame_stats into a single row of data for each team (100 and 200)
def create_participant_features(frame_stats):
    """
    Creates higher-order features for each participant (e.g. KDA, minions killed, etc.) 
    :param frame_stats: a dataframe with stats for each participant for a single team at a single point in time
    :return: a dataframe with features for each participant
    """
    # Create features for each participant
    # For KDA, we need to add 0.1 to the denominator to avoid dividing by 0
    num_minutes = frame_stats['event_time'] / 60
    frame_stats['KDA'] = (frame_stats['CHAMPIONS_KILLED'] + frame_stats['ASSISTS']) / (frame_stats['NUM_DEATHS'] + 1.0)
    frame_stats['cs_per_min'] = (frame_stats['MINIONS_KILLED'] + frame_stats['NEUTRAL_MINIONS_KILLED']) / num_minutes
    frame_stats['xp_per_min'] = frame_stats['XP'] / num_minutes
    frame_stats['gold_per_min'] = frame_stats['totalGold'] / num_minutes
    frame_stats['vision_per_min'] = frame_stats['VISION_SCORE'] / num_minutes
    frame_stats['wards_per_min'] = (frame_stats['WARD_PLACED'] + frame_stats['WARD_KILLED']) / num_minutes
    frame_stats['trade_efficiency'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / (frame_stats['TOTAL_DAMAGE_TAKEN'] + 1.0)  # Higher for poke-heavy champions
    frame_stats['damage_to_champions_per_min'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / num_minutes
    frame_stats['damage_to_buildings_per_min'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'] / num_minutes
    frame_stats['gold_spent'] = frame_stats['totalGold'] - frame_stats['currentGold']
    frame_stats['share_of_minions_stolen'] = frame_stats['NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'] / (frame_stats['NEUTRAL_MINIONS_KILLED'] + 1.0)
    frame_stats['share_of_team_gold'] = frame_stats['totalGold'] / frame_stats['totalGold'].sum()
    frame_stats['share_of_team_xp'] = frame_stats['XP'] / frame_stats['XP'].sum()
    frame_stats['share_of_team_damage_to_champions'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'].sum()
    frame_stats['share_of_team_damage_to_buildings'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'].sum()
    frame_stats['share_of_team_damage_to_objectives'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'].sum()
    return frame_stats

team_features_from_event_data = ['inhibKills', 'towerKills', 'baronKills', 'dragonKills', 'assists', 'championsKills', 'totalGold', 'deaths']
team_features_from_frame_stats = ['MINIONS_KILLED', 'NEUTRAL_MINIONS_KILLED', 'VISION_SCORE']

def create_team_features(frame_stats, event_data):
    """
    Creates team-level features (e.g. total gold, total share of dragons/barons taken, etc.)
    :param frame_stats: A previously generated dataframe with features for each participant 
    :param event_data: The event data for the current event 
    :return: 
    """
    # Extract the team_features for each team based on event_data['teams'][i][feature]
    # Then compute the share of each feature for each team (whenever both features are zero, set the share to 0.5)
    # Then add the share of each feature to the frame_stats dataframe
    
    # First extract the team features from event_data
    team_features = {'100': {}, '200': {}}
    for team in event_data['teams']:
        team_id = str(team['teamID'])
        for feature in team_features_from_event_data:
            team_features[team_id][feature] = team[feature]
    
    # Compute the data for each team as the sum of the data for each participant on each team 
    for team in team_features:
        for feature in team_features_from_frame_stats:
            team_features[team][feature] = frame_stats[frame_stats['team_id'] == team][feature].sum()
    
    # Now compute the share of each feature for each team, setting the share to 0.5 if they are both 0
    for team in team_features:
        for feature in team_features_from_event_data + team_features_from_frame_stats:
            total_value = (team_features['100'][feature] + team_features['200'][feature])
            if total_value == 0:
                team_features[team]['team_share_of_' + feature] = 0.5
            else:
                team_features[team]['team_share_of_' + feature] = team_features[team][feature] / total_value
                
    # Drop all features that are not 'share_of_' features
    for team in team_features:
        for feature in team_features_from_event_data + team_features_from_frame_stats:
            del team_features[team][feature]
    return team_features
            

def create_diff_features(frame_stats):
    # Create features based on the difference between the player on the row and the player on the other team (row +5)
    # Do this for the first 5 players
    # For diff metrics, the value for the other team is the negative of the values for the first team 
    # For share metrics, the value for the other team is 1- the value for the first team
    
    # DIFF METRICS
    # Overall relative performance indicators 
    frame_stats['KDA_diff'] = (frame_stats['KDA'] - frame_stats['KDA'].shift(-5))  
    frame_stats['cs_per_min_diff'] = (frame_stats['cs_per_min'] - frame_stats['cs_per_min'].shift(-5))
    frame_stats['xp_per_min_diff'] = (frame_stats['xp_per_min'] - frame_stats['xp_per_min'].shift(-5))
    frame_stats['gold_per_min_diff'] = (frame_stats['gold_per_min'] - frame_stats['gold_per_min'].shift(-5))
    frame_stats['vision_per_min_diff'] = (frame_stats['vision_per_min'] - frame_stats['vision_per_min'].shift(-5))
    frame_stats['wards_per_min_diff'] = (frame_stats['wards_per_min'] - frame_stats['wards_per_min'].shift(-5))
    
    # Lane trade indicators
    frame_stats['trade_efficiency_diff'] = (frame_stats['trade_efficiency'] - frame_stats['trade_efficiency'].shift(-5))
    frame_stats['damage_to_champions_per_min_diff'] = (frame_stats['damage_to_champions_per_min'] - frame_stats['damage_to_champions_per_min'].shift(-5))
    frame_stats['damage_to_buildings_per_min_diff'] = (frame_stats['damage_to_buildings_per_min'] - frame_stats['damage_to_buildings_per_min'].shift(-5))
    
    # SHARE METRICS
    # Opponent dominance indicators
    frame_stats['lane_cs_dominance'] = (frame_stats['cs_per_min'] / (frame_stats['cs_per_min'] + frame_stats['cs_per_min'].shift(-5)))
    frame_stats['lane_damage_to_champions_dominance'] = (frame_stats['damage_to_champions_per_min'] / 
                                                         (1.0 + frame_stats['damage_to_champions_per_min'] + frame_stats['damage_to_champions_per_min'].shift(-5)))
    frame_stats['lane_damage_to_buildings_dominance'] = (frame_stats['damage_to_buildings_per_min'] / 
                                                         (1.0 + frame_stats['damage_to_buildings_per_min'] + frame_stats['damage_to_buildings_per_min'].shift(-5)))
    
    # AGGREGATE METRICS
    # Now get the values for the other team (row +5) by either doing negative or 1- the values we just computed. But ONLY operate on rows 5-9
    # DIFF METRICS
    frame_stats.loc[5:10, 'KDA_diff'] = -frame_stats.loc[0:4, 'KDA_diff'].values
    frame_stats.loc[5:10, 'cs_per_min_diff'] = -frame_stats.loc[0:4, 'cs_per_min_diff'].values
    frame_stats.loc[5:10, 'xp_per_min_diff'] = -frame_stats.loc[0:4, 'xp_per_min_diff'].values
    frame_stats.loc[5:10, 'gold_per_min_diff'] = -frame_stats.loc[0:4, 'gold_per_min_diff'].values
    frame_stats.loc[5:10, 'vision_per_min_diff'] = -frame_stats.loc[0:4, 'vision_per_min_diff'].values
    frame_stats.loc[5:10, 'trade_efficiency_diff'] = -frame_stats.loc[0:4, 'trade_efficiency_diff'].values
    frame_stats.loc[5:10, 'damage_to_champions_per_min_diff'] = -frame_stats.loc[0:4, 'damage_to_champions_per_min_diff'].values
    frame_stats.loc[5:10, 'damage_to_buildings_per_min_diff'] = -frame_stats.loc[0:4, 'damage_to_buildings_per_min_diff'].values
    # SHARE METRICS
    frame_stats.loc[5:10, 'lane_cs_dominance'] = 1 - frame_stats.loc[0:4, 'lane_cs_dominance'].values
    frame_stats.loc[5:10, 'lane_damage_to_champions_dominance'] = 1 - frame_stats.loc[0:4, 'lane_damage_to_champions_dominance'].values
    frame_stats.loc[5:10, 'lane_damage_to_buildings_dominance'] = 1 - frame_stats.loc[0:4, 'lane_damage_to_buildings_dominance'].values
    
    return frame_stats


participant_mapping = {
    '1': 'top',
    '2': 'jungle',
    '3': 'mid',
    '4': 'bot',
    '5': 'support',
    '6': 'top',
    '7': 'jungle',
    '8': 'mid',
    '9': 'bot',
    '10': 'support'
}
def melt_frame_stats(frame_stats):
    """
    Melts the frame_stats dataframe so that each row is a single feature for all participants
    """
    # Rename the participant_id such that it maps to ["top","jungle","mid","bot","support"] for each team
    frame_stats['participant_id'] = frame_stats['participant_id'].map(participant_mapping)
    frame_stats = frame_stats.melt(id_vars = ['participant_id'], value_vars = frame_stats.columns)
    frame_stats['name'] = frame_stats['participant_id'] + '_' + frame_stats['variable']
    frame_stats = frame_stats[['name','value']].set_index('name').transpose()
    return frame_stats

# %%
event
# Out:
# {'eventTime': '2023-06-22T23:02:24.156Z',
#  'eventType': 'stats_update',
#  'platformGameId': 'ESPORTSTMNT02:3207804',
#  'gameTime': 1171003,
#  'stageID': 1,
#  'participants': [{'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 699,
#    'spellVamp': 0,
#    'participantID': 1,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 27,
#    'ability1CooldownRemaining': 2.568115234375,
#    'XPForNextLevel': 9960,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 3191,
#    'magicResist': 77,
#    'ability3CooldownRemaining': 0.8946533203125,
#    'ability3Level': 1,
#    'ability2CooldownRemaining': 10.202392578125,
#    'summonerSpell1Name': 'S12_SummonerTeleportUpgrade',
#    'teamID': 100,
#    'currentGold': 780,
#    'healthRegen': 38,
#    'ability4Level': 2,
#    'level': 12,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382277692401216,
#    'ability2Level': 4,
#    'health': 2260,
#    'ultimateName': 'SionR',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 20,
#     'killPalisade': 350,
#     'misc': 45,
#     'itemSold': 5,
#     'killMinion': 3201,
#     'starting': 500,
#     'ambient': 2164},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 1159, 'x': 6195},
#    'primaryAbilityResourceMax': 1031,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'SionW',
#    'attackDamage': 107,
#    'ability3Name': 'SionE',
#    'championName': 'Sion',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': '100 Ssumday',
#    'respawnTimer': 0,
#    'attackSpeed': 122,
#    'XP': 9266,
#    'ultimateCooldownRemaining': 0,
#    'stackingBuffs': [{'stacks': 707, 'id': 1911847746},
#     {'stacks': 3, 'id': 968555378}],
#    'armor': 155,
#    'summonerSpell1CooldownRemaining': 0,
#    'ability1Name': 'SionQ',
#    'totalGold': 6280,
#    'items': [{'itemID': 3047, 'itemCooldown': 0},
#     {'itemID': 2031, 'itemCooldown': 0},
#     {'itemID': 1028, 'itemCooldown': 0},
#     {'itemID': 3068, 'itemStacks': 43, 'itemCooldown': 0},
#     {'itemID': 1033, 'itemCooldown': 0},
#     {'itemID': 1054, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 19.9539794921875}],
#    'abilityPower': 0,
#    'ability4Name': 'SionR',
#    'stats': [{'value': 155, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 1, 'name': 'NUM_DEATHS'},
#     {'value': 0, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 8, 'name': 'WARD_PLACED'},
#     {'value': 2, 'name': 'WARD_KILLED'},
#     {'value': 16.944278717041016, 'name': 'VISION_SCORE'},
#     {'value': 72929.0546875, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 50844.7890625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 22083.263671875, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 1, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 4208.474609375, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 2039.4429931640625,
#      'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 2168.03173828125, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 1, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 11425.681640625, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 7993.54052734375, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 3137.671875, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 294.4728698730469, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 16499.1171875, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 2372.916259765625, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 2372.916259765625, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 2927.5458984375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 299.9603271484375, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 42.69746398925781,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 11.659530639648438, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 25, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 4, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 3, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 0, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 2, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 0, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 803,
#    'spellVamp': 0,
#    'participantID': 2,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 156,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 7300,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 1757,
#    'magicResist': 68,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 1,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerFlash',
#    'teamID': 100,
#    'currentGold': 948,
#    'healthRegen': 29,
#    'ability4Level': 1,
#    'level': 10,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382276651083040,
#    'ability2Level': 3,
#    'health': 1163,
#    'ultimateName': 'MonkeyKingSpinToWin',
#    'summonerSpell2Name': 'SummonerSmiteAvatarUtility',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 105,
#     'killPalisade': 87,
#     'misc': 160,
#     'ambient': 2164,
#     'killMinion': 42,
#     'starting': 500,
#     'killNeutralMinion': 3079},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 2930, 'x': 4577},
#    'primaryAbilityResourceMax': 803,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'monkeykingdecoy',
#    'attackDamage': 148,
#    'ability3Name': 'MonkeyKingNimbus',
#    'championName': 'MonkeyKing',
#    'ccReduction': 30,
#    'shutdownValue': 0,
#    'playerName': '100 Closer',
#    'respawnTimer': 0,
#    'attackSpeed': 149,
#    'XP': 7207,
#    'ultimateCooldownRemaining': 0,
#    'stackingBuffs': [{'stacks': 1200, 'id': 3805539831},
#     {'stacks': 1, 'id': 1476838120}],
#    'armor': 74,
#    'summonerSpell1CooldownRemaining': 0,
#    'ability1Name': 'MonkeyKingDoubleAttack',
#    'totalGold': 6138,
#    'items': [{'itemID': 3111, 'itemCooldown': 0},
#     {'itemID': 6632, 'itemCooldown': 0},
#     {'itemID': 1036, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 0, 'itemCooldown': 23.67138671875}],
#    'abilityPower': 0,
#    'ability4Name': 'MonkeyKingSpinToWin',
#    'stats': [{'value': 7, 'name': 'MINIONS_KILLED'},
#     {'value': 116.0000228881836, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 94.0000228881836, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 2.5, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 1, 'name': 'NUM_DEATHS'},
#     {'value': 1, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 5, 'name': 'WARD_PLACED'},
#     {'value': 5, 'name': 'WARD_KILLED'},
#     {'value': 18.542064666748047, 'name': 'VISION_SCORE'},
#     {'value': 113773.890625, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 69721.4609375, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 11137.5205078125, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 32915.01953125, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 1537.889892578125, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 1312.8935546875, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 139.11404418945312, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 85.88235473632812, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 14318.3955078125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 8940.3642578125, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 5020.13671875, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 357.88116455078125, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 9691.404296875, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 10505.603515625, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 119.23455810546875, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 2.96978759765625,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 1.2456618547439575, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 26, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 7, 'name': 'GET_BACK_PINGS'},
#     {'value': 1, 'name': 'RETREAT_PINGS'},
#     {'value': 44, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 9, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 17, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 3, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 1, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 0, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 23.9512939453125,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 1100,
#    'spellVamp': 0,
#    'participantID': 3,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 189,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 9960,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 1953,
#    'magicResist': 42,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 4,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'S12_SummonerTeleportUpgrade',
#    'teamID': 100,
#    'currentGold': 710,
#    'healthRegen': 29,
#    'ability4Level': 2,
#    'level': 12,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2878373465278176,
#    'ability2Level': 1,
#    'health': 654,
#    'ultimateName': 'NeekoR',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 5,
#     'killPalisade': 262,
#     'misc': 60,
#     'itemSold': 775,
#     'killMinion': 3554,
#     'killChampion': 300,
#     'starting': 500,
#     'ambient': 2164},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 6,
#    'position': {'z': 1907, 'x': 4669},
#    'primaryAbilityResourceMax': 1115,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'NeekoW2',
#    'attackDamage': 72,
#    'ability3Name': 'NeekoE',
#    'championName': 'Neeko',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': '100 Quid',
#    'respawnTimer': 0,
#    'attackSpeed': 144,
#    'XP': 9708,
#    'ultimateCooldownRemaining': 23.9512939453125,
#    'armor': 78,
#    'summonerSpell1CooldownRemaining': 41.7486572265625,
#    'ability1Name': 'NeekoQ',
#    'totalGold': 6845,
#    'items': [{'itemID': 1056, 'itemCooldown': 0},
#     {'itemID': 1026, 'itemCooldown': 0},
#     {'itemID': 3152, 'itemCooldown': 0},
#     {'itemID': 3158, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 0}],
#    'abilityPower': 154,
#    'ability4Name': 'NeekoR',
#    'stats': [{'value': 178, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 1, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 2, 'name': 'NUM_DEATHS'},
#     {'value': 0, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 10, 'name': 'WARD_PLACED'},
#     {'value': 2, 'name': 'WARD_KILLED'},
#     {'value': 13.898396492004395, 'name': 'VISION_SCORE'},
#     {'value': 85254.3046875, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 12210.5634765625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 69178.7109375, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 3865, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 4621.33251953125, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 304.6264343261719, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 4316.70556640625, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 6492.63525390625, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 3605.030029296875, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 2570.530029296875, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 317.0740966796875, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 2847.68408203125, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 282.1368713378906, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 282.1368713378906, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 282.1368713378906, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 129.1129913330078, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 11.40252685546875,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 9.76580810546875, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 14, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 0, 'name': 'GET_BACK_PINGS'},
#     {'value': 2, 'name': 'RETREAT_PINGS'},
#     {'value': 13, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 1, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 4, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 0, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 724,
#    'spellVamp': 0,
#    'participantID': 4,
#    'lifeSteal': 3,
#    'primaryAbilityResourceRegen': 30,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 8580,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 1555,
#    'magicResist': 41,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 5,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerFlash',
#    'teamID': 100,
#    'currentGold': 833,
#    'healthRegen': 19,
#    'ability4Level': 2,
#    'level': 11,
#    'ability1Level': 1,
#    'armorPenetration': 0,
#    'accountID': 2991794322826336,
#    'ability2Level': 3,
#    'health': 1389,
#    'ultimateName': 'XayahR',
#    'summonerSpell2Name': 'SummonerHaste',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 80,
#     'killPalisade': 175,
#     'misc': 640,
#     'itemSold': 190,
#     'killMinion': 4089,
#     'starting': 500,
#     'ambient': 2164},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 4201, 'x': 4840},
#    'primaryAbilityResourceMax': 811,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'XayahW',
#    'attackDamage': 201,
#    'ability3Name': 'XayahE',
#    'championName': 'Xayah',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': '100 Doublelift',
#    'respawnTimer': 0,
#    'attackSpeed': 209,
#    'XP': 7765,
#    'ultimateCooldownRemaining': 0,
#    'armor': 67,
#    'summonerSpell1CooldownRemaining': 0,
#    'ability1Name': 'XayahQ',
#    'totalGold': 7648,
#    'items': [{'itemID': 1038, 'itemCooldown': 0},
#     {'itemID': 6672, 'itemCooldown': 0},
#     {'itemID': 3133, 'itemCooldown': 0},
#     {'itemID': 3006, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 66.9539794921875}],
#    'abilityPower': 0,
#    'ability4Name': 'XayahR',
#    'stats': [{'value': 206, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 0, 'name': 'NUM_DEATHS'},
#     {'value': 1, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 9, 'name': 'WARD_PLACED'},
#     {'value': 6, 'name': 'WARD_KILLED'},
#     {'value': 22.01340103149414, 'name': 'VISION_SCORE'},
#     {'value': 85609.7890625, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 83483.8515625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 645.9283447265625, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 1480, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 3400.347412109375, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 3369.419189453125, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 30.928325653076172, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 4414.96337890625, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 2292.54736328125, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 2031.9501953125, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 90.465576171875, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 1800.707763671875, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 680.0380249023438, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 680.0380249023438, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 1645.9287109375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 4.6019744873046875, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 4.6019744873046875,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 4.6019744873046875, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 7, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 0, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 10, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 4, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 0, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 3, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 567,
#    'spellVamp': 0,
#    'participantID': 5,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 36,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 6120,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 1727,
#    'magicResist': 53,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 2,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerDot',
#    'teamID': 100,
#    'currentGold': 325,
#    'healthRegen': 33,
#    'ability4Level': 1,
#    'level': 9,
#    'ability1Level': 1,
#    'armorPenetration': 0,
#    'accountID': 2770027483498048,
#    'ability2Level': 5,
#    'health': 1314,
#    'ultimateName': 'RakanR',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 70,
#     'misc': 190,
#     'killMinion': 126,
#     'supportItem': 823,
#     'starting': 500,
#     'ambient': 2441},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 461, 'x': 394},
#    'primaryAbilityResourceMax': 652,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'RakanW',
#    'attackDamage': 85,
#    'ability3Name': 'RakanE',
#    'championName': 'Rakan',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': '100 Busio',
#    'respawnTimer': 0,
#    'attackSpeed': 120,
#    'XP': 5107,
#    'ultimateCooldownRemaining': 0,
#    'armor': 69,
#    'summonerSpell1CooldownRemaining': 0,
#    'ability1Name': 'RakanQ',
#    'totalGold': 4150,
#    'items': [{'itemID': 3158, 'itemCooldown': 0},
#     {'itemID': 3067, 'itemCooldown': 0},
#     {'itemID': 4642, 'itemCooldown': 0},
#     {'itemID': 3860, 'itemStacks': 4, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 1, 'itemCooldown': 0}],
#    'abilityPower': 49,
#    'ability4Name': 'RakanR',
#    'stats': [{'value': 28, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 1, 'name': 'NUM_DEATHS'},
#     {'value': 1, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 27, 'name': 'WARD_PLACED'},
#     {'value': 5, 'name': 'WARD_KILLED'},
#     {'value': 44.823692321777344, 'name': 'VISION_SCORE'},
#     {'value': 11564.017578125, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 3215.798828125, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 1062.6739501953125, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 7285.54345703125, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 590.8165283203125, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 230.11944580078125,
#      'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 360.6970520019531, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 4018.471923828125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 1103.431396484375, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 2817.24658203125, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 97.79350280761719, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 3359.1728515625, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 210.75917053222656,
#      'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 64.0769271850586, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 20.777549743652344, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 13.272132873535156,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 597.8876342773438, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 3.3795156478881836, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 11, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 0, 'name': 'GET_BACK_PINGS'},
#     {'value': 2, 'name': 'RETREAT_PINGS'},
#     {'value': 19, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 0, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 7, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 5, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 30},
#   {'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 917,
#    'spellVamp': 0,
#    'participantID': 6,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 33,
#    'ability1CooldownRemaining': 0.558349609375,
#    'XPForNextLevel': 9960,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 2686,
#    'magicResist': 54,
#    'ability3CooldownRemaining': 7.3179931640625,
#    'ability3Level': 1,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerFlash',
#    'teamID': 200,
#    'currentGold': 405,
#    'healthRegen': 43,
#    'ability4Level': 2,
#    'level': 12,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382277410637088,
#    'ability2Level': 4,
#    'health': 2430,
#    'ultimateName': 'KSanteR',
#    'summonerSpell2Name': 'S12_SummonerTeleportUpgrade',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 122,
#     'killStructure': 150,
#     'misc': 45,
#     'itemSold': 10,
#     'killMinion': 3519,
#     'ambient': 2164,
#     'starting': 500},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 6406, 'x': 6122},
#    'primaryAbilityResourceMax': 1000,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'KSanteW',
#    'attackDamage': 103,
#    'ability3Name': 'KSanteE',
#    'championName': 'KSante',
#    'ccReduction': 0,
#    'shutdownValue': 0,
#    'playerName': 'C9 Fudge',
#    'respawnTimer': 0,
#    'attackSpeed': 134,
#    'XP': 9384,
#    'ultimateCooldownRemaining': 0,
#    'armor': 190,
#    'summonerSpell1CooldownRemaining': 0,
#    'ability1Name': 'KSanteQ',
#    'totalGold': 6500,
#    'items': [{'itemID': 1054, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 6662, 'itemCooldown': 0},
#     {'itemID': 3047, 'itemCooldown': 0},
#     {'itemID': 6660, 'itemCooldown': 0},
#     {'itemID': 1029, 'itemCooldown': 0},
#     {'itemID': 3340, 'itemStacks': 0, 'itemCooldown': 98.943115234375}],
#    'abilityPower': 0,
#    'ability4Name': 'KSanteR',
#    'stats': [{'value': 169, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 1, 'name': 'NUM_DEATHS'},
#     {'value': 2, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 8, 'name': 'WARD_PLACED'},
#     {'value': 2, 'name': 'WARD_KILLED'},
#     {'value': 16.977075576782227, 'name': 'VISION_SCORE'},
#     {'value': 81876.140625, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 75396.515625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 782.6912231445312, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 5696.90869140625, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 2864.461669921875, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 2511.022216796875, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 271.4017639160156, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 82.03813934326172, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 9222.76953125, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 6258.80615234375, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 2878.08056640625, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 85.88235473632812, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 9248.818359375, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 1559.7861328125, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 1508.998291015625, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 26.43321990966797,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 11.422286987304688, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 14, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 17, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 35, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 5, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 10, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 1, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 1, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 32.6600341796875,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 511,
#    'spellVamp': 0,
#    'participantID': 7,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 95,
#    'ability1CooldownRemaining': 1.4110107421875,
#    'XPForNextLevel': 9960,
#    'summonerSpell2CooldownRemaining': 2.0361328125,
#    'healthMax': 2503,
#    'magicResist': 83,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 4,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerFlash',
#    'teamID': 200,
#    'currentGold': 1276,
#    'healthRegen': 24,
#    'ability4Level': 2,
#    'level': 12,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382277187036448,
#    'ability2Level': 1,
#    'health': 2503,
#    'ultimateName': 'MaokaiR',
#    'summonerSpell2Name': 'SummonerSmiteAvatarDefensive',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 422,
#     'starting': 500,
#     'killNeutralMinion': 3424,
#     'killStructure': 150,
#     'misc': 406,
#     'killMinion': 49,
#     'ambient': 2164,
#     'itemUndo': 400},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 2938, 'x': 6856},
#    'primaryAbilityResourceMax': 798,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'MaokaiW',
#    'attackDamage': 101,
#    'ability3Name': 'MaokaiE',
#    'championName': 'Maokai',
#    'ccReduction': 19,
#    'shutdownValue': 0,
#    'playerName': 'C9 Blaber',
#    'respawnTimer': 0,
#    'attackSpeed': 120,
#    'XP': 8870,
#    'ultimateCooldownRemaining': 32.6600341796875,
#    'stackingBuffs': [{'stacks': 1200, 'id': 3805539831}],
#    'armor': 97,
#    'summonerSpell1CooldownRemaining': 0,
#    'ability1Name': 'MaokaiQ',
#    'totalGold': 7266,
#    'items': [{'itemID': 4637, 'itemCooldown': 0},
#     {'itemID': 3158, 'itemCooldown': 0},
#     {'itemID': 1011, 'itemCooldown': 0},
#     {'itemID': 1033, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 1, 'itemCooldown': 0}],
#    'abilityPower': 104,
#    'ability4Name': 'MaokaiR',
#    'stats': [{'value': 12, 'name': 'MINIONS_KILLED'},
#     {'value': 140.00003051757812, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 95.5000228881836, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 6.5, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 0, 'name': 'NUM_DEATHS'},
#     {'value': 4, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 7, 'name': 'WARD_PLACED'},
#     {'value': 9, 'name': 'WARD_KILLED'},
#     {'value': 33.24052810668945, 'name': 'VISION_SCORE'},
#     {'value': 166534.671875, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 20898.201171875, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 104305.703125, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 41330.40234375, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 5524.2021484375, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 88.7878189086914, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 4844.71875, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 590.6961059570312, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 15340.2841796875, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 10425.4208984375, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 4914.86328125, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 11750.6376953125, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 31355.912109375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 434.6139221191406, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 54.628509521484375,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 23.717641830444336, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 32, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 0, 'name': 'GET_BACK_PINGS'},
#     {'value': 17, 'name': 'RETREAT_PINGS'},
#     {'value': 73, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 2, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 2, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 2, 'name': 'PUSH_PINGS'},
#     {'value': 5, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 1, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 0, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 1076,
#    'spellVamp': 0,
#    'participantID': 8,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 31,
#    'ability1CooldownRemaining': 1.751220703125,
#    'XPForNextLevel': 13020,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 1987,
#    'magicResist': 85,
#    'ability3CooldownRemaining': 7.938232421875,
#    'ability3Level': 2,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'S12_SummonerTeleportUpgrade',
#    'teamID': 200,
#    'currentGold': 1463,
#    'healthRegen': 117,
#    'ability4Level': 1,
#    'level': 14,
#    'ability1Level': 6,
#    'armorPenetration': 0,
#    'accountID': 2383216168420736,
#    'ability2Level': 6,
#    'health': 1740,
#    'ultimateName': 'JayceStanceGtH',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 52,
#     'shutdownReward': 50,
#     'misc': 650,
#     'killStructure': 816,
#     'killMinion': 4084,
#     'killChampion': 700,
#     'ambient': 2164,
#     'starting': 500},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 1741, 'x': 7960},
#    'primaryAbilityResourceMax': 1896,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'JayceHyperCharge',
#    'attackDamage': 301,
#    'ability3Name': 'JayceAccelerationGate',
#    'championName': 'Jayce',
#    'ccReduction': 30,
#    'shutdownValue': 250,
#    'playerName': 'C9 EMENES',
#    'respawnTimer': 0,
#    'attackSpeed': 136,
#    'XP': 11677,
#    'ultimateCooldownRemaining': 0,
#    'stackingBuffs': [{'stacks': 76, 'id': 2609129978}],
#    'armor': 89,
#    'summonerSpell1CooldownRemaining': 81.89501953125,
#    'ability1Name': 'JayceShockBlast',
#    'totalGold': 9018,
#    'items': [{'itemID': 3142, 'itemCooldown': 0},
#     {'itemID': 2031, 'itemCooldown': 0},
#     {'itemID': 1054, 'itemCooldown': 0},
#     {'itemID': 3004, 'itemStacks': 357, 'itemCooldown': 0},
#     {'itemID': 3111, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 29.9625244140625}],
#    'abilityPower': 0,
#    'ability4Name': 'JayceStanceGtH',
#    'stats': [{'value': 207, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 2, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 0, 'name': 'NUM_DEATHS'},
#     {'value': 1, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 7, 'name': 'WARD_PLACED'},
#     {'value': 8, 'name': 'WARD_KILLED'},
#     {'value': 20.586578369140625, 'name': 'VISION_SCORE'},
#     {'value': 106475.4609375, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 99756.5546875, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 4522.50146484375, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 2196.38623046875, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 8653.263671875, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 7054.49853515625, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 1141.271484375, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 457.4927978515625, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 4276.6484375, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 1906.65673828125, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 2369.990966796875, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 2907.82080078125, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 3078.81005859375, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 3078.81005859375, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 7207.4990234375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 57.754425048828125, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 12.2430419921875,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 2.699249267578125, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 11, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 8, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 17, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 8, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 3, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 2, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 557,
#    'spellVamp': 0,
#    'participantID': 9,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 66,
#    'ability1CooldownRemaining': 0,
#    'XPForNextLevel': 8580,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 1895,
#    'magicResist': 44,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 3,
#    'ability2CooldownRemaining': 4.5958251953125,
#    'summonerSpell1Name': 'SummonerBoost',
#    'teamID': 200,
#    'currentGold': 692,
#    'healthRegen': 18,
#    'ability4Level': 2,
#    'level': 11,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2615481136170368,
#    'ability2Level': 1,
#    'health': 1895,
#    'ultimateName': 'ZeriR',
#    'summonerSpell2Name': 'SummonerFlash',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 230,
#     'killPalisade': 87,
#     'misc': 245,
#     'killStructure': 416,
#     'killMinion': 4179,
#     'killChampion': 300,
#     'ambient': 2164,
#     'starting': 500},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 18,
#    'position': {'z': 3943, 'x': 6949},
#    'primaryAbilityResourceMax': 644,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'ZeriW',
#    'attackDamage': 114,
#    'ability3Name': 'ZeriE',
#    'championName': 'Zeri',
#    'ccReduction': 0,
#    'shutdownValue': 100,
#    'playerName': 'C9 Berserker',
#    'respawnTimer': 0,
#    'attackSpeed': 170,
#    'XP': 7352,
#    'ultimateCooldownRemaining': 0,
#    'stackingBuffs': [{'stacks': 100, 'id': 3290852513}],
#    'armor': 72,
#    'summonerSpell1CooldownRemaining': 0,
#    'ability1Name': 'ZeriQ',
#    'totalGold': 8172,
#    'items': [{'itemID': 2031, 'itemStacks': 2, 'itemCooldown': 0},
#     {'itemID': 4636, 'itemCooldown': 0},
#     {'itemID': 3020, 'itemCooldown': 0},
#     {'itemID': 3087, 'itemCooldown': 0},
#     {'itemID': 3363, 'itemCooldown': 0}],
#    'abilityPower': 103,
#    'ability4Name': 'ZeriR',
#    'stats': [{'value': 212, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 1, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 0, 'name': 'NUM_DEATHS'},
#     {'value': 3, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 9, 'name': 'WARD_PLACED'},
#     {'value': 11, 'name': 'WARD_KILLED'},
#     {'value': 34.76461410522461, 'name': 'VISION_SCORE'},
#     {'value': 108010.5703125, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 37843.27734375, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 63842.65625, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 6324.8984375, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 6955.68310546875, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 2414.210205078125, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 4515.01513671875, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 26.45995330810547, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 2588.780029296875, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 2330.13818359375, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 258.642333984375, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 1404.7421875, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 2620.313232421875, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 2620.313232421875, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 4332.77734375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 28.847320556640625, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 7.47161865234375,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 1.3679701089859009, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 12, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 3, 'name': 'GET_BACK_PINGS'},
#     {'value': 0, 'name': 'RETREAT_PINGS'},
#     {'value': 15, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 0, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 3, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 1, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 7, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 0},
#   {'ability4CooldownRemaining': 0,
#    'magicPenetrationPercent': 0,
#    'alive': True,
#    'primaryAbilityResource': 955,
#    'spellVamp': 0,
#    'participantID': 10,
#    'lifeSteal': 0,
#    'primaryAbilityResourceRegen': 91,
#    'ability1CooldownRemaining': 1.8475341796875,
#    'XPForNextLevel': 7300,
#    'summonerSpell2CooldownRemaining': 0,
#    'healthMax': 1254,
#    'magicResist': 36,
#    'ability3CooldownRemaining': 0,
#    'ability3Level': 4,
#    'ability2CooldownRemaining': 0,
#    'summonerSpell1Name': 'SummonerHeal',
#    'teamID': 200,
#    'currentGold': 616,
#    'healthRegen': 18,
#    'ability4Level': 1,
#    'level': 10,
#    'ability1Level': 5,
#    'armorPenetration': 0,
#    'accountID': 2382277312029984,
#    'ability2Level': 1,
#    'health': 1254,
#    'ultimateName': 'YuumiR',
#    'summonerSpell2Name': 'SummonerExhaust',
#    'cooldownReduction': 0,
#    'goldStats': {'assist': 142,
#     'killPalisade': 262,
#     'killMinion': 21,
#     'killStructure': 416,
#     'misc': 170,
#     'itemSold': 20,
#     'killChampion': 600,
#     'supportItem': 680,
#     'ambient': 2438,
#     'starting': 500},
#    'magicPenetrationPercentBonus': 0,
#    'magicPenetration': 0,
#    'position': {'z': 3943, 'x': 6949},
#    'primaryAbilityResourceMax': 1038,
#    'armorPenetrationPercentBonus': 0,
#    'armorPenetrationPercent': 0,
#    'ability2Name': 'YuumiWEndWrapper',
#    'attackDamage': 76,
#    'ability3Name': 'YuumiE',
#    'championName': 'Yuumi',
#    'ccReduction': 0,
#    'shutdownValue': 150,
#    'playerName': 'C9 Zven',
#    'respawnTimer': 0,
#    'attackSpeed': 107,
#    'XP': 6884,
#    'ultimateCooldownRemaining': 0,
#    'stackingBuffs': [{'stacks': 2, 'id': 3810510983},
#     {'stacks': 954, 'id': 4124813883}],
#    'armor': 68,
#    'summonerSpell1CooldownRemaining': 0,
#    'ability1Name': 'YuumiQ',
#    'totalGold': 5281,
#    'items': [{'itemID': 1028, 'itemCooldown': 0},
#     {'itemID': 4005, 'itemCooldown': 0},
#     {'itemID': 1004, 'itemCooldown': 0},
#     {'itemID': 3851, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 2055, 'itemStacks': 1, 'itemCooldown': 0},
#     {'itemID': 4642, 'itemCooldown': 0},
#     {'itemID': 3364, 'itemStacks': 1, 'itemCooldown': 0}],
#    'abilityPower': 121,
#    'ability4Name': 'YuumiR',
#    'stats': [{'value': 3, 'name': 'MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#     {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#     {'value': 2, 'name': 'CHAMPIONS_KILLED'},
#     {'value': 0, 'name': 'NUM_DEATHS'},
#     {'value': 2, 'name': 'ASSISTS'},
#     {'value': 0, 'name': 'PERK0'},
#     {'value': 0, 'name': 'PERK0_VAR1'},
#     {'value': 0, 'name': 'PERK0_VAR2'},
#     {'value': 0, 'name': 'PERK0_VAR3'},
#     {'value': 0, 'name': 'PERK1'},
#     {'value': 0, 'name': 'PERK1_VAR1'},
#     {'value': 0, 'name': 'PERK1_VAR2'},
#     {'value': 0, 'name': 'PERK1_VAR3'},
#     {'value': 0, 'name': 'PERK2'},
#     {'value': 0, 'name': 'PERK2_VAR1'},
#     {'value': 0, 'name': 'PERK2_VAR2'},
#     {'value': 0, 'name': 'PERK2_VAR3'},
#     {'value': 0, 'name': 'PERK3'},
#     {'value': 0, 'name': 'PERK3_VAR1'},
#     {'value': 0, 'name': 'PERK3_VAR2'},
#     {'value': 0, 'name': 'PERK3_VAR3'},
#     {'value': 0, 'name': 'PERK4'},
#     {'value': 0, 'name': 'PERK4_VAR1'},
#     {'value': 0, 'name': 'PERK4_VAR2'},
#     {'value': 0, 'name': 'PERK4_VAR3'},
#     {'value': 0, 'name': 'PERK5'},
#     {'value': 0, 'name': 'PERK5_VAR1'},
#     {'value': 0, 'name': 'PERK5_VAR2'},
#     {'value': 0, 'name': 'PERK5_VAR3'},
#     {'value': 20, 'name': 'WARD_PLACED'},
#     {'value': 2, 'name': 'WARD_KILLED'},
#     {'value': 34.48716735839844, 'name': 'VISION_SCORE'},
#     {'value': 5768.42822265625, 'name': 'TOTAL_DAMAGE_DEALT'},
#     {'value': 572.8134155273438, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#     {'value': 5195.615234375, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#     {'value': 2817.63134765625, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 223.041015625, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 2594.59033203125, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#     {'value': 777.9525146484375, 'name': 'TOTAL_DAMAGE_TAKEN'},
#     {'value': 678.851806640625, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#     {'value': 99.10064697265625, 'name': 'MAGIC_DAMAGE_TAKEN'},
#     {'value': 0, 'name': 'TRUE_DAMAGE_TAKEN'},
#     {'value': 381.05999755859375, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#     {'value': 749.0155029296875, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#     {'value': 923.3621826171875, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#     {'value': 923.3621826171875, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#     {'value': 1051.0408935546875, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#     {'value': 78.76849365234375, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#     {'value': 73.90643310546875,
#      'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#     {'value': 494.76007080078125, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#     {'value': 7.7596893310546875, 'name': 'TIME_CCING_OTHERS'},
#     {'value': 0, 'name': 'BASIC_PINGS'},
#     {'value': 7, 'name': 'COMMAND_PINGS'},
#     {'value': 0, 'name': 'DANGER_PINGS'},
#     {'value': 1, 'name': 'GET_BACK_PINGS'},
#     {'value': 5, 'name': 'RETREAT_PINGS'},
#     {'value': 20, 'name': 'ON_MY_WAY_PINGS'},
#     {'value': 0, 'name': 'ASSIST_ME_PINGS'},
#     {'value': 3, 'name': 'ENEMY_MISSING_PINGS'},
#     {'value': 0, 'name': 'PUSH_PINGS'},
#     {'value': 0, 'name': 'ALL_IN_PINGS'},
#     {'value': 0, 'name': 'HOLD_PINGS'},
#     {'value': 0, 'name': 'BAIT_PINGS'},
#     {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#     {'value': 15, 'name': 'ENEMY_VISION_PINGS'},
#     {'value': 1, 'name': 'NEED_VISION_PINGS'}],
#    'goldPerSecond': 30}],
#  'gameName': '110303581088069312|game1',
#  'sequenceIndex': 4026,
#  'teams': [{'inhibKills': 0,
#    'towerKills': 0,
#    'teamID': 100,
#    'baronKills': 0,
#    'dragonKills': 0,
#    'assists': 3,
#    'championsKills': 1,
#    'totalGold': 31061,
#    'deaths': 5},
#   {'inhibKills': 0,
#    'towerKills': 3,
#    'teamID': 200,
#    'baronKills': 0,
#    'dragonKills': 2,
#    'assists': 12,
#    'championsKills': 5,
#    'totalGold': 36237,
#    'deaths': 1}],
#  'gameOver': False,
#  'playbackID': 1}

# %%
participant_data
# Out:
# {'ability4CooldownRemaining': 0,
#  'magicPenetrationPercent': 0,
#  'alive': True,
#  'primaryAbilityResource': 699,
#  'spellVamp': 0,
#  'participantID': 1,
#  'lifeSteal': 0,
#  'primaryAbilityResourceRegen': 27,
#  'ability1CooldownRemaining': 2.568115234375,
#  'XPForNextLevel': 9960,
#  'summonerSpell2CooldownRemaining': 0,
#  'healthMax': 3191,
#  'magicResist': 77,
#  'ability3CooldownRemaining': 0.8946533203125,
#  'ability3Level': 1,
#  'ability2CooldownRemaining': 10.202392578125,
#  'summonerSpell1Name': 'S12_SummonerTeleportUpgrade',
#  'teamID': 100,
#  'currentGold': 780,
#  'healthRegen': 38,
#  'ability4Level': 2,
#  'level': 12,
#  'ability1Level': 5,
#  'armorPenetration': 0,
#  'accountID': 2382277692401216,
#  'ability2Level': 4,
#  'health': 2260,
#  'ultimateName': 'SionR',
#  'summonerSpell2Name': 'SummonerFlash',
#  'cooldownReduction': 0,
#  'goldStats': {'assist': 20,
#   'killPalisade': 350,
#   'misc': 45,
#   'itemSold': 5,
#   'killMinion': 3201,
#   'starting': 500,
#   'ambient': 2164},
#  'magicPenetrationPercentBonus': 0,
#  'magicPenetration': 0,
#  'position': {'z': 1159, 'x': 6195},
#  'primaryAbilityResourceMax': 1031,
#  'armorPenetrationPercentBonus': 0,
#  'armorPenetrationPercent': 0,
#  'ability2Name': 'SionW',
#  'attackDamage': 107,
#  'ability3Name': 'SionE',
#  'championName': 'Sion',
#  'ccReduction': 0,
#  'shutdownValue': 0,
#  'playerName': '100 Ssumday',
#  'respawnTimer': 0,
#  'attackSpeed': 122,
#  'XP': 9266,
#  'ultimateCooldownRemaining': 0,
#  'stackingBuffs': [{'stacks': 707, 'id': 1911847746},
#   {'stacks': 3, 'id': 968555378}],
#  'armor': 155,
#  'summonerSpell1CooldownRemaining': 0,
#  'ability1Name': 'SionQ',
#  'totalGold': 6280,
#  'items': [{'itemID': 3047, 'itemCooldown': 0},
#   {'itemID': 2031, 'itemCooldown': 0},
#   {'itemID': 1028, 'itemCooldown': 0},
#   {'itemID': 3068, 'itemStacks': 43, 'itemCooldown': 0},
#   {'itemID': 1033, 'itemCooldown': 0},
#   {'itemID': 1054, 'itemCooldown': 0},
#   {'itemID': 3363, 'itemCooldown': 19.9539794921875}],
#  'abilityPower': 0,
#  'ability4Name': 'SionR',
#  'stats': [{'value': 155, 'name': 'MINIONS_KILLED'},
#   {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED'},
#   {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE'},
#   {'value': 0, 'name': 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'},
#   {'value': 0, 'name': 'CHAMPIONS_KILLED'},
#   {'value': 1, 'name': 'NUM_DEATHS'},
#   {'value': 0, 'name': 'ASSISTS'},
#   {'value': 0, 'name': 'PERK0'},
#   {'value': 0, 'name': 'PERK0_VAR1'},
#   {'value': 0, 'name': 'PERK0_VAR2'},
#   {'value': 0, 'name': 'PERK0_VAR3'},
#   {'value': 0, 'name': 'PERK1'},
#   {'value': 0, 'name': 'PERK1_VAR1'},
#   {'value': 0, 'name': 'PERK1_VAR2'},
#   {'value': 0, 'name': 'PERK1_VAR3'},
#   {'value': 0, 'name': 'PERK2'},
#   {'value': 0, 'name': 'PERK2_VAR1'},
#   {'value': 0, 'name': 'PERK2_VAR2'},
#   {'value': 0, 'name': 'PERK2_VAR3'},
#   {'value': 0, 'name': 'PERK3'},
#   {'value': 0, 'name': 'PERK3_VAR1'},
#   {'value': 0, 'name': 'PERK3_VAR2'},
#   {'value': 0, 'name': 'PERK3_VAR3'},
#   {'value': 0, 'name': 'PERK4'},
#   {'value': 0, 'name': 'PERK4_VAR1'},
#   {'value': 0, 'name': 'PERK4_VAR2'},
#   {'value': 0, 'name': 'PERK4_VAR3'},
#   {'value': 0, 'name': 'PERK5'},
#   {'value': 0, 'name': 'PERK5_VAR1'},
#   {'value': 0, 'name': 'PERK5_VAR2'},
#   {'value': 0, 'name': 'PERK5_VAR3'},
#   {'value': 8, 'name': 'WARD_PLACED'},
#   {'value': 2, 'name': 'WARD_KILLED'},
#   {'value': 16.944278717041016, 'name': 'VISION_SCORE'},
#   {'value': 72929.0546875, 'name': 'TOTAL_DAMAGE_DEALT'},
#   {'value': 50844.7890625, 'name': 'PHYSICAL_DAMAGE_DEALT_PLAYER'},
#   {'value': 22083.263671875, 'name': 'MAGIC_DAMAGE_DEALT_PLAYER'},
#   {'value': 1, 'name': 'TRUE_DAMAGE_DEALT_PLAYER'},
#   {'value': 4208.474609375, 'name': 'TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#   {'value': 2039.4429931640625, 'name': 'PHYSICAL_DAMAGE_DEALT_TO_CHAMPIONS'},
#   {'value': 2168.03173828125, 'name': 'MAGIC_DAMAGE_DEALT_TO_CHAMPIONS'},
#   {'value': 1, 'name': 'TRUE_DAMAGE_DEALT_TO_CHAMPIONS'},
#   {'value': 11425.681640625, 'name': 'TOTAL_DAMAGE_TAKEN'},
#   {'value': 7993.54052734375, 'name': 'PHYSICAL_DAMAGE_TAKEN'},
#   {'value': 3137.671875, 'name': 'MAGIC_DAMAGE_TAKEN'},
#   {'value': 294.4728698730469, 'name': 'TRUE_DAMAGE_TAKEN'},
#   {'value': 16499.1171875, 'name': 'TOTAL_DAMAGE_SELF_MITIGATED'},
#   {'value': 0, 'name': 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES'},
#   {'value': 2372.916259765625, 'name': 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS'},
#   {'value': 2372.916259765625, 'name': 'TOTAL_DAMAGE_DEALT_TO_TURRETS'},
#   {'value': 2927.5458984375, 'name': 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'},
#   {'value': 299.9603271484375, 'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT'},
#   {'value': 42.69746398925781,
#    'name': 'TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS'},
#   {'value': 0, 'name': 'TOTAL_HEAL_ON_TEAMMATES'},
#   {'value': 11.659530639648438, 'name': 'TIME_CCING_OTHERS'},
#   {'value': 0, 'name': 'BASIC_PINGS'},
#   {'value': 25, 'name': 'COMMAND_PINGS'},
#   {'value': 0, 'name': 'DANGER_PINGS'},
#   {'value': 4, 'name': 'GET_BACK_PINGS'},
#   {'value': 0, 'name': 'RETREAT_PINGS'},
#   {'value': 3, 'name': 'ON_MY_WAY_PINGS'},
#   {'value': 0, 'name': 'ASSIST_ME_PINGS'},
#   {'value': 2, 'name': 'ENEMY_MISSING_PINGS'},
#   {'value': 0, 'name': 'PUSH_PINGS'},
#   {'value': 0, 'name': 'ALL_IN_PINGS'},
#   {'value': 0, 'name': 'HOLD_PINGS'},
#   {'value': 0, 'name': 'BAIT_PINGS'},
#   {'value': 0, 'name': 'VISION_CLEARED_PINGS'},
#   {'value': 0, 'name': 'ENEMY_VISION_PINGS'},
#   {'value': 0, 'name': 'NEED_VISION_PINGS'}],
#  'goldPerSecond': 0}

# %%
individual_stats = []
for participant_data in event['participants']:
    individual_stats.append(extract_participant_stats(participant_data))

# Convert the list of dictionaries into a single dataframe and ensure that it's sorted by partipant_id when evaluated as a number
frame_stats = pd.DataFrame.from_dict(individual_stats).sort_values(by=['participant_id'], key=lambda x: x.astype(int))

# Add the time column
event_time = 600
frame_stats['event_time'] = event_time

frame_stats_100 = frame_stats[frame_stats['team_id'] == '100']
frame_stats_100 = create_participant_features(frame_stats[frame_stats['team_id'] == '100'])
frame_stats_200 = frame_stats[frame_stats['team_id'] == '200']
frame_stats_200 = create_participant_features(frame_stats[frame_stats['team_id'] == '200'])

frame_stats = pd.concat([frame_stats_100, frame_stats_200])
# Get the team features
team_features_stats = create_team_features(frame_stats, event)
# Get the lane difference features 
frame_stats = create_diff_features(frame_stats)

# Lastly turn these into per-player features by splitting again by team_id, pivoting on participant_id, and then joining back together
frame_stats_100 = frame_stats[frame_stats['team_id'] == '100'].drop('team_id',axis=1)
frame_stats_200 = frame_stats[frame_stats['team_id'] == '200'].drop('team_id',axis=1)

# Pivot and convert to dictionary format 
frame_stats_100 = melt_frame_stats(frame_stats_100)
frame_stats_100 = {x:y for x, y in zip(frame_stats_100.columns.values, frame_stats_100.values[0])}
all_stats_100 = {**team_features_stats['100'], **frame_stats_100}
all_stats_100 = {x + f'_at_{event_time/60.0}': y for x, y in all_stats_100.items()}

frame_stats_200 = melt_frame_stats(frame_stats_200)
frame_stats_200 = {x:y for x, y in zip(frame_stats_200.columns.values, frame_stats_200.values[0])}
all_stats_200 = {**team_features_stats['200'], **frame_stats_200}
all_stats_200 = {x + f'_at_{event_time/60.0}': y for x, y in all_stats_200.items()}
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['KDA'] = (frame_stats['CHAMPIONS_KILLED'] + frame_stats['ASSISTS']) / (frame_stats['NUM_DEATHS'] + 1.0)
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['cs_per_min'] = (frame_stats['MINIONS_KILLED'] + frame_stats['NEUTRAL_MINIONS_KILLED']) / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['xp_per_min'] = frame_stats['XP'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['gold_per_min'] = frame_stats['totalGold'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['vision_per_min'] = frame_stats['VISION_SCORE'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['wards_per_min'] = (frame_stats['WARD_PLACED'] + frame_stats['WARD_KILLED']) / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['trade_efficiency'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / (frame_stats['TOTAL_DAMAGE_TAKEN'] + 1.0)  # Higher for poke-heavy champions
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['damage_to_champions_per_min'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['damage_to_buildings_per_min'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['gold_spent'] = frame_stats['totalGold'] - frame_stats['currentGold']
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_minions_stolen'] = frame_stats['NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'] / (frame_stats['NEUTRAL_MINIONS_KILLED'] + 1.0)
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_gold'] = frame_stats['totalGold'] / frame_stats['totalGold'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_xp'] = frame_stats['XP'] / frame_stats['XP'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_damage_to_champions'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_damage_to_buildings'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_damage_to_objectives'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['KDA'] = (frame_stats['CHAMPIONS_KILLED'] + frame_stats['ASSISTS']) / (frame_stats['NUM_DEATHS'] + 1.0)
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['cs_per_min'] = (frame_stats['MINIONS_KILLED'] + frame_stats['NEUTRAL_MINIONS_KILLED']) / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['xp_per_min'] = frame_stats['XP'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['gold_per_min'] = frame_stats['totalGold'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['vision_per_min'] = frame_stats['VISION_SCORE'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['wards_per_min'] = (frame_stats['WARD_PLACED'] + frame_stats['WARD_KILLED']) / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['trade_efficiency'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / (frame_stats['TOTAL_DAMAGE_TAKEN'] + 1.0)  # Higher for poke-heavy champions
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['damage_to_champions_per_min'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['damage_to_buildings_per_min'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'] / num_minutes
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['gold_spent'] = frame_stats['totalGold'] - frame_stats['currentGold']
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_minions_stolen'] = frame_stats['NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'] / (frame_stats['NEUTRAL_MINIONS_KILLED'] + 1.0)
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_gold'] = frame_stats['totalGold'] / frame_stats['totalGold'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_xp'] = frame_stats['XP'] / frame_stats['XP'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_damage_to_champions'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_damage_to_buildings'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'].sum()
# C:\Users\brian\AppData\Local\Temp\ipykernel_2768\2373307094.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame_stats['share_of_team_damage_to_objectives'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'].sum()

# %%
all_stats_100
# Out:
# {'team_share_of_inhibKills_at_10.0': 0.5,
#  'team_share_of_towerKills_at_10.0': 0.0,
#  'team_share_of_baronKills_at_10.0': 0.5,
#  'team_share_of_dragonKills_at_10.0': 0.0,
#  'team_share_of_assists_at_10.0': 0.2,
#  'team_share_of_championsKills_at_10.0': 0.16666666666666666,
#  'team_share_of_totalGold_at_10.0': 0.46154417664715147,
#  'team_share_of_deaths_at_10.0': 0.8333333333333334,
#  'team_share_of_MINIONS_KILLED_at_10.0': 0.4876805437553101,
#  'team_share_of_NEUTRAL_MINIONS_KILLED_at_10.0': 0.4531249948777269,
#  'team_share_of_VISION_SCORE_at_10.0': 0.453499424082263,
#  'top_XP_at_10.0': 9266.0,
#  'jungle_XP_at_10.0': 7207.0,
#  'mid_XP_at_10.0': 9708.0,
#  'bot_XP_at_10.0': 7765.0,
#  'support_XP_at_10.0': 5107.0,
#  'top_totalGold_at_10.0': 6280.0,
#  'jungle_totalGold_at_10.0': 6138.0,
#  'mid_totalGold_at_10.0': 6845.0,
#  'bot_totalGold_at_10.0': 7648.0,
#  'support_totalGold_at_10.0': 4150.0,
#  'top_currentGold_at_10.0': 780.0,
#  'jungle_currentGold_at_10.0': 948.0,
#  'mid_currentGold_at_10.0': 710.0,
#  'bot_currentGold_at_10.0': 833.0,
#  'support_currentGold_at_10.0': 325.0,
#  'top_MINIONS_KILLED_at_10.0': 155.0,
#  'jungle_MINIONS_KILLED_at_10.0': 7.0,
#  'mid_MINIONS_KILLED_at_10.0': 178.0,
#  'bot_MINIONS_KILLED_at_10.0': 206.0,
#  'support_MINIONS_KILLED_at_10.0': 28.0,
#  'top_NEUTRAL_MINIONS_KILLED_at_10.0': 0.0,
#  'jungle_NEUTRAL_MINIONS_KILLED_at_10.0': 116.0000228881836,
#  'mid_NEUTRAL_MINIONS_KILLED_at_10.0': 0.0,
#  'bot_NEUTRAL_MINIONS_KILLED_at_10.0': 0.0,
#  'support_NEUTRAL_MINIONS_KILLED_at_10.0': 0.0,
#  'top_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_10.0': 0.0,
#  'jungle_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_10.0': 94.0000228881836,
#  'mid_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_10.0': 0.0,
#  'bot_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_10.0': 0.0,
#  'support_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_10.0': 0.0,
#  'top_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_10.0': 0.0,
#  'jungle_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_10.0': 2.5,
#  'mid_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_10.0': 0.0,
#  'bot_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_10.0': 0.0,
#  'support_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_10.0': 0.0,
#  'top_CHAMPIONS_KILLED_at_10.0': 0.0,
#  'jungle_CHAMPIONS_KILLED_at_10.0': 0.0,
#  'mid_CHAMPIONS_KILLED_at_10.0': 1.0,
#  'bot_CHAMPIONS_KILLED_at_10.0': 0.0,
#  'support_CHAMPIONS_KILLED_at_10.0': 0.0,
#  'top_NUM_DEATHS_at_10.0': 1.0,
#  'jungle_NUM_DEATHS_at_10.0': 1.0,
#  'mid_NUM_DEATHS_at_10.0': 2.0,
#  'bot_NUM_DEATHS_at_10.0': 0.0,
#  'support_NUM_DEATHS_at_10.0': 1.0,
#  'top_ASSISTS_at_10.0': 0.0,
#  'jungle_ASSISTS_at_10.0': 1.0,
#  'mid_ASSISTS_at_10.0': 0.0,
#  'bot_ASSISTS_at_10.0': 1.0,
#  'support_ASSISTS_at_10.0': 1.0,
#  'top_WARD_PLACED_at_10.0': 8.0,
#  'jungle_WARD_PLACED_at_10.0': 5.0,
#  'mid_WARD_PLACED_at_10.0': 10.0,
#  'bot_WARD_PLACED_at_10.0': 9.0,
#  'support_WARD_PLACED_at_10.0': 27.0,
#  'top_WARD_KILLED_at_10.0': 2.0,
#  'jungle_WARD_KILLED_at_10.0': 5.0,
#  'mid_WARD_KILLED_at_10.0': 2.0,
#  'bot_WARD_KILLED_at_10.0': 6.0,
#  'support_WARD_KILLED_at_10.0': 5.0,
#  'top_VISION_SCORE_at_10.0': 16.944278717041016,
#  'jungle_VISION_SCORE_at_10.0': 18.542064666748047,
#  'mid_VISION_SCORE_at_10.0': 13.898396492004395,
#  'bot_VISION_SCORE_at_10.0': 22.01340103149414,
#  'support_VISION_SCORE_at_10.0': 44.823692321777344,
#  'top_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_10.0': 4208.474609375,
#  'jungle_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_10.0': 1537.889892578125,
#  'mid_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_10.0': 4621.33251953125,
#  'bot_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_10.0': 3400.347412109375,
#  'support_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_10.0': 590.8165283203125,
#  'top_TOTAL_DAMAGE_TAKEN_at_10.0': 11425.681640625,
#  'jungle_TOTAL_DAMAGE_TAKEN_at_10.0': 14318.3955078125,
#  'mid_TOTAL_DAMAGE_TAKEN_at_10.0': 6492.63525390625,
#  'bot_TOTAL_DAMAGE_TAKEN_at_10.0': 4414.96337890625,
#  'support_TOTAL_DAMAGE_TAKEN_at_10.0': 4018.471923828125,
#  'top_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_10.0': 2372.916259765625,
#  'jungle_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_10.0': 0.0,
#  'mid_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_10.0': 282.1368713378906,
#  'bot_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_10.0': 680.0380249023438,
#  'support_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_10.0': 0.0,
#  'top_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_10.0': 2927.5458984375,
#  'jungle_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_10.0': 10505.603515625,
#  'mid_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_10.0': 282.1368713378906,
#  'bot_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_10.0': 1645.9287109375,
#  'support_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_10.0': 64.0769271850586,
#  'top_event_time_at_10.0': 600.0,
#  'jungle_event_time_at_10.0': 600.0,
#  'mid_event_time_at_10.0': 600.0,
#  'bot_event_time_at_10.0': 600.0,
#  'support_event_time_at_10.0': 600.0,
#  'top_KDA_at_10.0': 0.0,
#  'jungle_KDA_at_10.0': 0.5,
#  'mid_KDA_at_10.0': 0.3333333333333333,
#  'bot_KDA_at_10.0': 1.0,
#  'support_KDA_at_10.0': 0.5,
#  'top_cs_per_min_at_10.0': 15.5,
#  'jungle_cs_per_min_at_10.0': 12.300002288818359,
#  'mid_cs_per_min_at_10.0': 17.8,
#  'bot_cs_per_min_at_10.0': 20.6,
#  'support_cs_per_min_at_10.0': 2.8,
#  'top_xp_per_min_at_10.0': 926.6,
#  'jungle_xp_per_min_at_10.0': 720.7,
#  'mid_xp_per_min_at_10.0': 970.8,
#  'bot_xp_per_min_at_10.0': 776.5,
#  'support_xp_per_min_at_10.0': 510.7,
#  'top_gold_per_min_at_10.0': 628.0,
#  'jungle_gold_per_min_at_10.0': 613.8,
#  'mid_gold_per_min_at_10.0': 684.5,
#  'bot_gold_per_min_at_10.0': 764.8,
#  'support_gold_per_min_at_10.0': 415.0,
#  'top_vision_per_min_at_10.0': 1.6944278717041015,
#  'jungle_vision_per_min_at_10.0': 1.8542064666748046,
#  'mid_vision_per_min_at_10.0': 1.3898396492004395,
#  'bot_vision_per_min_at_10.0': 2.201340103149414,
#  'support_vision_per_min_at_10.0': 4.482369232177734,
#  'top_wards_per_min_at_10.0': 1.0,
#  'jungle_wards_per_min_at_10.0': 1.0,
#  'mid_wards_per_min_at_10.0': 1.2,
#  'bot_wards_per_min_at_10.0': 1.5,
#  'support_wards_per_min_at_10.0': 3.2,
#  'top_trade_efficiency_at_10.0': 0.36830242950085473,
#  'jungle_trade_efficiency_at_10.0': 0.10739907922363551,
#  'mid_trade_efficiency_at_10.0': 0.7116710962093666,
#  'bot_trade_efficiency_at_10.0': 0.7700125930282457,
#  'support_trade_efficiency_at_10.0': 0.1469885944016302,
#  'top_damage_to_champions_per_min_at_10.0': 420.8474609375,
#  'jungle_damage_to_champions_per_min_at_10.0': 153.7889892578125,
#  'mid_damage_to_champions_per_min_at_10.0': 462.133251953125,
#  'bot_damage_to_champions_per_min_at_10.0': 340.0347412109375,
#  'support_damage_to_champions_per_min_at_10.0': 59.08165283203125,
#  'top_damage_to_buildings_per_min_at_10.0': 237.2916259765625,
#  'jungle_damage_to_buildings_per_min_at_10.0': 0.0,
#  'mid_damage_to_buildings_per_min_at_10.0': 28.213687133789062,
#  'bot_damage_to_buildings_per_min_at_10.0': 68.00380249023438,
#  'support_damage_to_buildings_per_min_at_10.0': 0.0,
#  'top_gold_spent_at_10.0': 5500.0,
#  'jungle_gold_spent_at_10.0': 5190.0,
#  'mid_gold_spent_at_10.0': 6135.0,
#  'bot_gold_spent_at_10.0': 6815.0,
#  'support_gold_spent_at_10.0': 3825.0,
#  'top_share_of_minions_stolen_at_10.0': 0.0,
#  'jungle_share_of_minions_stolen_at_10.0': 0.021367517187490116,
#  'mid_share_of_minions_stolen_at_10.0': 0.0,
#  'bot_share_of_minions_stolen_at_10.0': 0.0,
#  'support_share_of_minions_stolen_at_10.0': 0.0,
#  'top_share_of_team_gold_at_10.0': 0.20218280158397992,
#  'jungle_share_of_team_gold_at_10.0': 0.19761115224880074,
#  'mid_share_of_team_gold_at_10.0': 0.2203728147838125,
#  'bot_share_of_team_gold_at_10.0': 0.2462251698271144,
#  'support_share_of_team_gold_at_10.0': 0.13360806155629246,
#  'top_share_of_team_xp_at_10.0': 0.23726730340818888,
#  'jungle_share_of_team_xp_at_10.0': 0.1845440811205285,
#  'mid_share_of_team_xp_at_10.0': 0.24858525593424322,
#  'bot_share_of_team_xp_at_10.0': 0.19883235602898625,
#  'support_share_of_team_xp_at_10.0': 0.13077100350805315,
#  'top_share_of_team_damage_to_champions_at_10.0': 0.29309251064814285,
#  'jungle_share_of_team_damage_to_champions_at_10.0': 0.10710389192132141,
#  'mid_share_of_team_damage_to_champions_at_10.0': 0.32184534217505356,
#  'bot_share_of_team_damage_to_champions_at_10.0': 0.23681177923016133,
#  'support_share_of_team_damage_to_champions_at_10.0': 0.04114647602532085,
#  'top_share_of_team_damage_to_buildings_at_10.0': 0.711499670853811,
#  'jungle_share_of_team_damage_to_buildings_at_10.0': 0.0,
#  'mid_share_of_team_damage_to_buildings_at_10.0': 0.0845964497341598,
#  'bot_share_of_team_damage_to_buildings_at_10.0': 0.20390387941202917,
#  'support_share_of_team_damage_to_buildings_at_10.0': 0.0,
#  'top_share_of_team_damage_to_objectives_at_10.0': 0.18978868684962197,
#  'jungle_share_of_team_damage_to_objectives_at_10.0': 0.681063513592529,
#  'mid_share_of_team_damage_to_objectives_at_10.0': 0.01829053691409517,
#  'bot_share_of_team_damage_to_objectives_at_10.0': 0.1067032454943381,
#  'support_share_of_team_damage_to_objectives_at_10.0': 0.00415401714941575,
#  'top_KDA_diff_at_10.0': -1.0,
#  'jungle_KDA_diff_at_10.0': -3.5,
#  'mid_KDA_diff_at_10.0': -2.6666666666666665,
#  'bot_KDA_diff_at_10.0': -3.0,
#  'support_KDA_diff_at_10.0': -3.5,
#  'top_cs_per_min_diff_at_10.0': -1.3999999999999986,
#  'jungle_cs_per_min_diff_at_10.0': -2.900000762939454,
#  'mid_cs_per_min_diff_at_10.0': -2.8999999999999986,
#  'bot_cs_per_min_diff_at_10.0': -0.5999999999999979,
#  'support_cs_per_min_diff_at_10.0': 2.5,
#  'top_xp_per_min_diff_at_10.0': -11.799999999999955,
#  'jungle_xp_per_min_diff_at_10.0': -166.29999999999995,
#  'mid_xp_per_min_diff_at_10.0': -196.9000000000001,
#  'bot_xp_per_min_diff_at_10.0': 41.299999999999955,
#  'support_xp_per_min_diff_at_10.0': -177.7,
#  'top_gold_per_min_diff_at_10.0': -22.0,
#  'jungle_gold_per_min_diff_at_10.0': -112.80000000000007,
#  'mid_gold_per_min_diff_at_10.0': -217.29999999999995,
#  'bot_gold_per_min_diff_at_10.0': -52.40000000000009,
#  'support_gold_per_min_diff_at_10.0': -113.10000000000002,
#  'top_vision_per_min_diff_at_10.0': -0.0032796859741210938,
#  'jungle_vision_per_min_diff_at_10.0': -1.4698463439941407,
#  'mid_vision_per_min_diff_at_10.0': -0.6688181877136232,
#  'bot_vision_per_min_diff_at_10.0': -1.275121307373047,
#  'support_vision_per_min_diff_at_10.0': 1.0336524963378904,
#  'top_wards_per_min_diff_at_10.0': 0.0,
#  'jungle_wards_per_min_diff_at_10.0': -0.6000000000000001,
#  'mid_wards_per_min_diff_at_10.0': -0.30000000000000004,
#  'bot_wards_per_min_diff_at_10.0': -0.5,
#  'support_wards_per_min_diff_at_10.0': 1.0,
#  'top_trade_efficiency_diff_at_10.0': 0.05775025663735034,
#  'jungle_trade_efficiency_diff_at_10.0': -0.2526882566039463,
#  'mid_trade_efficiency_diff_at_10.0': -1.3112309253817895,
#  'bot_trade_efficiency_diff_at_10.0': -1.9158074483585192,
#  'support_trade_efficiency_diff_at_10.0': -3.4702169408137276,
#  'top_damage_to_champions_per_min_diff_at_10.0': 134.4012939453125,
#  'jungle_damage_to_champions_per_min_diff_at_10.0': -398.63122558593756,
#  'mid_damage_to_champions_per_min_diff_at_10.0': -403.19311523437494,
#  'bot_damage_to_champions_per_min_diff_at_10.0': -355.53356933593744,
#  'support_damage_to_champions_per_min_diff_at_10.0': -222.68148193359377,
#  'top_damage_to_buildings_per_min_diff_at_10.0': 237.2916259765625,
#  'jungle_damage_to_buildings_per_min_diff_at_10.0': 0.0,
#  'mid_damage_to_buildings_per_min_diff_at_10.0': -279.667318725586,
#  'bot_damage_to_buildings_per_min_diff_at_10.0': -194.02752075195315,
#  'support_damage_to_buildings_per_min_diff_at_10.0': -92.33621826171876,
#  'top_lane_cs_dominance_at_10.0': 0.4783950617283951,
#  'jungle_lane_cs_dominance_at_10.0': 0.44727272364088394,
#  'mid_lane_cs_dominance_at_10.0': 0.4623376623376624,
#  'bot_lane_cs_dominance_at_10.0': 0.4928229665071771,
#  'support_lane_cs_dominance_at_10.0': 0.903225806451613,
#  'top_lane_damage_to_champions_dominance_at_10.0': 0.5941708979757723,
#  'jungle_lane_damage_to_champions_dominance_at_10.0': 0.2174589758813812,
#  'mid_lane_damage_to_champions_dominance_at_10.0': 0.34787150869672434,
#  'bot_lane_damage_to_champions_dominance_at_10.0': 0.3280279183380041,
#  'support_lane_damage_to_champions_dominance_at_10.0': 0.17283180839828705,
#  'top_lane_damage_to_buildings_dominance_at_10.0': 0.9958034614271407,
#  'jungle_lane_damage_to_buildings_dominance_at_10.0': 0.0,
#  'mid_lane_damage_to_buildings_dominance_at_10.0': 0.0836966221071929,
#  'bot_lane_damage_to_buildings_dominance_at_10.0': 0.20542775435016025,
#  'support_lane_damage_to_buildings_dominance_at_10.0': 0.0}

# %%
team_features_stats
# Out:
# {'team_100': {'team_share_of_inhibKills': 0.5,
#   'team_share_of_towerKills': 0.0,
#   'team_share_of_baronKills': 0.5,
#   'team_share_of_dragonKills': 0.0,
#   'team_share_of_assists': 0.2,
#   'team_share_of_championsKills': 0.16666666666666666,
#   'team_share_of_totalGold': 0.46154417664715147,
#   'team_share_of_deaths': 0.8333333333333334,
#   'team_share_of_MINIONS_KILLED': 0.4876805437553101,
#   'team_share_of_NEUTRAL_MINIONS_KILLED': 0.4531249948777269,
#   'team_share_of_VISION_SCORE': 0.453499424082263},
#  'team_200': {'team_share_of_inhibKills': 0.5,
#   'team_share_of_towerKills': 1.0,
#   'team_share_of_baronKills': 0.5,
#   'team_share_of_dragonKills': 1.0,
#   'team_share_of_assists': 0.8,
#   'team_share_of_championsKills': 0.8333333333333334,
#   'team_share_of_totalGold': 0.5384558233528485,
#   'team_share_of_deaths': 0.16666666666666666,
#   'team_share_of_MINIONS_KILLED': 0.5123194562446899,
#   'team_share_of_NEUTRAL_MINIONS_KILLED': 0.546875005122273,
#   'team_share_of_VISION_SCORE': 0.546500575917737}}

# %%
from datetime import datetime
import pandas as pd
import numpy as np

class FrameFeaturesAtTimeGenerator:
    def __init__(self, event, event_time):
        self.event = event
        self.event_time = event_time  # Must be time in SECONDS, not minutes 
        
        self.team_features_from_event_data = ['inhibKills', 'towerKills', 'baronKills', 'dragonKills', 'assists', 'championsKills', 'totalGold', 'deaths']
        self.team_features_from_frame_stats = ['MINIONS_KILLED', 'NEUTRAL_MINIONS_KILLED', 'VISION_SCORE']
        self.participant_mapping = {
            '1': 'top',
            '2': 'jungle',
            '3': 'mid',
            '4': 'bot',
            '5': 'support',
            '6': 'top',
            '7': 'jungle',
            '8': 'mid',
            '9': 'bot',
            '10': 'support'
        }
        
    def extract_participant_stats(self, participant_data):
        """
        Extracts basic stats from participant data
        """
        participant_id = str(participant_data['participantID'])
        team_id = str(participant_data['teamID'])
        participant_stats_basic = {'XP': participant_data['XP'], 'totalGold': participant_data['totalGold'], 'currentGold':participant_data['currentGold']}
        participant_stats_frames = participant_data['stats']
        participant_stats_granular = self.extract_participants_granular_stats(participant_stats_frames)
        
        # Combine the basic and granular stats
        participant_stats = {'participant_id': participant_id, 'team_id': team_id, **participant_stats_basic, **participant_stats_granular}
        return participant_stats
        
    def extract_participants_granular_stats(self, stats_frames):
        """
        Extracts granular stats from participant data (e.g. minions killed, jungle minions killed, KDA, etc.)
        :param stats_frame: the 'stats' item from the 'status_update' event 
        :return: a dictionary of granular stats
        """
        stat_record = {}
        stats_to_record = {'MINIONS_KILLED', 'NEUTRAL_MINIONS_KILLED', 'NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE', 'NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE', 'CHAMPIONS_KILLED','NUM_DEATHS','ASSISTS',
                           'WARD_PLACED','WARD_KILLED','VISION_SCORE','TOTAL_DAMAGE_DEALT_TO_CHAMPIONS', 'TOTAL_DAMAGE_TAKEN', 'TOTAL_DAMAGE_DEALT_TO_BUILDINGS', 'TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'}
        # other stats to consider 
        # ['TOTAL_TIME_CROWD_CONTROL_DEALT_TO_CHAMPIONS', 'TOTAL_HEAL_ON_TEAMMATES', 'TOTAL_DAMAGE_SHIELDED_ON_TEAMMATES']
        for stat in stats_frames:
            stat_name = stat['name']
            if stat_name in stats_to_record:
                stat_record[stat_name] = stat['value']
        return stat_record
    
    # Now need to convert frame_stats into a single row of data for each team (100 and 200)
    def create_participant_features(self, frame_stats):
        """
        Creates higher-order features for each participant (e.g. KDA, minions killed, etc.) 
        :param frame_stats: a dataframe with stats for each participant for a single team at a single point in time
        :return: a dataframe with features for each participant
        """
        # Create features for each participant
        # For KDA, we need to add 0.1 to the denominator to avoid dividing by 0
        num_minutes = frame_stats['event_time'] / 60
        frame_stats['KDA'] = (frame_stats['CHAMPIONS_KILLED'] + frame_stats['ASSISTS']) / (frame_stats['NUM_DEATHS'] + 1.0)
        frame_stats['cs_per_min'] = (frame_stats['MINIONS_KILLED'] + frame_stats['NEUTRAL_MINIONS_KILLED']) / num_minutes
        frame_stats['xp_per_min'] = frame_stats['XP'] / num_minutes
        frame_stats['gold_per_min'] = frame_stats['totalGold'] / num_minutes
        frame_stats['vision_per_min'] = frame_stats['VISION_SCORE'] / num_minutes
        frame_stats['wards_per_min'] = (frame_stats['WARD_PLACED'] + frame_stats['WARD_KILLED']) / num_minutes
        frame_stats['trade_efficiency'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / (frame_stats['TOTAL_DAMAGE_TAKEN'] + 1.0)  # Higher for poke-heavy champions
        frame_stats['damage_to_champions_per_min'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / num_minutes
        frame_stats['damage_to_buildings_per_min'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'] / num_minutes
        frame_stats['gold_spent'] = frame_stats['totalGold'] - frame_stats['currentGold']
        frame_stats['share_of_minions_stolen'] = frame_stats['NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE'] / (frame_stats['NEUTRAL_MINIONS_KILLED'] + 1.0)
        frame_stats['share_of_team_gold'] = frame_stats['totalGold'] / frame_stats['totalGold'].sum()
        frame_stats['share_of_team_xp'] = frame_stats['XP'] / frame_stats['XP'].sum()
        frame_stats['share_of_team_damage_to_champions'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_CHAMPIONS'].sum()
        frame_stats['share_of_team_damage_to_buildings'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_BUILDINGS'].sum()
        frame_stats['share_of_team_damage_to_objectives'] = frame_stats['TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'] / frame_stats['TOTAL_DAMAGE_DEALT_TO_OBJECTIVES'].sum()
        return frame_stats
    
    
    def create_team_features(self, frame_stats, event_data):
        """
        Creates team-level features (e.g. total gold, total share of dragons/barons taken, etc.)
        :param frame_stats: A previously generated dataframe with features for each participant 
        :param event_data: The event data for the current event 
        :return: 
        """
        # Extract the team_features for each team based on event_data['teams'][i][feature]
        # Then compute the share of each feature for each team (whenever both features are zero, set the share to 0.5)
        # Then add the share of each feature to the frame_stats dataframe
        
        # First extract the team features from event_data
        team_features = {'100': {}, '200': {}}
        for team in event_data['teams']:
            team_id = str(team['teamID'])
            for feature in self.team_features_from_event_data:
                team_features[team_id][feature] = team[feature]
        
        # Compute the data for each team as the sum of the data for each participant on each team 
        for team in team_features:
            for feature in self.team_features_from_frame_stats:
                team_features[team][feature] = frame_stats[frame_stats['team_id'] == team][feature].sum()
        
        # Now compute the share of each feature for each team, setting the share to 0.5 if they are both 0
        for team in team_features:
            for feature in self.team_features_from_event_data + self.team_features_from_frame_stats:
                total_value = (team_features['100'][feature] + team_features['200'][feature])
                if total_value == 0:
                    team_features[team]['team_share_of_' + feature] = 0.5
                else:
                    team_features[team]['team_share_of_' + feature] = team_features[team][feature] / total_value
                    
        # Drop all features that are not 'share_of_' features
        for team in team_features:
            for feature in self.team_features_from_event_data + self.team_features_from_frame_stats:
                del team_features[team][feature]
        return team_features
                
    
    def create_diff_features(self, frame_stats):
        # Create features based on the difference between the player on the row and the player on the other team (row +5)
        # Do this for the first 5 players
        # For diff metrics, the value for the other team is the negative of the values for the first team 
        # For share metrics, the value for the other team is 1- the value for the first team
        
        # DIFF METRICS
        # Overall relative performance indicators 
        frame_stats['KDA_diff'] = (frame_stats['KDA'] - frame_stats['KDA'].shift(-5))  
        frame_stats['cs_per_min_diff'] = (frame_stats['cs_per_min'] - frame_stats['cs_per_min'].shift(-5))
        frame_stats['xp_per_min_diff'] = (frame_stats['xp_per_min'] - frame_stats['xp_per_min'].shift(-5))
        frame_stats['gold_per_min_diff'] = (frame_stats['gold_per_min'] - frame_stats['gold_per_min'].shift(-5))
        frame_stats['vision_per_min_diff'] = (frame_stats['vision_per_min'] - frame_stats['vision_per_min'].shift(-5))
        frame_stats['wards_per_min_diff'] = (frame_stats['wards_per_min'] - frame_stats['wards_per_min'].shift(-5))
        
        # Lane trade indicators
        frame_stats['trade_efficiency_diff'] = (frame_stats['trade_efficiency'] - frame_stats['trade_efficiency'].shift(-5))
        frame_stats['damage_to_champions_per_min_diff'] = (frame_stats['damage_to_champions_per_min'] - frame_stats['damage_to_champions_per_min'].shift(-5))
        frame_stats['damage_to_buildings_per_min_diff'] = (frame_stats['damage_to_buildings_per_min'] - frame_stats['damage_to_buildings_per_min'].shift(-5))
        
        # SHARE METRICS
        # Opponent dominance indicators
        frame_stats['lane_cs_dominance'] = (frame_stats['cs_per_min'] / (frame_stats['cs_per_min'] + frame_stats['cs_per_min'].shift(-5)))
        frame_stats['lane_damage_to_champions_dominance'] = (frame_stats['damage_to_champions_per_min'] / 
                                                             (1.0 + frame_stats['damage_to_champions_per_min'] + frame_stats['damage_to_champions_per_min'].shift(-5)))
        frame_stats['lane_damage_to_buildings_dominance'] = (frame_stats['damage_to_buildings_per_min'] / 
                                                             (1.0 + frame_stats['damage_to_buildings_per_min'] + frame_stats['damage_to_buildings_per_min'].shift(-5)))
        
        # AGGREGATE METRICS
        # Now get the values for the other team (row +5) by either doing negative or 1- the values we just computed. But ONLY operate on rows 5-9
        # DIFF METRICS
        frame_stats.loc[5:10, 'KDA_diff'] = -frame_stats.loc[0:4, 'KDA_diff'].values
        frame_stats.loc[5:10, 'cs_per_min_diff'] = -frame_stats.loc[0:4, 'cs_per_min_diff'].values
        frame_stats.loc[5:10, 'xp_per_min_diff'] = -frame_stats.loc[0:4, 'xp_per_min_diff'].values
        frame_stats.loc[5:10, 'gold_per_min_diff'] = -frame_stats.loc[0:4, 'gold_per_min_diff'].values
        frame_stats.loc[5:10, 'vision_per_min_diff'] = -frame_stats.loc[0:4, 'vision_per_min_diff'].values
        frame_stats.loc[5:10, 'trade_efficiency_diff'] = -frame_stats.loc[0:4, 'trade_efficiency_diff'].values
        frame_stats.loc[5:10, 'damage_to_champions_per_min_diff'] = -frame_stats.loc[0:4, 'damage_to_champions_per_min_diff'].values
        frame_stats.loc[5:10, 'damage_to_buildings_per_min_diff'] = -frame_stats.loc[0:4, 'damage_to_buildings_per_min_diff'].values
        frame_stats.loc[5:10, 'wards_per_min_diff'] = -frame_stats.loc[0:4, 'wards_per_min_diff'].values
        # SHARE METRICS
        frame_stats.loc[5:10, 'lane_cs_dominance'] = 1 - frame_stats.loc[0:4, 'lane_cs_dominance'].values
        frame_stats.loc[5:10, 'lane_damage_to_champions_dominance'] = 1 - frame_stats.loc[0:4, 'lane_damage_to_champions_dominance'].values
        frame_stats.loc[5:10, 'lane_damage_to_buildings_dominance'] = 1 - frame_stats.loc[0:4, 'lane_damage_to_buildings_dominance'].values
        
        return frame_stats
    
    
    def melt_frame_stats(self, frame_stats):
        """
        Melts the frame_stats dataframe so that each row is a single feature for all participants
        """
        # Rename the participant_id such that it maps to ["top","jungle","mid","bot","support"] for each team
        frame_stats['participant_id'] = frame_stats['participant_id'].map(self.participant_mapping)
        frame_stats = frame_stats.melt(id_vars = ['participant_id'], value_vars = frame_stats.columns)
        frame_stats['name'] = frame_stats['participant_id'] + '_' + frame_stats['variable']
        frame_stats = frame_stats[['name','value']].set_index('name').transpose()
        return frame_stats
    
    def process_frame(self, time = None):
        individual_stats = []
        for participant_data in self.event['participants']:
            individual_stats.append(self.extract_participant_stats(participant_data))
        
        # Convert the list of dictionaries into a single dataframe and ensure that it's sorted by partipant_id when evaluated as a number
        frame_stats = pd.DataFrame.from_dict(individual_stats).sort_values(by=['participant_id'], key=lambda x: x.astype(int))
        
        # Add the time column
        frame_stats['event_time'] = self.event_time
        
        frame_stats_100 = frame_stats[frame_stats['team_id'] == '100']
        frame_stats_100 = self.create_participant_features(frame_stats[frame_stats['team_id'] == '100'])
        frame_stats_200 = frame_stats[frame_stats['team_id'] == '200']
        frame_stats_200 = self.create_participant_features(frame_stats[frame_stats['team_id'] == '200'])
        
        frame_stats = pd.concat([frame_stats_100, frame_stats_200])
        # Get the team features
        team_features_stats = self.create_team_features(frame_stats, event)
        # Get the lane difference features 
        frame_stats = self.create_diff_features(frame_stats)
        
        # Lastly turn these into per-player features by splitting again by team_id, pivoting on participant_id, and then joining back together
        frame_stats_100 = frame_stats[frame_stats['team_id'] == '100'].drop(['team_id', 'event_time'],axis=1)
        frame_stats_200 = frame_stats[frame_stats['team_id'] == '200'].drop(['team_id', 'event_time'],axis=1)
        
        # Pivot and convert to dictionary format 
        frame_stats_100 = self.melt_frame_stats(frame_stats_100)
        frame_stats_100 = {x:y for x, y in zip(frame_stats_100.columns.values, frame_stats_100.values[0])}
        all_stats_100 = {**team_features_stats['100'], **frame_stats_100}
        if time is None:
            time = round(self.event_time/60)
        all_stats_100 = {x + f'_at_{time}': y for x, y in all_stats_100.items()}
        
        frame_stats_200 = self.melt_frame_stats(frame_stats_200)
        frame_stats_200 = {x:y for x, y in zip(frame_stats_200.columns.values, frame_stats_200.values[0])}
        all_stats_200 = {**team_features_stats['200'], **frame_stats_200}
        all_stats_200 = {x + f'_at_{time}': y for x, y in all_stats_200.items()}
        
        return all_stats_100, all_stats_200

# %%
event = game_data[-2]

frame_processor = FrameFeaturesAtTimeGenerator(event, 600)
frame_stats_100, frame_stats_200 = frame_processor.process_frame('game_end')

# %%
len(frame_stats_200)
# Out:
# 236

# %%
frame_stats_100
# Out:
# {'team_share_of_inhibKills_at_game_end': 1.0,
#  'team_share_of_towerKills_at_game_end': 0.9090909090909091,
#  'team_share_of_baronKills_at_game_end': 1.0,
#  'team_share_of_dragonKills_at_game_end': 1.0,
#  'team_share_of_assists_at_game_end': 0.921875,
#  'team_share_of_championsKills_at_game_end': 0.8928571428571429,
#  'team_share_of_totalGold_at_game_end': 0.5884210647641221,
#  'team_share_of_deaths_at_game_end': 0.10714285714285714,
#  'team_share_of_MINIONS_KILLED_at_game_end': 0.49703138252756573,
#  'team_share_of_NEUTRAL_MINIONS_KILLED_at_game_end': 0.5745701975713059,
#  'team_share_of_VISION_SCORE_at_game_end': 0.6249044831147744,
#  'top_XP_at_game_end': 12995.0,
#  'jungle_XP_at_game_end': 12213.0,
#  'mid_XP_at_game_end': 11271.0,
#  'bot_XP_at_game_end': 10866.0,
#  'support_XP_at_game_end': 7815.0,
#  'top_totalGold_at_game_end': 9197.0,
#  'jungle_totalGold_at_game_end': 13249.0,
#  'mid_totalGold_at_game_end': 9412.0,
#  'bot_totalGold_at_game_end': 11993.0,
#  'support_totalGold_at_game_end': 7201.0,
#  'top_currentGold_at_game_end': 592.0,
#  'jungle_currentGold_at_game_end': 2956.0,
#  'mid_currentGold_at_game_end': 2742.0,
#  'bot_currentGold_at_game_end': 1918.0,
#  'support_currentGold_at_game_end': 1521.0,
#  'top_MINIONS_KILLED_at_game_end': 185.0,
#  'jungle_MINIONS_KILLED_at_game_end': 29.0,
#  'mid_MINIONS_KILLED_at_game_end': 154.0,
#  'bot_MINIONS_KILLED_at_game_end': 213.0,
#  'support_MINIONS_KILLED_at_game_end': 5.0,
#  'top_NEUTRAL_MINIONS_KILLED_at_game_end': 0.0,
#  'jungle_NEUTRAL_MINIONS_KILLED_at_game_end': 155.449951171875,
#  'mid_NEUTRAL_MINIONS_KILLED_at_game_end': 0.0,
#  'bot_NEUTRAL_MINIONS_KILLED_at_game_end': 0.0,
#  'support_NEUTRAL_MINIONS_KILLED_at_game_end': 0.0,
#  'top_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_game_end': 0.0,
#  'jungle_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_game_end': 96.80001831054688,
#  'mid_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_game_end': 0.0,
#  'bot_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_game_end': 0.0,
#  'support_NEUTRAL_MINIONS_KILLED_YOUR_JUNGLE_at_game_end': 0.0,
#  'top_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_game_end': 0.0,
#  'jungle_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_game_end': 20.39999771118164,
#  'mid_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_game_end': 0.0,
#  'bot_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_game_end': 0.0,
#  'support_NEUTRAL_MINIONS_KILLED_ENEMY_JUNGLE_at_game_end': 0.0,
#  'top_CHAMPIONS_KILLED_at_game_end': 3.0,
#  'jungle_CHAMPIONS_KILLED_at_game_end': 11.0,
#  'mid_CHAMPIONS_KILLED_at_game_end': 4.0,
#  'bot_CHAMPIONS_KILLED_at_game_end': 7.0,
#  'support_CHAMPIONS_KILLED_at_game_end': 0.0,
#  'top_NUM_DEATHS_at_game_end': 0.0,
#  'jungle_NUM_DEATHS_at_game_end': 1.0,
#  'mid_NUM_DEATHS_at_game_end': 1.0,
#  'bot_NUM_DEATHS_at_game_end': 0.0,
#  'support_NUM_DEATHS_at_game_end': 1.0,
#  'top_ASSISTS_at_game_end': 8.0,
#  'jungle_ASSISTS_at_game_end': 8.0,
#  'mid_ASSISTS_at_game_end': 13.0,
#  'bot_ASSISTS_at_game_end': 8.0,
#  'support_ASSISTS_at_game_end': 22.0,
#  'top_WARD_PLACED_at_game_end': 10.0,
#  'jungle_WARD_PLACED_at_game_end': 8.0,
#  'mid_WARD_PLACED_at_game_end': 8.0,
#  'bot_WARD_PLACED_at_game_end': 11.0,
#  'support_WARD_PLACED_at_game_end': 24.0,
#  'top_WARD_KILLED_at_game_end': 0.0,
#  'jungle_WARD_KILLED_at_game_end': 7.0,
#  'mid_WARD_KILLED_at_game_end': 6.0,
#  'bot_WARD_KILLED_at_game_end': 2.0,
#  'support_WARD_KILLED_at_game_end': 3.0,
#  'top_VISION_SCORE_at_game_end': 14.676288604736328,
#  'jungle_VISION_SCORE_at_game_end': 36.689788818359375,
#  'mid_VISION_SCORE_at_game_end': 31.35653305053711,
#  'bot_VISION_SCORE_at_game_end': 28.216798782348633,
#  'support_VISION_SCORE_at_game_end': 52.74542236328125,
#  'top_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_game_end': 14952.392578125,
#  'jungle_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_game_end': 22980.689453125,
#  'mid_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_game_end': 14841.8544921875,
#  'bot_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_game_end': 14870.3173828125,
#  'support_TOTAL_DAMAGE_DEALT_TO_CHAMPIONS_at_game_end': 2036.3572998046875,
#  'top_TOTAL_DAMAGE_TAKEN_at_game_end': 16260.89453125,
#  'jungle_TOTAL_DAMAGE_TAKEN_at_game_end': 19985.98046875,
#  'mid_TOTAL_DAMAGE_TAKEN_at_game_end': 13617.4462890625,
#  'bot_TOTAL_DAMAGE_TAKEN_at_game_end': 8263.6044921875,
#  'support_TOTAL_DAMAGE_TAKEN_at_game_end': 6916.00341796875,
#  'top_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_game_end': 3077.09716796875,
#  'jungle_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_game_end': 10012.0849609375,
#  'mid_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_game_end': 2712.46826171875,
#  'bot_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_game_end': 7234.4453125,
#  'support_TOTAL_DAMAGE_DEALT_TO_BUILDINGS_at_game_end': 1815.2640380859375,
#  'top_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_game_end': 4521.6337890625,
#  'jungle_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_game_end': 53367.09375,
#  'mid_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_game_end': 2952.135009765625,
#  'bot_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_game_end': 14372.88671875,
#  'support_TOTAL_DAMAGE_DEALT_TO_OBJECTIVES_at_game_end': 2042.664306640625,
#  'top_KDA_at_game_end': 11.0,
#  'jungle_KDA_at_game_end': 9.5,
#  'mid_KDA_at_game_end': 8.5,
#  'bot_KDA_at_game_end': 15.0,
#  'support_KDA_at_game_end': 11.0,
#  'top_cs_per_min_at_game_end': 18.5,
#  'jungle_cs_per_min_at_game_end': 18.4449951171875,
#  'mid_cs_per_min_at_game_end': 15.4,
#  'bot_cs_per_min_at_game_end': 21.3,
#  'support_cs_per_min_at_game_end': 0.5,
#  'top_xp_per_min_at_game_end': 1299.5,
#  'jungle_xp_per_min_at_game_end': 1221.3,
#  'mid_xp_per_min_at_game_end': 1127.1,
#  'bot_xp_per_min_at_game_end': 1086.6,
#  'support_xp_per_min_at_game_end': 781.5,
#  'top_gold_per_min_at_game_end': 919.7,
#  'jungle_gold_per_min_at_game_end': 1324.9,
#  'mid_gold_per_min_at_game_end': 941.2,
#  'bot_gold_per_min_at_game_end': 1199.3,
#  'support_gold_per_min_at_game_end': 720.1,
#  'top_vision_per_min_at_game_end': 1.4676288604736327,
#  'jungle_vision_per_min_at_game_end': 3.6689788818359377,
#  'mid_vision_per_min_at_game_end': 3.1356533050537108,
#  'bot_vision_per_min_at_game_end': 2.821679878234863,
#  'support_vision_per_min_at_game_end': 5.274542236328125,
#  'top_wards_per_min_at_game_end': 1.0,
#  'jungle_wards_per_min_at_game_end': 1.5,
#  'mid_wards_per_min_at_game_end': 1.4,
#  'bot_wards_per_min_at_game_end': 1.3,
#  'support_wards_per_min_at_game_end': 2.7,
#  'top_trade_efficiency_at_game_end': 0.9194742069807076,
#  'jungle_trade_efficiency_at_game_end': 1.1497829544115339,
#  'mid_trade_efficiency_at_game_end': 1.0898346387801643,
#  'bot_trade_efficiency_at_game_end': 1.799277557307111,
#  'support_trade_efficiency_at_game_end': 0.29439877021235955,
#  'top_damage_to_champions_per_min_at_game_end': 1495.2392578125,
#  'jungle_damage_to_champions_per_min_at_game_end': 2298.0689453125,
#  'mid_damage_to_champions_per_min_at_game_end': 1484.18544921875,
#  'bot_damage_to_champions_per_min_at_game_end': 1487.03173828125,
#  'support_damage_to_champions_per_min_at_game_end': 203.63572998046874,
#  'top_damage_to_buildings_per_min_at_game_end': 307.709716796875,
#  'jungle_damage_to_buildings_per_min_at_game_end': 1001.20849609375,
#  'mid_damage_to_buildings_per_min_at_game_end': 271.246826171875,
#  'bot_damage_to_buildings_per_min_at_game_end': 723.44453125,
#  'support_damage_to_buildings_per_min_at_game_end': 181.52640380859376,
#  'top_gold_spent_at_game_end': 8605.0,
#  'jungle_gold_spent_at_game_end': 10293.0,
#  'mid_gold_spent_at_game_end': 6670.0,
#  'bot_gold_spent_at_game_end': 10075.0,
#  'support_gold_spent_at_game_end': 5680.0,
#  'top_share_of_minions_stolen_at_game_end': 0.0,
#  'jungle_share_of_minions_stolen_at_game_end': 0.13039312290209873,
#  'mid_share_of_minions_stolen_at_game_end': 0.0,
#  'bot_share_of_minions_stolen_at_game_end': 0.0,
#  'support_share_of_minions_stolen_at_game_end': 0.0,
#  'top_share_of_team_gold_at_game_end': 0.1801496513358928,
#  'jungle_share_of_team_gold_at_game_end': 0.2595197053984173,
#  'mid_share_of_team_gold_at_game_end': 0.18436104364177702,
#  'bot_share_of_team_gold_at_game_end': 0.23491733918357752,
#  'support_share_of_team_gold_at_game_end': 0.14105226044033534,
#  'top_share_of_team_xp_at_game_end': 0.2355873821609862,
#  'jungle_share_of_team_xp_at_game_end': 0.22141044234952864,
#  'mid_share_of_team_xp_at_game_end': 0.20433284989122552,
#  'bot_share_of_team_xp_at_game_end': 0.19699057287889776,
#  'support_share_of_team_xp_at_game_end': 0.14167875271936187,
#  'top_share_of_team_damage_to_champions_at_game_end': 0.21458161370450307,
#  'jungle_share_of_team_damage_to_champions_at_game_end': 0.3297956097078334,
#  'mid_share_of_team_damage_to_champions_at_game_end': 0.21299528290611455,
#  'bot_share_of_team_damage_to_champions_at_game_end': 0.2134037535217097,
#  'support_share_of_team_damage_to_champions_at_game_end': 0.029223740159839286,
#  'top_share_of_team_damage_to_buildings_at_game_end': 0.12382007262427612,
#  'jungle_share_of_team_damage_to_buildings_at_game_end': 0.402878758554788,
#  'mid_share_of_team_damage_to_buildings_at_game_end': 0.10914768004507502,
#  'bot_share_of_team_damage_to_buildings_at_game_end': 0.2911086309898424,
#  'support_share_of_team_damage_to_buildings_at_game_end': 0.07304485778601846,
#  'top_share_of_team_damage_to_objectives_at_game_end': 0.05852761705950346,
#  'jungle_share_of_team_damage_to_objectives_at_game_end': 0.6907788140945899,
#  'mid_share_of_team_damage_to_objectives_at_game_end': 0.03821216741998469,
#  'bot_share_of_team_damage_to_objectives_at_game_end': 0.1860413401787315,
#  'support_share_of_team_damage_to_objectives_at_game_end': 0.026440061247190522,
#  'top_KDA_diff_at_game_end': 10.857142857142858,
#  'jungle_KDA_diff_at_game_end': 9.071428571428571,
#  'mid_KDA_diff_at_game_end': 8.3,
#  'bot_KDA_diff_at_game_end': 14.857142857142858,
#  'support_KDA_diff_at_game_end': 10.5,
#  'top_cs_per_min_diff_at_game_end': 0.6000000000000014,
#  'jungle_cs_per_min_diff_at_game_end': 6.234992980957031,
#  'mid_cs_per_min_diff_at_game_end': -3.700000000000001,
#  'bot_cs_per_min_diff_at_game_end': 3.400000000000002,
#  'support_cs_per_min_diff_at_game_end': -3.2,
#  'top_xp_per_min_diff_at_game_end': 358.0,
#  'jungle_xp_per_min_diff_at_game_end': 459.0999999999999,
#  'mid_xp_per_min_diff_at_game_end': 151.9999999999999,
#  'bot_xp_per_min_diff_at_game_end': 322.9999999999999,
#  'support_xp_per_min_diff_at_game_end': 212.79999999999995,
#  'top_gold_per_min_diff_at_game_end': 146.70000000000005,
#  'jungle_gold_per_min_diff_at_game_end': 657.8000000000001,
#  'mid_gold_per_min_diff_at_game_end': 96.0,
#  'bot_gold_per_min_diff_at_game_end': 435.0,
#  'support_gold_per_min_diff_at_game_end': 198.80000000000007,
#  'top_vision_per_min_diff_at_game_end': 0.5331495285034179,
#  'jungle_vision_per_min_diff_at_game_end': 1.2798112869262699,
#  'mid_vision_per_min_diff_at_game_end': 1.9383527755737302,
#  'bot_vision_per_min_diff_at_game_end': 1.5552388191223143,
#  'support_vision_per_min_diff_at_game_end': 1.2368377685546879,
#  'top_wards_per_min_diff_at_game_end': 0.4,
#  'jungle_wards_per_min_diff_at_game_end': 0.9,
#  'mid_wards_per_min_diff_at_game_end': 0.4999999999999999,
#  'bot_wards_per_min_diff_at_game_end': 0.4,
#  'support_wards_per_min_diff_at_game_end': 0.20000000000000018,
#  'top_trade_efficiency_diff_at_game_end': 0.45860938218172076,
#  'jungle_trade_efficiency_diff_at_game_end': 0.9780240079335577,
#  'mid_trade_efficiency_diff_at_game_end': 0.1376679897378097,
#  'bot_trade_efficiency_diff_at_game_end': 1.106506626641447,
#  'support_trade_efficiency_diff_at_game_end': -0.002556441332614068,
#  'top_damage_to_champions_per_min_diff_at_game_end': 253.64970703125005,
#  'jungle_damage_to_champions_per_min_diff_at_game_end': 1841.1024902343752,
#  'mid_damage_to_champions_per_min_diff_at_game_end': 331.3899414062498,
#  'bot_damage_to_champions_per_min_diff_at_game_end': 648.972265625,
#  'support_damage_to_champions_per_min_diff_at_game_end': -39.66248779296876,
#  'top_damage_to_buildings_per_min_diff_at_game_end': -135.68271484374998,
#  'jungle_damage_to_buildings_per_min_diff_at_game_end': 1001.20849609375,
#  'mid_damage_to_buildings_per_min_diff_at_game_end': 105.37971191406251,
#  'bot_damage_to_buildings_per_min_diff_at_game_end': 723.44453125,
#  'support_damage_to_buildings_per_min_diff_at_game_end': 181.52640380859376,
#  'top_lane_cs_dominance_at_game_end': 0.5082417582417582,
#  'jungle_lane_cs_dominance_at_game_end': 0.6016961921316408,
#  'mid_lane_cs_dominance_at_game_end': 0.4463768115942029,
#  'bot_lane_cs_dominance_at_game_end': 0.5433673469387755,
#  'support_lane_cs_dominance_at_game_end': 0.11904761904761904,
#  'top_lane_damage_to_champions_dominance_at_game_end': 0.5461405231470663,
#  'jungle_lane_damage_to_champions_dominance_at_game_end': 0.8338314322765175,
#  'mid_lane_damage_to_champions_dominance_at_game_end': 0.5626217449609769,
#  'bot_lane_damage_to_champions_dominance_at_game_end': 0.6392835032818519,
#  'support_lane_damage_to_champions_dominance_at_game_end': 0.4546110671039063,
#  'top_lane_damage_to_buildings_dominance_at_game_end': 0.40913287834125345,
#  'jungle_lane_damage_to_buildings_dominance_at_game_end': 0.9990022036293869,
#  'mid_lane_damage_to_buildings_dominance_at_game_end': 0.619123933618376,
#  'bot_lane_damage_to_buildings_dominance_at_game_end': 0.9986196320672411,
#  'support_lane_damage_to_buildings_dominance_at_game_end': 0.9945213405889011}

# %%
class GameFeaturesGenerator:
    TIME_FORMAT = '%Y-%m-%dT%H:%M:%S.%fZ'

    @staticmethod
    def get_event_time(start_time, event_time):
        return (datetime.strptime(event_time, GameFeaturesGenerator.TIME_FORMAT) - start_time).total_seconds()

    @staticmethod
    def flip_team_id(team_id):
        """
        Flips team_id from 100 to 200 and vice versa. Needed for when processing turret fall events because we want to update the feature for the team that lost the turret
        """
        if team_id == 100:
            return 200
        elif team_id == 200:
            return 100
        else:
            print("Error: team_id is not 100 or 200")

    def __init__(self, game_data, mapping_data):
        self.game_data = game_data
        self.game_start_time = datetime.strptime(game_data[0]['eventTime'], GameFeaturesGenerator.TIME_FORMAT)
        self.team_id_mapping = {"100": mapping_data['teamMapping']['100'], "200": mapping_data['teamMapping']['200']}
        self.esports_game_id = mapping_data['esportsGameId']  # Looks like '110310652412257228'
        self.platform_game_id = mapping_data['platformGameId']  # Looks lik {'esportsGameId': '110310652412257228'
        # Create flags for first events (e.g. first turret kill, first dragon kill, etc.). These can only happen once (for both teams)
        self.first_herald_flag = True
        self.first_dragon_flag = True
        self.first_baron_flag = True
        self.first_turret_flag = True
        self.first_inhibitor_flag = True
        self.first_kill_flag = True

        # Create features for each team
        # EPIC MONSTER EVENT FEATURES
        self.IMPORTANT_MONSTER_TYPES = ["riftHerald", "dragon", "baron"]
        epic_monster_kill_event_features = [
            ["first_" + monster_type + "_ind", "first_" + monster_type + "_time", "num_" + monster_type] for
            monster_type
            in self.IMPORTANT_MONSTER_TYPES]
        epic_monster_kill_event_features = [item for sublist in epic_monster_kill_event_features for item in
                                            sublist]  # Flatten list of lists

        # BUILDING DESTROYED EVENT FEATURES
        self.IMPORTANT_BUILDING_TYPES = ["turret", "inhibitor"]
        building_destroyed_event_features = [
            ["first_" + building_type + "_ind", "first_" + building_type + "_time", "num_" + building_type] for
            building_type
            in self.IMPORTANT_BUILDING_TYPES]
        building_destroyed_event_features = [item for sublist in building_destroyed_event_features for item in
                                             sublist]  # Flatten list of lists

        # CHAMPION KILL EVENT FEATURES
        champion_kill_event_features = ["first_kill_ind", "first_kill_time", "num_kills"]

        # GAME METADATA FEATURES
        # TODO: Also need a feature for whether this was a domestic or international game (e.g. LCS vs. Worlds)
        game_metadata_features = ["game_end_time"]

        all_features = (["platformGameId", "esportsGameId", "team_id", "start_time", "outcome"] +
                        epic_monster_kill_event_features + building_destroyed_event_features + champion_kill_event_features + game_metadata_features)
        self.team_features = {"100": {feature: np.nan for feature in all_features},
                              "200": {feature: np.nan for feature in all_features}}
        # Set all "num_" features to 0
        for team_id in ["100", "200"]:
            for feature in all_features:
                if feature.startswith("num_"):
                    self.team_features[team_id][feature] = 0

    def process_epic_monster_kill_event(self, event, team_features):
        monster_type = event['monsterType']
        if monster_type in self.IMPORTANT_MONSTER_TYPES:
            event_time = event['eventTime']
            time_of_kill = GameFeaturesGenerator.get_event_time(self.game_start_time, event_time)
            killer_team_id = str(event['killerTeamID'])
            victim_team_id = str(GameFeaturesGenerator.flip_team_id(event['killerTeamID']))
            if self.first_herald_flag:
                team_features[killer_team_id]['first_riftHerald_ind'] = 1
                team_features[victim_team_id]['first_riftHerald_ind'] = 0
                team_features[killer_team_id]['first_riftHerald_time'] = time_of_kill
                self.first_herald_flag = False
            if self.first_dragon_flag:
                team_features[killer_team_id]['first_dragon_ind'] = 1
                team_features[victim_team_id]['first_dragon_ind'] = 0
                team_features[killer_team_id]['first_dragon_time'] = time_of_kill
                self.first_dragon_flag = False
            if self.first_baron_flag:
                team_features[killer_team_id]['first_baron_ind'] = 1
                team_features[victim_team_id]['first_baron_ind'] = 0
                team_features[killer_team_id]['first_baron_time'] = time_of_kill
                self.first_baron_flag = False
            team_features[killer_team_id]['num_' + monster_type] += 1

    def process_building_destroyed_event(self, event, team_features):
        building_type = event['buildingType']
        if building_type in self.IMPORTANT_BUILDING_TYPES:
            event_time = event['eventTime']
            time_of_event = GameFeaturesGenerator.get_event_time(self.game_start_time, event_time)
            team_id = str(GameFeaturesGenerator.flip_team_id(event['teamID']))
            victim_team_id = str(event['teamID'])
            if self.first_turret_flag:
                team_features[team_id]['first_turret_ind'] = 1
                team_features[victim_team_id]['first_turret_ind'] = 0
                team_features[team_id]['first_turret_time'] = time_of_event
                self.first_turret_flag = False
            if self.first_inhibitor_flag:
                team_features[team_id]['first_inhibitor_ind'] = 1
                team_features[victim_team_id]['first_inhibitor_ind'] = 0
                team_features[team_id]['first_inhibitor_time'] = time_of_event
                self.first_inhibitor_flag = False
            team_features[team_id]['num_' + building_type] += 1

    def process_champion_kill_event(self, event, team_features):
        event_time = event['eventTime']
        time_of_event = GameFeaturesGenerator.get_event_time(self.game_start_time, event_time)
        killer_team_id = str(event['killerTeamID'])
        victim_team_id = str(GameFeaturesGenerator.flip_team_id(event['killerTeamID']))
        if self.first_kill_flag:
            team_features[killer_team_id]['first_kill_ind'] = 1
            team_features[victim_team_id]['first_kill_ind'] = 0
            team_features[killer_team_id]['first_kill_time'] = time_of_event
            self.first_kill_flag = False
        team_features[killer_team_id]['num_kills'] += 1

    def process_game_end_event(self, event, team_features):
        # We only call this method for the final event, so if for some reason there is no game_end event then discard the data
        if event['eventType'] == "game_end":
            event_time = event['eventTime']
            time_of_event = GameFeaturesGenerator.get_event_time(self.game_start_time, event_time)
            team_features['100']['game_end_time'] = time_of_event
            team_features['200']['game_end_time'] = time_of_event
            winning_team = event['winningTeam']
            losing_team = GameFeaturesGenerator.flip_team_id(winning_team)
            team_features[str(winning_team)]['outcome'] = 1
            team_features[str(losing_team)]['outcome'] = 0
        else:
            raise Exception("Error: event is not a game_end event")

    def process_game(self):
        """
        Loops through all events in the game and updates the team features as they occur
        :return: a pandas dataframe with the features for each team and label "outcome"
        """
        self.time_flags = [t for t in [7, 14, 20, 30]]  # 999 is a placeholder for the game_end flag
        frame_stats_100_dict = {str(time): None for time in self.time_flags+['game_end']}  # {'7': None, '14': None, '20': None, '30': None, 'game_end': None}
        frame_stats_200_dict = {str(time): None for time in self.time_flags+['game_end']}
        
        self.time_flags.append(999)
        for event in self.game_data:
            if event['eventType'] == "epic_monster_kill":
                self.process_epic_monster_kill_event(event, self.team_features)
            elif event['eventType'] == "building_destroyed":
                self.process_building_destroyed_event(event, self.team_features)
            elif event['eventType'] == "champion_kill":
                self.process_champion_kill_event(event, self.team_features)
            elif event['eventType'] == "game_end":
                self.process_game_end_event(event, self.team_features)
            elif event['eventType'] == "stats_update": 
                """
                Check the event time and process this frame if it is the first "stats_update" past each flag (7, 14, 20, 30)
                - 7: midlaners hit lv. 6 and may roam, dragons spawns at 5 rift herald spawn at 8 
                - 14: tower plates fall, unleashed TP activates
                - 20: Baron spawns 
                - 30: Very late game (laners likely full build with ~300 cs). Usually baron/elder is taken and game ends soon after.
                """ 
                event_time = GameFeaturesGenerator.get_event_time(self.game_start_time, event['eventTime'])
                if (event_time >= self.time_flags[0]*60) or event['gameOver']:
                    if event['gameOver']:
                        time_for_stat_label = 'game_end'
                        # print("Game ended at " + str(event_time))
                    else:
                        time_for_stat_label = str(self.time_flags.pop(0))
                    frame_processor = FrameFeaturesAtTimeGenerator(event, event_time)  # Requires the time for stat per min computations
                    frame_stats_100, frame_stats_200 = frame_processor.process_frame(time_for_stat_label)  # Requires time solely for labeling purposes
                    frame_stats_100_dict[time_for_stat_label] = frame_stats_100
                    frame_stats_200_dict[time_for_stat_label] = frame_stats_200
        
        # If any frames remain, then copy the last frame for each remaining time flag and fill the values with NA 
        self.time_flags.remove(999)
        for time_flag_remaining in self.time_flags:
            template_frame = deepcopy(frame_stats_100_dict['game_end'])
            # Replace the 'game_end' part of the name with the current time flag
            template_frame = {x.replace('game_end', str(time_flag_remaining)):y for x, y in template_frame.items()}
            # Replace the values with na to indicate that the game did not arrive at that state
            template_frame = {x:np.nan for x in template_frame}
            frame_stats_100_dict[str(time_flag_remaining)] = template_frame
            frame_stats_200_dict[str(time_flag_remaining)] = template_frame
        
        
        # Lastly, unpack all features into a single dictionary in order of the dictionary keys, ending with the game_end features
        frame_stats_100_full = {}
        frame_stats_200_full = {}
        for time_flag in frame_stats_100_dict:
            frame_stats_100_full = {**frame_stats_100_full, **frame_stats_100_dict[time_flag]}
            frame_stats_200_full = {**frame_stats_200_full, **frame_stats_200_dict[time_flag]}
        # Add the frame_stats to the team_features
        self.team_features['100'] = {**self.team_features['100'], **frame_stats_100_full}
        self.team_features['200'] = {**self.team_features['200'], **frame_stats_200_full}
        
        # Now we have all the datapoints, we can create a dataframe with the team ID, label, start_time, and features
        # First assign the rest of the metadata
        rows = []
        for team_id in ["100", "200"]:
            # Assign metadata (same for both teams)
            self.team_features[team_id]['platformGameId'] = self.platform_game_id
            self.team_features[team_id]['esportsGameId'] = self.esports_game_id
            self.team_features[team_id]['start_time'] = self.game_start_time

            # Assessing team-specific data
            self.team_features[team_id]['team_id'] = self.team_id_mapping[team_id]
            rows.append(pd.DataFrame.from_dict(self.team_features[team_id], orient='index').transpose())
        return pd.concat(rows, ignore_index=True)

# %%
# Read in teams data
with open("teams.json", "r") as json_file:
   teams_data = json.load(json_file)

# %%
teams_data
# Out:
# [{'team_id': '107582169874155554',
#   'name': "God's Plan",
#   'acronym': 'GDP',
#   'slug': 'gods-plan'},
#  {'team_id': '105550059790656435',
#   'name': 'T1 Esports Academy',
#   'acronym': 'T1',
#   'slug': 't1-challengers'},
#  {'team_id': '103535282143744679',
#   'name': 'Dark Passage Akademi',
#   'acronym': 'DP',
#   'slug': 'dark-passage-akademi'},
#  {'team_id': '109637393694097670',
#   'name': 'Team Heretics',
#   'acronym': 'TH',
#   'slug': 'team-heretics-lec'},
#  {'team_id': '101157821387445307',
#   'name': 'Caps',
#   'acronym': 'EU1',
#   'slug': 'caps'},
#  {'team_id': '110534724851488577',
#   'name': 'Froggy Five',
#   'acronym': 'FROG',
#   'slug': 'froggy-five'},
#  {'team_id': '109671201259007744',
#   'name': 'Team Liquid Honda First',
#   'acronym': 'TLF',
#   'slug': 'team-liquid-honda-first'},
#  {'team_id': '107423086908356081',
#   'name': 'Nyyrikki',
#   'acronym': 'NKI',
#   'slug': 'nyyrikki'},
#  {'team_id': '107582176093752697',
#   'name': 'Hooked Esports',
#   'acronym': 'HK',
#   'slug': 'hooked-esports'},
#  {'team_id': '99566406336293850',
#   'name': 'Bombers',
#   'acronym': 'BMR',
#   'slug': 'bombers'},
#  {'team_id': '107251374793416561',
#   'name': 'CERBERUS ESPORTS',
#   'acronym': 'CES',
#   'slug': 'cerberus-esports'},
#  {'team_id': '105593951536470384',
#   'name': 'GTZ Esports',
#   'acronym': 'GTZ',
#   'slug': 'gtz-bulls'},
#  {'team_id': '103935446548920777',
#   'name': 'Misfits Premier',
#   'acronym': 'MSFP',
#   'slug': 'misfits-premier'},
#  {'team_id': '103535282151674574',
#   'name': 'Royal Youth Akademi',
#   'acronym': 'RYLA',
#   'slug': 'royal-youth-akademi'},
#  {'team_id': '104211677548295324',
#   'name': 'Double Crunch Team Italy',
#   'acronym': 'DCTI',
#   'slug': 'double-crunch-team-italy-pg-esports'},
#  {'team_id': '106827827857159558',
#   'name': 'V3 Academy',
#   'acronym': 'V3',
#   'slug': 'v3-academy'},
#  {'team_id': '105521637552587612',
#   'name': 'Team Phantasma',
#   'acronym': 'TP',
#   'slug': 'team-phantasma'},
#  {'team_id': '101383792559569368',
#   'name': 'All Knights',
#   'acronym': 'AK',
#   'slug': 'all-knights'},
#  {'team_id': '105550005698683818',
#   'name': 'Liberty Academy',
#   'acronym': 'LBR',
#   'slug': 'liberty-academy'},
#  {'team_id': '109631541326560210',
#   'name': 'Reven Esports',
#   'acronym': 'RVN',
#   'slug': 'reven-esports'},
#  {'team_id': '105550054006182911',
#   'name': 'NONGSHIM ESPORTS ACADEMY',
#   'acronym': 'NS',
#   'slug': 'ns-challengers'},
#  {'team_id': '105514967858969605',
#   'name': 'GameWard',
#   'acronym': 'GW',
#   'slug': 'gameward'},
#  {'team_id': '107581178720470377',
#   'name': 'Arctic Gaming',
#   'acronym': 'ARC',
#   'slug': 'arctic-gaming'},
#  {'team_id': '100205573495116443',
#   'name': 'Gen.G',
#   'acronym': 'GEN',
#   'slug': 'geng'},
#  {'team_id': '109783160511364305',
#   'name': 'CB Gaming',
#   'acronym': 'CB',
#   'slug': 'cb-gaming'},
#  {'team_id': '109783164711873455',
#   'name': 'Zenigma',
#   'acronym': 'ZEN',
#   'slug': 'zenigma'},
#  {'team_id': '107582618156093368',
#   'name': 'Incubus',
#   'acronym': 'INC',
#   'slug': 'incubus'},
#  {'team_id': '100285330169036485',
#   'name': 'Unsold Stuff Gaming',
#   'acronym': 'USG',
#   'slug': 'unsold-stuff-gaming'},
#  {'team_id': '105593161016793151',
#   'name': 'Inside Games',
#   'acronym': 'ING',
#   'slug': 'inside-games'},
#  {'team_id': '105521408363571548',
#   'name': 'Illuminar Gaming',
#   'acronym': 'IHG',
#   'slug': 'illuminar-gaming'},
#  {'team_id': '104710316579222193',
#   'name': 'G2 Arctic',
#   'acronym': 'G2AR',
#   'slug': 'g2-arctic'},
#  {'team_id': '98767991871709842',
#   'name': 'Gambit Esports',
#   'acronym': 'GMB',
#   'slug': 'gambit-esports'},
#  {'team_id': '110424397251619481',
#   'name': 'Myth Esports',
#   'acronym': 'MYTH',
#   'slug': 'myth-esports'},
#  {'team_id': '105521706535388095',
#   'name': 'Anorthosis Famagusta Esports',
#   'acronym': 'ANO',
#   'slug': 'anorthosis-famagusta-esports'},
#  {'team_id': '107582609836036013',
#   'name': 'Diamond Doves',
#   'acronym': 'DD',
#   'slug': 'diamond-doves'},
#  {'team_id': '109782867012820172',
#   'name': 'Horizon Gaming',
#   'acronym': 'HZG',
#   'slug': 'horizon-gaming'},
#  {'team_id': '99566404581868574',
#   'name': 'Kwangdong Freecs',
#   'acronym': 'KDF',
#   'slug': 'kwangdong-freecs'},
#  {'team_id': '105550003470349739',
#   'name': 'Rensga Academy',
#   'acronym': 'RNS',
#   'slug': 'rensga-academy'},
#  {'team_id': '103877554248683116',
#   'name': 'Schalke 04 Evolution',
#   'acronym': 'S04E',
#   'slug': 'schalke-04-evolution'},
#  {'team_id': '110534728305628996',
#   'name': "Kelyx's Grandpa Gamers",
#   'acronym': 'OLD',
#   'slug': 'kelyxs-grandpa-gamers'},
#  {'team_id': '105515219038427019',
#   'name': 'Karmine Corp',
#   'acronym': 'KC',
#   'slug': 'karmine-corp'},
#  {'team_id': '98767991866488695',
#   'name': 'Fnatic',
#   'acronym': 'FNC',
#   'slug': 'fnatic'},
#  {'team_id': '105503848339138647',
#   'name': 'PENTA 1860',
#   'acronym': 'PTA',
#   'slug': 'penta-1860'},
#  {'team_id': '107693836459380354',
#   'name': 'SAMPI',
#   'acronym': 'SMP',
#   'slug': 'sampi'},
#  {'team_id': '105515109012592449',
#   'name': 'IZIDREAM',
#   'acronym': 'IZI',
#   'slug': 'izidream'},
#  {'team_id': '105553684493690219',
#   'name': 'Split Raiders',
#   'acronym': 'STR',
#   'slug': 'split-raiders'},
#  {'team_id': '106334794714373670',
#   'name': 'Goexanimo',
#   'acronym': 'GOEX',
#   'slug': 'goexanimo'},
#  {'team_id': '101428372830010965',
#   'name': 'Alpha Esports',
#   'acronym': 'ALF',
#   'slug': 'alpha-esports'},
#  {'team_id': '103877756742242918',
#   'name': 'Racoon',
#   'acronym': 'RCN',
#   'slug': 'racoon'},
#  {'team_id': '100205573002983994',
#   'name': 'EVOS Esports',
#   'acronym': 'EVS',
#   'slug': 'evos-esports'},
#  {'team_id': '100285330170285888',
#   'name': 'Kuala Lumpur Hunters',
#   'acronym': 'KLH',
#   'slug': 'kuala-lumpur-hunters'},
#  {'team_id': '99566405126602853',
#   'name': 'FlyQuest Challengers',
#   'acronym': 'FLY',
#   'slug': 'fly-academy'},
#  {'team_id': '107603566520687175',
#   'name': 'Team Mayan eSports',
#   'acronym': 'MYN',
#   'slug': 'team-mayan-esports'},
#  {'team_id': '109675484017801229',
#   'name': 'Team Bliss',
#   'acronym': 'TB',
#   'slug': 'team-bliss'},
#  {'team_id': '105521419784127190',
#   'name': 'Komil&Friends',
#   'acronym': 'KNF',
#   'slug': 'komilfriends'},
#  {'team_id': '103935642731826448',
#   'name': 'Sector One',
#   'acronym': 'S1',
#   'slug': 'sector-one'},
#  {'team_id': '108018637503819612',
#   'name': 'PRO42 Esports',
#   'acronym': 'P42',
#   'slug': 'pro42-esports'},
#  {'team_id': '101383792891050518',
#   'name': 'Gravitas',
#   'acronym': 'GRV',
#   'slug': 'gravitas'},
#  {'team_id': '99566405128626825',
#   'name': '100 Thieves Challengers',
#   'acronym': '100',
#   'slug': '100-academy'},
#  {'team_id': '104367068120825486',
#   'name': 'PSG Talon',
#   'acronym': 'PSG',
#   'slug': 'psg-talon'},
#  {'team_id': '105913232697120493',
#   'name': 'EG Prodigies',
#   'acronym': 'EG',
#   'slug': 'eg-prodigies'},
#  {'team_id': '105515345386578249',
#   'name': 'Solary',
#   'acronym': 'SLY',
#   'slug': 'solary'},
#  {'team_id': '101157821395833925',
#   'name': 'Uzi',
#   'acronym': 'CN3',
#   'slug': 'uzi'},
#  {'team_id': '102787200124959636',
#   'name': 'Crvena Zvezda Esports',
#   'acronym': 'CZV',
#   'slug': 'crvena-zvezda-esports'},
#  {'team_id': '106857761435870473',
#   'name': 'Supernova',
#   'acronym': 'SN',
#   'slug': 'supernova'},
#  {'team_id': '107598699275015260',
#   'name': 'LeviatÃ¡n Esports',
#   'acronym': 'LEV',
#   'slug': 'leviatan-esports'},
#  {'team_id': '107110686951738484',
#   'name': 'Esports Empire',
#   'acronym': 'EE',
#   'slug': 'esports-empire'},
#  {'team_id': '103935523328473675',
#   'name': 'K1CK Neosurf',
#   'acronym': 'K1',
#   'slug': 'k1ck-neosurf'},
#  {'team_id': '103877925817094140',
#   'name': 'PIGSPORTS',
#   'acronym': 'PIG',
#   'slug': 'pigsports'},
#  {'team_id': '109696126554266494',
#   'name': 'Geekay Esports',
#   'acronym': 'GK',
#   'slug': 'geekay-esports'},
#  {'team_id': '106301891501674861',
#   'name': 'PDW',
#   'acronym': 'PDW',
#   'slug': 'pdw'},
#  {'team_id': '107582638341246907',
#   'name': 'Instinct Gaming',
#   'acronym': 'INS',
#   'slug': 'instinct-gaming'},
#  {'team_id': '98767991860392497',
#   'name': 'TSM',
#   'acronym': 'TSM',
#   'slug': 'tsm'},
#  {'team_id': '109782787975510889',
#   'name': 'Native Gaming',
#   'acronym': 'N8V',
#   'slug': 'native-gaming'},
#  {'team_id': '99566406490127625',
#   'name': 'J Team',
#   'acronym': 'JT',
#   'slug': 'taipei-j-team'},
#  {'team_id': '99566404850008779',
#   'name': 'Suzhou LNG Esports',
#   'acronym': 'LNG',
#   'slug': 'lng-esports'},
#  {'team_id': '107467794614674479',
#   'name': 'FnaticTQ',
#   'acronym': 'FNTQ',
#   'slug': 'fnatictq'},
#  {'team_id': '99566408221961358',
#   'name': 'RED Kalunga',
#   'acronym': 'RED',
#   'slug': 'red-kalunga'},
#  {'team_id': '108319669531442279',
#   'name': 'Aguilas Doradas',
#   'acronym': 'AD',
#   'slug': 'aguilas-doradas'},
#  {'team_id': '105548000936710641',
#   'name': 'Method2Madness',
#   'acronym': 'M2XX',
#   'slug': 'method2madness'},
#  {'team_id': '109828279319224248',
#   'name': 'MGN Box Esports',
#   'acronym': 'MBE',
#   'slug': 'mgn-box-esports'},
#  {'team_id': '105301755072677196',
#   'name': 'LCK Queue Kings',
#   'acronym': 'LCKQ',
#   'slug': 'lckqueuekings'},
#  {'team_id': '101157821440857212',
#   'name': 'EU with Influencers',
#   'acronym': 'EUWI',
#   'slug': 'eu-with-influencers'},
#  {'team_id': '101157821459731619',
#   'name': 'Tandem Mode C',
#   'acronym': 'TMC',
#   'slug': 'tandem-mode-c'},
#  {'team_id': '109749493607708438',
#   'name': 'ENEMI3S',
#   'acronym': 'NM3',
#   'slug': 'enemi3s'},
#  {'team_id': '103535282124208038',
#   'name': 'Pentanet.GG',
#   'acronym': 'PGG',
#   'slug': 'pentanetgg'},
#  {'team_id': '99124844354766222',
#   'name': 'PCS All-Stars',
#   'acronym': 'PCS1',
#   'slug': 'pcs-all-stars'},
#  {'team_id': '105549988405523871',
#   'name': 'Flamengo Academy',
#   'acronym': 'FLA',
#   'slug': 'flamengo-academy'},
#  {'team_id': '109696115986547257',
#   'name': 'Fox Gaming',
#   'acronym': 'FOX',
#   'slug': 'fox-gaming'},
#  {'team_id': '101157821437777013',
#   'name': 'NA with Influencers',
#   'acronym': 'NAWI',
#   'slug': 'na-with-influencers'},
#  {'team_id': '110534741480867943',
#   'name': 'Teamless Revenge',
#   'acronym': 'TRV',
#   'slug': 'teamless-revenge'},
#  {'team_id': '107700199633958891',
#   'name': 'CTBC Flying Oyster',
#   'acronym': 'CFO',
#   'slug': 'ctbc-flying-oyster'},
#  {'team_id': '102787200147504121',
#   'name': 'Campus Party Sparks',
#   'acronym': 'SPKS',
#   'slug': 'campus-party-sparks'},
#  {'team_id': '107581733744920199',
#   'name': 'Goat Esports',
#   'acronym': 'GOT',
#   'slug': 'goat-esports'},
#  {'team_id': '107603551467692884',
#   'name': 'ELR Gaming',
#   'acronym': 'ELR',
#   'slug': 'elr-gaming'},
#  {'team_id': '102747101562758215',
#   'name': 'SeolHaeOne Prince',
#   'acronym': 'SP',
#   'slug': 'apk-prince'},
#  {'team_id': '105193385417106233',
#   'name': 'LLA All-Stars',
#   'acronym': 'LLA',
#   'slug': 'llaallstars'},
#  {'team_id': '99566405132177721',
#   'name': 'Clutch Gaming Academy',
#   'acronym': 'CGA',
#   'slug': 'clutch-gaming-academy'},
#  {'team_id': '105505619546859895',
#   'name': 'OKSavingsBank BRION',
#   'acronym': 'BRO',
#   'slug': 'fredit-brion'},
#  {'team_id': '107581765633427097',
#   'name': 'Fuego',
#   'acronym': 'FUE',
#   'slug': 'fuego'},
#  {'team_id': '105519977854458717',
#   'name': 'Nordavind',
#   'acronym': 'NVD',
#   'slug': 'nordavind'},
#  {'team_id': '99566404848691211',
#   'name': 'Invictus Gaming',
#   'acronym': 'IG',
#   'slug': 'invictus-gaming'},
#  {'team_id': '107598704067400262',
#   'name': 'Stone Movistar',
#   'acronym': 'STM',
#   'slug': 'stone-movistar'},
#  {'team_id': '98767991860392497',
#   'name': 'TSM',
#   'acronym': 'TSM',
#   'slug': 'tsm'},
#  {'team_id': '107598805167594304',
#   'name': 'Wap Esports',
#   'acronym': 'WAP',
#   'slug': 'wap-esports'},
#  {'team_id': '105594135137147298',
#   'name': 'White Dragons',
#   'acronym': 'WD',
#   'slug': 'white-dragons'},
#  {'team_id': '99566404853854212',
#   'name': 'Bilibili Gaming Pingan Bank',
#   'acronym': 'BLG',
#   'slug': 'bilibili-gaming'},
#  {'team_id': '106295024192678387',
#   'name': 'Gaia Esports',
#   'acronym': 'GAIA',
#   'slug': 'gaia-esports'},
#  {'team_id': '109696073114910519',
#   'name': 'Anubis Gaming',
#   'acronym': 'ANB',
#   'slug': 'anubis-gaming'},
#  {'team_id': '105503948999800557',
#   'name': 'E WIE EINFACH E-SPORTS',
#   'acronym': 'EWI',
#   'slug': 'e-wie-einfach-e-sports'},
#  {'team_id': '107599174108436104',
#   'name': 'Rebirth Esports',
#   'acronym': 'RBT',
#   'slug': 'rebirth-esports'},
#  {'team_id': '98767991926151025',
#   'name': 'G2 Esports',
#   'acronym': 'G2',
#   'slug': 'g2-esports'},
#  {'team_id': '108203159356403647',
#   'name': 'Kwangdong Freecs Academy',
#   'acronym': 'KDF',
#   'slug': 'kwangdong-freecs-academy'},
#  {'team_id': '102141671184261103',
#   'name': 'Columbia College',
#   'acronym': 'CCL',
#   'slug': 'columbia-college'},
#  {'team_id': '99124844358677975',
#   'name': 'LEC All-Stars',
#   'acronym': 'LEC',
#   'slug': 'eu-lcs-allstars'},
#  {'team_id': '103240746431167117',
#   'name': 'Exosen',
#   'acronym': 'LST1',
#   'slug': 'exosen'},
#  {'team_id': '108517492697602721',
#   'name': 'Dewish Team',
#   'acronym': 'DWT',
#   'slug': 'dewish-team'},
#  {'team_id': '105537226118106446',
#   'name': 'Axolotl Esports',
#   'acronym': 'AXL',
#   'slug': 'axolotl'},
#  {'team_id': '106857755268998406',
#   'name': 'Resolve',
#   'acronym': 'RSV',
#   'slug': 'resolve'},
#  {'team_id': '109631610813971977',
#   'name': 'Mezexis Esports',
#   'acronym': 'MZS',
#   'slug': 'mezexis-esports'},
#  {'team_id': '103935421249833954',
#   'name': 'MAD Lions Madrid',
#   'acronym': 'MADM',
#   'slug': 'mad-lions-madrid'},
#  {'team_id': '106300533256999014',
#   'name': 'Starlan Gaming Club',
#   'acronym': 'SGC',
#   'slug': 'starlan-gaming-club'},
#  {'team_id': '105352091319919029',
#   'name': 'LCS Legends',
#   'acronym': 'LCSL',
#   'slug': 'lcs-legends'},
#  {'team_id': '101157821464777897',
#   'name': 'Team URF B',
#   'acronym': 'UFB',
#   'slug': 'team-urf-b'},
#  {'team_id': '101157821463139495',
#   'name': 'Team URF A',
#   'acronym': 'UFA',
#   'slug': 'team-urf-a'},
#  {'team_id': '109981644490281844',
#   'name': 'Rock Bottom Esports',
#   'acronym': 'ROCK',
#   'slug': 'rock-bottom-esports'},
#  {'team_id': '106302593752767294',
#   'name': 'Miners Academy',
#   'acronym': 'NMG',
#   'slug': 'netshoes-miners-academy'},
#  {'team_id': '100285330168091787',
#   'name': 'DetonatioN FocusMe',
#   'acronym': 'DFM',
#   'slug': 'detonation-focusme'},
#  {'team_id': '105593213115128994',
#   'name': 'Dark Tigers',
#   'acronym': 'DTG',
#   'slug': 'dark-tigers'},
#  {'team_id': '103877879209300619',
#   'name': 'Vipers Inc',
#   'acronym': 'VIP',
#   'slug': 'vipers-inc'},
#  {'team_id': '102141671185899507',
#   'name': 'University of Western Ontario',
#   'acronym': 'UWO',
#   'slug': 'university-of-western-ontario'},
#  {'team_id': '110534732558665825',
#   'name': 'Komodo',
#   'acronym': 'KMD',
#   'slug': 'komodo'},
#  {'team_id': '109485351596724390',
#   'name': 'Los Grandes Academy',
#   'acronym': 'LOS',
#   'slug': 'los-grandes-academy'},
#  {'team_id': '99124844355850858',
#   'name': 'LCS All-Stars',
#   'acronym': 'LCSS',
#   'slug': 'lcs-all-stars'},
#  {'team_id': '102787200153467923',
#   'name': 'BCN Squad',
#   'acronym': 'BCN',
#   'slug': 'bcn-squad'},
#  {'team_id': '102141671186685941',
#   'name': 'University of Waterloo',
#   'acronym': 'UW',
#   'slug': 'university-of-waterloo'},
#  {'team_id': '99566405129589291',
#   'name': 'Golden Guardians Challengers',
#   'acronym': 'GG',
#   'slug': 'gg-academy'},
#  {'team_id': '106806773698472633',
#   'name': 'Team Aze',
#   'acronym': 'AZE',
#   'slug': 'team-aze'},
#  {'team_id': '105913221137618666',
#   'name': 'No Org',
#   'acronym': 'NOR',
#   'slug': 'no-org'},
#  {'team_id': '109672446077514083',
#   'name': 'The Kings Moon',
#   'acronym': 'TKM',
#   'slug': 'the-kings-moon'},
#  {'team_id': '103461966965149786',
#   'name': 'MAD Lions',
#   'acronym': 'MAD',
#   'slug': 'mad-lions'},
#  {'team_id': '109783023470714128',
#   'name': 'Team Tony Top',
#   'acronym': 'TONY',
#   'slug': 'douyin-tony-top'},
#  {'team_id': '104710369093939895',
#   'name': 'SuppUp eSports',
#   'acronym': 'SSU',
#   'slug': 'suppup-esports'},
#  {'team_id': '103240746422450813',
#   'name': 'Closer',
#   'acronym': 'TCL2',
#   'slug': 'closer'},
#  {'team_id': '99566405124618295',
#   'name': 'Team Liquid Honda Challengers',
#   'acronym': 'TL',
#   'slug': 'tl-academy'},
#  {'team_id': '107598785733448849',
#   'name': 'River Plate Gaming',
#   'acronym': 'RIV',
#   'slug': 'river-plate-gaming'},
#  {'team_id': '108121047955658273',
#   'name': 'Aurelius Esports',
#   'acronym': 'AU',
#   'slug': 'aurelius-esports'},
#  {'team_id': '109981647134921596',
#   'name': 'CCG Esports',
#   'acronym': 'CCG',
#   'slug': 'ccg-esports'},
#  {'team_id': '99322214695067838',
#   'name': 'Team Vitality',
#   'acronym': 'VIT',
#   'slug': 'team-vitality'},
#  {'team_id': '102825747701670848',
#   'name': 'Azules Esports',
#   'acronym': 'UCH',
#   'slug': 'azules-esports'},
#  {'team_id': '99294153830557090',
#   'name': 'OpTic Gaming',
#   'acronym': 'OPT',
#   'slug': 'optic-gaming'},
#  {'team_id': '107700208463820785',
#   'name': 'Hurricane Gaming',
#   'acronym': 'HG',
#   'slug': 'hurricane-gaming'},
#  {'team_id': '103240746430053003',
#   'name': 'TheShy',
#   'acronym': 'CN1',
#   'slug': 'theshy'},
#  {'team_id': '101157821352457994',
#   'name': 'KR with Influencers',
#   'acronym': 'KRWI',
#   'slug': 'kr-with-influencers'},
#  {'team_id': '101428372605353526',
#   'name': 'Sengoku Gaming',
#   'acronym': 'SG',
#   'slug': 'sengoku-gaming'},
#  {'team_id': '102787200159169580',
#   'name': 'Godsent',
#   'acronym': 'GOD',
#   'slug': 'godsent'},
#  {'team_id': '103240746423564927',
#   'name': 'Nomanz',
#   'acronym': 'LCL1',
#   'slug': 'nomanz'},
#  {'team_id': '109485335453835911',
#   'name': 'Vivo Keyd Stars Academy',
#   'acronym': 'VKS',
#   'slug': 'vivo-keyd-stars-academy'},
#  {'team_id': '102787200129022886',
#   'name': 'eSuba',
#   'acronym': 'ESB',
#   'slug': 'esuba'},
#  {'team_id': '109480056092207899',
#   'name': 'FLUXO',
#   'acronym': 'FX',
#   'slug': 'fluxo'},
#  {'team_id': '105536952747658409',
#   'name': 'MKERS',
#   'acronym': 'MKS',
#   'slug': 'mkers'},
#  {'team_id': '99566406493155041',
#   'name': 'Machi Esports',
#   'acronym': 'MCX',
#   'slug': 'machi-esports'},
#  {'team_id': '106371176555003349',
#   'name': 'NK Osijek Esport',
#   'acronym': 'NKOS',
#   'slug': 'nk-osijek-esport'},
#  {'team_id': '110534700622694005',
#   'name': 'Aporia',
#   'acronym': 'APR',
#   'slug': 'aporia'},
#  {'team_id': '107423083507599175',
#   'name': 'Vanir',
#   'acronym': 'VNR',
#   'slug': 'vanir'},
#  {'team_id': '105514907449611976',
#   'name': 'Team BDS Academy',
#   'acronym': 'BDSA',
#   'slug': 'team-bds-academy'},
#  {'team_id': '100725845022060229',
#   'name': 'Liiv SANDBOX',
#   'acronym': 'LSB',
#   'slug': 'liiv-sandbox'},
#  {'team_id': '98926509892121852',
#   'name': 'FlyQuest',
#   'acronym': 'FLY',
#   'slug': 'flyquest'},
#  {'team_id': '107598788926820994',
#   'name': 'Macro Pampas',
#   'acronym': 'PAM',
#   'slug': 'pampas'},
#  {'team_id': '107581738783262346',
#   'name': 'Gravity Elite',
#   'acronym': 'GVE',
#   'slug': 'gravity-elite'},
#  {'team_id': '99566406338282437',
#   'name': 'ORDER',
#   'acronym': 'ORD',
#   'slug': 'order'},
#  {'team_id': '98767991916844003',
#   'name': 'Kaos Latin Gamers',
#   'acronym': 'KLG',
#   'slug': 'kaos-latin-gamers'},
#  {'team_id': '105537621677160078',
#   'name': 'Team Queso',
#   'acronym': 'TQ',
#   'slug': 'team-queso'},
#  {'team_id': '103240746427890311',
#   'name': 'Tian',
#   'acronym': 'CN4',
#   'slug': 'tian'},
#  {'team_id': '105550026570060790',
#   'name': 'DK Challengers',
#   'acronym': 'DK',
#   'slug': 'dwg-kia-challengers'},
#  {'team_id': '99294153828264740',
#   'name': '100 Thieves',
#   'acronym': '100',
#   'slug': '100-thieves'},
#  {'team_id': '102787200136756173',
#   'name': 'Berlin International Gaming',
#   'acronym': 'BIG',
#   'slug': 'berlin-international-gaming'},
#  {'team_id': '102804906460506452',
#   'name': 'Lowkey Esports',
#   'acronym': 'LK',
#   'slug': 'lowkey-esports'},
#  {'team_id': '105351835580819729',
#   'name': 'LCS Queue Kings',
#   'acronym': 'LCSQ',
#   'slug': 'lcs-queue-kings'},
#  {'team_id': '103240746433395345',
#   'name': 'Clid',
#   'acronym': 'KR2',
#   'slug': 'clid'},
#  {'team_id': '98767991930907107',
#   'name': 'Immortals Progressive',
#   'acronym': 'IMT',
#   'slug': 'immortals-progressive'},
#  {'team_id': '98926509883054987',
#   'name': 'Dignitas',
#   'acronym': 'DIG',
#   'slug': 'dignitas'},
#  {'team_id': '108439036582886702',
#   'name': 'BWE Esports',
#   'acronym': 'BWE',
#   'slug': 'byteway-esports'},
#  {'team_id': '107581284487120142',
#   'name': 'Six Karma',
#   'acronym': '6K',
#   'slug': 'six-karma'},
#  {'team_id': '106857724782292541',
#   'name': 'C9 Amateur',
#   'acronym': 'C9AM',
#   'slug': 'c9-amateur'},
#  {'team_id': '107467827374313054',
#   'name': 'Finetwork KOI',
#   'acronym': 'FNK',
#   'slug': 'finetwork-koi'},
#  {'team_id': '103461966971048042',
#   'name': 'Evil Geniuses Challengers',
#   'acronym': 'EG',
#   'slug': 'eg-academy'},
#  {'team_id': '99566408221114231',
#   'name': 'KaBuM! Esports',
#   'acronym': 'KBM',
#   'slug': 'kabum-esports'},
#  {'team_id': '105913111502565010',
#   'name': 'Zoos Gaming',
#   'acronym': 'ZOOS',
#   'slug': 'zoos-gaming'},
#  {'team_id': '104710383210356454',
#   'name': 'LowLandLions',
#   'acronym': 'LION',
#   'slug': 'lowlandlions'},
#  {'team_id': '105550036134585264',
#   'name': 'BRO Challengers',
#   'acronym': 'BRO',
#   'slug': 'bro-challengers'},
#  {'team_id': '109697683685398040',
#   'name': 'MAGAZA',
#   'acronym': 'MGZ',
#   'slug': 'magaza'},
#  {'team_id': '105549998884468136',
#   'name': 'paiN Academy',
#   'acronym': 'PNG',
#   'slug': 'pain-academy'},
#  {'team_id': '109783130654973406',
#   'name': 'Godel Gamers',
#   'acronym': 'GODL',
#   'slug': 'godel-gamers'},
#  {'team_id': '105301773561628001',
#   'name': 'LCK Legends',
#   'acronym': 'LCKL',
#   'slug': 'lcklegends'},
#  {'team_id': '101157821382267957',
#   'name': 'Sneaky',
#   'acronym': 'NA2',
#   'slug': 'sneaky'},
#  {'team_id': '109698030312834058',
#   'name': 'Genbu Gaming',
#   'acronym': 'GNGG',
#   'slug': 'genbu-gaming'},
#  {'team_id': '103535282140533402',
#   'name': 'BeÅŸiktaÅŸ Akademi',
#   'acronym': 'BJK',
#   'slug': 'besiktas-akademi'},
#  {'team_id': '105351737774956843',
#   'name': 'LPL Legends',
#   'acronym': 'LPLL',
#   'slug': 'lpl-legends'},
#  {'team_id': '107603544245460197',
#   'name': 'Ramo Awake Gaming',
#   'acronym': 'AWK',
#   'slug': 'awake-gaming'},
#  {'team_id': '106269859169658575',
#   'name': 'Impunity Esports',
#   'acronym': 'IMP',
#   'slug': 'impunity-esports'},
#  {'team_id': '107599040773840060',
#   'name': 'Meta Gaming',
#   'acronym': 'MG',
#   'slug': 'meta-gaming'},
#  {'team_id': '107251295460371069',
#   'name': 'Team Secret',
#   'acronym': 'TS',
#   'slug': 'team-secret'},
#  {'team_id': '109674808371974726',
#   'name': "Newell's Esports",
#   'acronym': 'NOB',
#   'slug': 'newells-esports'},
#  {'team_id': '109631326144414089',
#   'name': '19 Esports',
#   'acronym': '19',
#   'slug': '19-esports'},
#  {'team_id': '103535282146169523',
#   'name': 'Info YatÄ±rÄ±m Aurora Akademi',
#   'acronym': 'AUR',
#   'slug': 'info-yatrm-aurora-akademi'},
#  {'team_id': '101422616509070746',
#   'name': 'Galatasaray Espor',
#   'acronym': 'GS',
#   'slug': 'galatasaray-espor'},
#  {'team_id': '108203173414485265',
#   'name': 'HLE Academy',
#   'acronym': 'HLE',
#   'slug': 'hle-academy'},
#  {'team_id': '103240746421271163',
#   'name': 'Chippys',
#   'acronym': 'OCE1',
#   'slug': 'chippys'},
#  {'team_id': '103240746424613505',
#   'name': 'Goku',
#   'acronym': 'BR2',
#   'slug': 'goku'},
#  {'team_id': '98767991954244555',
#   'name': 'GAM Esports',
#   'acronym': 'GAM',
#   'slug': 'gam-esports'},
#  {'team_id': '109674814051390025',
#   'name': 'Primate',
#   'acronym': 'PMT',
#   'slug': 'primate'},
#  {'team_id': '104251016988118464',
#   'name': 'Galatasaray Espor Akademi',
#   'acronym': 'GS',
#   'slug': 'galatasaray-espor-akademi'},
#  {'team_id': '108159996371573462',
#   'name': 'Maryville University',
#   'acronym': 'MU',
#   'slug': 'maryville-university'},
#  {'team_id': '99566406334639907',
#   'name': 'Legacy Esports',
#   'acronym': 'LGC',
#   'slug': 'legacy-esports'},
#  {'team_id': '101157821417067613',
#   'name': 'G4',
#   'acronym': 'LST2',
#   'slug': 'g4'},
#  {'team_id': '106827823550343961',
#   'name': 'AXZ Academy',
#   'acronym': 'AXZ',
#   'slug': 'axz-academy'},
#  {'team_id': '102787200126663579',
#   'name': 'Giants',
#   'acronym': 'GIA',
#   'slug': 'giants'},
#  {'team_id': '106250732506012141',
#   'name': 'Umbra Divinus Gaming',
#   'acronym': 'UDGG',
#   'slug': 'umbra-divinus-gaming'},
#  {'team_id': '105397404796640412',
#   'name': 'LOUD',
#   'acronym': 'LLL',
#   'slug': 'loud'},
#  {'team_id': '105593182576105603',
#   'name': 'BRUTE',
#   'acronym': 'BRT',
#   'slug': 'brute'},
#  {'team_id': '105504044166670507',
#   'name': 'Unicorns of Love Sexy Edition',
#   'acronym': 'USE',
#   'slug': 'unicorns-of-love-sexy-edition'},
#  {'team_id': '99566405944694628',
#   'name': 'Pixel Esports Club',
#   'acronym': 'PIX',
#   'slug': 'pixel-esports-club'},
#  {'team_id': '99566405131343995',
#   'name': 'Echo Fox Academy',
#   'acronym': 'FOXA',
#   'slug': 'echo-fox-academy'},
#  {'team_id': '104710343016706538',
#   'name': '7more7 Pompa Team',
#   'acronym': 'PT7',
#   'slug': '7more7-pompa-team'},
#  {'team_id': '109981650516317055',
#   'name': 'Mirage Alliance',
#   'acronym': 'MIR',
#   'slug': 'mirage-alliance'},
#  {'team_id': '109642680932009857',
#   'name': 'Nord Esports',
#   'acronym': 'NORD',
#   'slug': 'nord-esports'},
#  {'team_id': '107581206998502078',
#   'name': 'Atheris Esports',
#   'acronym': 'ATH',
#   'slug': 'atheris-esports'},
#  {'team_id': '105520077508552574',
#   'name': 'Tricked Esport',
#   'acronym': 'TRC',
#   'slug': 'tricked-esport'},
#  {'team_id': '107598683861013570',
#   'name': 'Boca Juniors Gaming',
#   'acronym': 'BOC',
#   'slug': 'boca-juniors-gaming'},
#  {'team_id': '103240746436737687',
#   'name': 'Mikyx',
#   'acronym': 'EU3',
#   'slug': 'mikyx'},
#  {'team_id': '110733889090164854',
#   'name': 'Return of the Middlesticks',
#   'acronym': 'ROTM',
#   'slug': 'return-of-the-middlesticks'},
#  {'team_id': '105503535895066182',
#   'name': 'Wave Esports',
#   'acronym': 'WAVE',
#   'slug': 'wave-esports'},
#  {'team_id': '102787200145472495',
#   'name': 'Defusekids',
#   'acronym': 'DKI',
#   'slug': 'defusekids'},
#  {'team_id': '107456352597333899',
#   'name': 'NNO Prime',
#   'acronym': 'NNO',
#   'slug': 'noneedorga'},
#  {'team_id': '107564167676290839',
#   'name': 'Rebels',
#   'acronym': 'RBLS',
#   'slug': 'rebels-gaming'},
#  {'team_id': '109668849651338559',
#   'name': 'FENNEL',
#   'acronym': 'FL',
#   'slug': 'fennel'},
#  {'team_id': '107599112065439311',
#   'name': 'Dark Horse',
#   'acronym': 'DHX',
#   'slug': 'dark-horse'},
#  {'team_id': '105515266817621145',
#   'name': 'Team MCES',
#   'acronym': 'MCES',
#   'slug': 'team-mces'},
#  {'team_id': '103877891572305836',
#   'name': 'Team Singularity',
#   'acronym': 'SNG',
#   'slug': 'team-singularity'},
#  {'team_id': '103963715924353674',
#   'name': 'Dragon Army',
#   'acronym': 'DA',
#   'slug': 'dragon-army'},
#  {'team_id': '105521426070232498',
#   'name': 'Rejects Gaming',
#   'acronym': 'RJX',
#   'slug': 'rejects-gaming'},
#  {'team_id': '107574959289974368',
#   'name': 'Odivelas Sports Club',
#   'acronym': 'OSC',
#   'slug': 'odivelas-sports-club'},
#  {'team_id': '98767991853197861', 'name': 'T1', 'acronym': 'T1', 'slug': 't1'},
#  {'team_id': '99322214689444546',
#   'name': 'Schalke 04 Esports',
#   'acronym': 'S04',
#   'slug': 'schalke-04'},
#  {'team_id': '107598764318774383',
#   'name': 'KRÃœ Esports',
#   'acronym': 'KRU',
#   'slug': 'kru-esports'},
#  {'team_id': '104270958001747936',
#   'name': 'One Breath Gaming',
#   'acronym': 'OBG',
#   'slug': 'one-breath-gaming'},
#  {'team_id': '107575082591536093',
#   'name': 'Entropiq',
#   'acronym': 'EIQ',
#   'slug': 'entropiq'},
#  {'team_id': '107598878262940546',
#   'name': 'Malvinas Rise',
#   'acronym': 'MVG',
#   'slug': 'malvinas-gaming'},
#  {'team_id': '107467803833323099',
#   'name': 'Los Heretics',
#   'acronym': 'HRTS',
#   'slug': 'team-heretics-sl'},
#  {'team_id': '99322214691747156',
#   'name': 'Splyce',
#   'acronym': 'SPY',
#   'slug': 'splyce'},
#  {'team_id': '105519846782566525',
#   'name': 'MnM Gaming',
#   'acronym': 'MNM',
#   'slug': 'mnm-gaming'},
#  {'team_id': '105593311172904657',
#   'name': 'Eclot Gaming',
#   'acronym': 'ECT',
#   'slug': 'eclot-gaming'},
#  {'team_id': '109671413728531527',
#   'name': 'Pentagon Rejects',
#   'acronym': 'PTR',
#   'slug': 'pentagon-rejects'},
#  {'team_id': '99566406065437842',
#   'name': 'Dark Passage',
#   'acronym': 'DP',
#   'slug': 'dark-passage'},
#  {'team_id': '106827844148688268',
#   'name': 'SG Academy',
#   'acronym': 'SG',
#   'slug': 'sg-academy'},
#  {'team_id': '103878020539746273',
#   'name': 'EGN Esports',
#   'acronym': 'EGN',
#   'slug': 'egn-esports'},
#  {'team_id': '107655539755387391',
#   'name': 'Varona Esports',
#   'acronym': 'VAE',
#   'slug': 'varona-esports'},
#  {'team_id': '108159958519099117',
#   'name': 'Bay State College',
#   'acronym': 'BAY',
#   'slug': 'bay-state-college'},
#  {'team_id': '98767991882270868',
#   'name': 'SHANGHAI EDWARD GAMING HYCAN',
#   'acronym': 'EDG',
#   'slug': 'edward-gaming'},
#  {'team_id': '105536643047197642',
#   'name': 'NASR ESPORTS',
#   'acronym': 'NASR',
#   'slug': 'nasr-esports'},
#  {'team_id': '107581689894520368',
#   'name': 'Bandits Gaming',
#   'acronym': 'BAN',
#   'slug': 'bandits'},
#  {'team_id': '107599089191671351',
#   'name': 'Santiago Wanderers',
#   'acronym': 'SW',
#   'slug': 'santiago-wanderers'},
#  {'team_id': '107700211633200412',
#   'name': 'Meta Falcon Team',
#   'acronym': 'MFT',
#   'slug': 'meta-falcon-team'},
#  {'team_id': '107582150625414483',
#   'name': 'AceS GaminG',
#   'acronym': 'ACS',
#   'slug': 'aces-gaming'},
#  {'team_id': '108203166973601408',
#   'name': 'Liiv SANDBOX Academy',
#   'acronym': 'LSB',
#   'slug': 'liiv-sandbox-academy'},
#  {'team_id': '101157821432665199',
#   'name': 'Ceros',
#   'acronym': 'JP2',
#   'slug': 'ceros'},
#  {'team_id': '99566406066182955',
#   'name': 'GALAKTICOS',
#   'acronym': 'GAL',
#   'slug': 'galakticos'},
#  {'team_id': '102141671183409133',
#   'name': 'Maryville University',
#   'acronym': 'MU',
#   'slug': 'maryville-university'},
#  {'team_id': '99294153826603341',
#   'name': 'Clutch Gaming',
#   'acronym': 'CLU',
#   'slug': 'clutch-gaming'},
#  {'team_id': '109672618694070633',
#   'name': 'Aethernum Esports',
#   'acronym': 'AET',
#   'slug': 'aethernum-esports'},
#  {'team_id': '103240746440080029',
#   'name': 'Doinb',
#   'acronym': 'CN2',
#   'slug': 'doinb'},
#  {'team_id': '103240746432281231',
#   'name': 'Ziv',
#   'acronym': 'LMS2',
#   'slug': 'ziv'},
#  {'team_id': '103535282135552642',
#   'name': 'Papara SuperMassive Blaze Akademi',
#   'acronym': 'SMB',
#   'slug': 'papara-supermassive-blaze-akademi'},
#  {'team_id': '105520796734358045',
#   'name': 'Team 7AM',
#   'acronym': '7AM',
#   'slug': 'team-7am'},
#  {'team_id': '100725845018863243',
#   'name': 'Dplus Kia',
#   'acronym': 'DK',
#   'slug': 'dwg-kia'},
#  {'team_id': '108352305932141947',
#   'name': 'DSYRE',
#   'acronym': 'DSYR',
#   'slug': 'dsyre'},
#  {'team_id': '109485342651298305',
#   'name': 'FLUXO Academy',
#   'acronym': 'FX',
#   'slug': 'fluxo-academy'},
#  {'team_id': '103963753080578719',
#   'name': 'CrowCrowd Moscow',
#   'acronym': 'CC',
#   'slug': 'crowcrowd-moscow'},
#  {'team_id': '99566406494784730',
#   'name': 'MAD Team',
#   'acronym': 'MADD',
#   'slug': 'mad-team'},
#  {'team_id': '107580497041999074',
#   'name': 'Team Ambition',
#   'acronym': 'TA',
#   'slug': 'team-ambition'},
#  {'team_id': '99566404846951820',
#   'name': 'LGD GAMING',
#   'acronym': 'LGD',
#   'slug': 'lgd-gaming'},
#  {'team_id': '101428372602011186',
#   'name': 'V3 Esports',
#   'acronym': 'V3',
#   'slug': 'v3-esports'},
#  {'team_id': '107581761958954646',
#   'name': 'Vandals Esports',
#   'acronym': 'VAN',
#   'slug': 'vandals-esports'},
#  {'team_id': '106857739520697600',
#   'name': '100 Next',
#   'acronym': '100X',
#   'slug': '100-next'},
#  {'team_id': '106334802515490809',
#   'name': 'Wortex',
#   'acronym': 'WTX',
#   'slug': 'wortex'},
#  {'team_id': '103877908090914662',
#   'name': 'Kenty',
#   'acronym': 'KEN',
#   'slug': 'kenty'},
#  {'team_id': '103240746438900379',
#   'name': 'Bolulu',
#   'acronym': 'TCL1',
#   'slug': 'bolulu'},
#  {'team_id': '101428372607057464',
#   'name': 'AXIZ',
#   'acronym': 'AXZ',
#   'slug': 'axiz'},
#  {'team_id': '105913238372341488',
#   'name': 'Wildcard',
#   'acronym': 'WC',
#   'slug': 'wildcard-gaming'},
#  {'team_id': '109539776003058530',
#   'name': 'Alior Bank Team',
#   'acronym': 'AB',
#   'slug': 'alior-bank-team'},
#  {'team_id': '107456994699991548',
#   'name': 'Atleta Esport',
#   'acronym': 'ATE',
#   'slug': 'atleta-esport'},
#  {'team_id': '103535282119620510',
#   'name': 'Fukuoka SoftBank HAWKS gaming',
#   'acronym': 'SHG',
#   'slug': 'fukuoka-softbank-hawks-gaming'},
#  {'team_id': '103240746426776197',
#   'name': 'Shrimp',
#   'acronym': 'BR1',
#   'slug': 'shrimp'},
#  {'team_id': '101383792887446028',
#   'name': 'MAMMOTH',
#   'acronym': 'MEC',
#   'slug': 'mammoth'},
#  {'team_id': '110492173877838150',
#   'name': 'Eternal Fire',
#   'acronym': 'EF',
#   'slug': 'eternal-fire'},
#  {'team_id': '109981655738221109',
#   'name': 'Team Plink',
#   'acronym': 'CAT',
#   'slug': 'team-plink'},
#  {'team_id': '107582598621022934',
#   'name': 'Club Deportivo Municipal',
#   'acronym': 'CDM',
#   'slug': 'club-deportivo-municipal'},
#  {'team_id': '107582173169864040',
#   'name': 'GeekSide Esports',
#   'acronym': 'GSE',
#   'slug': 'geekside-esports'},
#  {'team_id': '106302119383559530',
#   'name': 'Galaxy Racer',
#   'acronym': 'GXR',
#   'slug': 'galaxy-racer'},
#  {'team_id': '101157821399635017',
#   'name': 'Bang',
#   'acronym': 'NA1',
#   'slug': 'bang'},
#  {'team_id': '103461966975897718',
#   'name': 'Immortals Progressive Challengers',
#   'acronym': 'IMT',
#   'slug': 'imt-academy'},
#  {'team_id': '107582157086477662',
#   'name': 'Descuydado Aucas Esports',
#   'acronym': 'DSC',
#   'slug': 'descuydado-esports'},
#  {'team_id': '105536738266035235',
#   'name': 'Cyberground Gaming',
#   'acronym': 'CGG',
#   'slug': 'cyberground-gaming'},
#  {'team_id': '99566408217955692',
#   'name': 'paiN Gaming',
#   'acronym': 'PNG',
#   'slug': 'pain-gaming'},
#  {'team_id': '109676337359108345',
#   'name': 'Eclipse Gaming',
#   'acronym': 'ECG',
#   'slug': 'eclipse-gaming'},
#  {'team_id': '105536918475957734',
#   'name': 'Macko Esports',
#   'acronym': 'MCK',
#   'slug': 'macko-esports'},
#  {'team_id': '109698026697016325',
#   'name': 'Barcelona BG',
#   'acronym': 'BBG',
#   'slug': 'barcelona-bg'},
#  {'team_id': '107599144012469862',
#   'name': 'Maze Gaming',
#   'acronym': 'MAZ',
#   'slug': 'maze-gaming'},
#  {'team_id': '103877774634323825',
#   'name': 'YDN Gamers',
#   'acronym': 'YDN',
#   'slug': 'ydn-gamers'},
#  {'team_id': '103461966951059521',
#   'name': 'Evil Geniuses LG',
#   'acronym': 'EG',
#   'slug': 'evil-geniuses'},
#  {'team_id': '109696092218588987',
#   'name': 'Nigma Galaxy',
#   'acronym': 'NGX',
#   'slug': 'nigma-galaxy'},
#  {'team_id': '103535282138043022',
#   'name': 'FenerbahÃ§e Espor Akademi',
#   'acronym': 'FB',
#   'slug': 'fenerbahce-espor-akademi'},
#  {'team_id': '108203169709977541',
#   'name': 'BRO Academy',
#   'acronym': 'BRO',
#   'slug': 'fredit-brion-academy'},
#  {'team_id': '107603548241713732',
#   'name': 'Braves Rising',
#   'acronym': 'BRR',
#   'slug': 'braves-rising'},
#  {'team_id': '105520781900097659',
#   'name': '4 Elements',
#   'acronym': '4E',
#   'slug': '4-elements'},
#  {'team_id': '99566405688134373',
#   'name': 'Besiktasarchive',
#   'acronym': 'BJKK',
#   'slug': 'besiktasarchive'},
#  {'team_id': '104016416551172375',
#   'name': 'Seorabeol Gaming',
#   'acronym': 'SRB',
#   'slug': 'seorabeol-gaming'},
#  {'team_id': '103240746437786265',
#   'name': 'Bwipo',
#   'acronym': 'EU4',
#   'slug': 'bwipo'},
#  {'team_id': '107416342401528388',
#   'name': 'Maturalni Forsaken',
#   'acronym': 'MFSK',
#   'slug': 'forsaken'},
#  {'team_id': '109704625422425316',
#   'name': 'Benelux United',
#   'acronym': 'BLX',
#   'slug': 'benelux-united'},
#  {'team_id': '103877625775457850',
#   'name': 'Movistar Riders',
#   'acronym': 'MRS',
#   'slug': 'movistar-riders'},
#  {'team_id': '99566408217116828',
#   'name': 'INTZ',
#   'acronym': 'ITZ',
#   'slug': 'intz'},
#  {'team_id': '108159890692353756',
#   'name': 'St. Clair College',
#   'acronym': 'SCC',
#   'slug': 'st-clair-college'},
#  {'team_id': '108319257932089006',
#   'name': 'Osaka',
#   'acronym': 'OSK',
#   'slug': 'osaka'},
#  {'team_id': '110425005562048945',
#   'name': 'Keypulse Esports',
#   'acronym': 'KYP',
#   'slug': 'keypulse-esports'},
#  {'team_id': '100205576309502431',
#   'name': 'FURIA',
#   'acronym': 'FUR',
#   'slug': 'furia'},
#  {'team_id': '109783124183318312',
#   'name': 'University of St. Trevor',
#   'acronym': 'UST',
#   'slug': 'university-of-st-trevor'},
#  {'team_id': '101383793567806688',
#   'name': 'SK Gaming',
#   'acronym': 'SK',
#   'slug': 'sk-gaming'},
#  {'team_id': '101157821349705475',
#   'name': 'CN with Influencers',
#   'acronym': 'CNWI',
#   'slug': 'cn-with-influencers'},
#  {'team_id': '106421708401759879',
#   'name': 'Black Star Gaming',
#   'acronym': 'BSGG',
#   'slug': 'black-star-gaming'},
#  {'team_id': '110733870612047344',
#   'name': 'Team Coachify',
#   'acronym': 'CFY',
#   'slug': 'team-coachify'},
#  {'team_id': '107251941920386009',
#   'name': 'BTS ESPORTS',
#   'acronym': 'SKY',
#   'slug': 'bts-esports'},
#  {'team_id': '107582178455767077',
#   'name': 'Pirate Dream',
#   'acronym': 'PD',
#   'slug': 'pirate-dream'},
#  {'team_id': '98767991892579754',
#   'name': 'Royal Never Give Up',
#   'acronym': 'RNG',
#   'slug': 'royal-never-give-up'},
#  {'team_id': '107179740624168899',
#   'name': 'HEET',
#   'acronym': 'HEET',
#   'slug': 'heet'},
#  {'team_id': '105521412995449549',
#   'name': 'Team ESCA Gaming',
#   'acronym': 'ESCA',
#   'slug': 'team-esca-gaming'},
#  {'team_id': '107416483509696259',
#   'name': 'Eintracht Spandau',
#   'acronym': 'EINS',
#   'slug': 'eintracht-spandau'},
#  {'team_id': '102787200130988976',
#   'name': 'ASUS ROG Elite',
#   'acronym': 'ASUS',
#   'slug': 'asus-rog-elite'},
#  {'team_id': '99124844362174905',
#   'name': 'TCL All-Stars',
#   'acronym': 'TCL',
#   'slug': 'all-stars-tur'},
#  {'team_id': '104710682193583854',
#   'name': 'Topo Centras Iron Wolves',
#   'acronym': 'WOLF',
#   'slug': 'topo-centras-iron-wolves'},
#  {'team_id': '110534714934488523',
#   'name': 'CB Gaming',
#   'acronym': 'CBG',
#   'slug': 'cb-gaming'},
#  {'team_id': '107581287168722290',
#   'name': 'The Kings',
#   'acronym': 'TK',
#   'slug': 'the-kings'},
#  {'team_id': '107581300297680248',
#   'name': 'Zylant Esports',
#   'acronym': 'ZLT',
#   'slug': 'zylant-esports'},
#  {'team_id': '99124844361058275',
#   'name': 'CBLOL All-Stars',
#   'acronym': 'BR',
#   'slug': 'all-stars-cblol'},
#  {'team_id': '110418022381234710',
#   'name': 'SPIKE Syndicate',
#   'acronym': 'SPK',
#   'slug': 'spike-syndicate'},
#  {'team_id': '109642690191894407',
#   'name': 'Ruddy Esports',
#   'acronym': 'RUD',
#   'slug': 'ruddy-esports'},
#  {'team_id': '104843437139220481',
#   'name': 'Undead BK',
#   'acronym': 'UBK',
#   'slug': 'undead-bk'},
#  {'team_id': '109698855806033734',
#   'name': 'Universitario Esports',
#   'acronym': 'UE',
#   'slug': 'universitario-esports'},
#  {'team_id': '98767991949608898',
#   'name': 'FenerbahÃ§e Espor',
#   'acronym': 'FB',
#   'slug': 'fenerbahce-espor'},
#  {'team_id': '103877976717529187',
#   'name': 'Intrepid Fox Gaming',
#   'acronym': 'IF',
#   'slug': 'intrepid-fox-gaming'},
#  {'team_id': '101428372603715124',
#   'name': 'Crest Gaming Act',
#   'acronym': 'CGA',
#   'slug': 'crest-gaming-act'},
#  {'team_id': '105549984475833252',
#   'name': 'Cruzeiro Academy',
#   'acronym': 'CRZA',
#   'slug': 'cruzeiro-academy'},
#  {'team_id': '105193481874236222',
#   'name': 'LCL-All-Stars',
#   'acronym': 'LCL',
#   'slug': 'lcl-all-stars'},
#  {'team_id': '101157821425652839',
#   'name': 'Plugo',
#   'acronym': 'LLA1',
#   'slug': 'plugo'},
#  {'team_id': '103240746435623573',
#   'name': 'CoreJJ',
#   'acronym': 'NA3',
#   'slug': 'corejj'},
#  {'team_id': '109692074894483834',
#   'name': 'West Point Esports',
#   'acronym': 'WP',
#   'slug': 'sem9-wpe'},
#  {'team_id': '101428372600307248',
#   'name': 'Rascal Jester',
#   'acronym': 'RJ',
#   'slug': 'rascal-jester'},
#  {'team_id': '107581755241449104',
#   'name': 'Red Rooster',
#   'acronym': 'RRR',
#   'slug': 'red-rooster'},
#  {'team_id': '103935468920814040',
#   'name': 'Team GO',
#   'acronym': 'GO',
#   'slug': 'gamersorigin'},
#  {'team_id': '101383793569248484',
#   'name': 'Astralis',
#   'acronym': 'AST',
#   'slug': 'astralis'},
#  {'team_id': '109631614501223948',
#   'name': 'War Legion Esports',
#   'acronym': 'WLE',
#   'slug': 'war-legion-esports'},
#  {'team_id': '104212474149188693',
#   'name': 'Altokekw EspaÃ±ita',
#   'acronym': 'OLE',
#   'slug': 'lvp'},
#  {'team_id': '110733881542862348',
#   'name': 'Cold Hearted',
#   'acronym': 'COLD',
#   'slug': 'cold-hearted'},
#  {'team_id': '107179722233063345',
#   'name': 'Cryptova',
#   'acronym': 'OVA',
#   'slug': 'cryptova'},
#  {'team_id': '99566408358330419',
#   'name': 'Isurus',
#   'acronym': 'ISG',
#   'slug': 'isurus'},
#  {'team_id': '102787200138722262',
#   'name': 'Devils.One',
#   'acronym': 'DV1',
#   'slug': 'devilsone'},
#  {'team_id': '107467834753797729',
#   'name': 'Bisons',
#   'acronym': 'BSO',
#   'slug': 'bisons-eclub'},
#  {'team_id': '107603586980602718',
#   'name': 'NOCTA',
#   'acronym': 'NOC',
#   'slug': 'nocta'},
#  {'team_id': '105547976546505145',
#   'name': 'Team Infamous',
#   'acronym': 'IFM',
#   'slug': 'team-infamous'},
#  {'team_id': '106857734387052095',
#   'name': 'AOE Gold',
#   'acronym': 'AOE',
#   'slug': 'aoe-esports'},
#  {'team_id': '100205576307813373',
#   'name': 'Flamengo ',
#   'acronym': 'FLA',
#   'slug': 'flamengo-esports'},
#  {'team_id': '105520786527322647',
#   'name': 'KRC Genk Esports',
#   'acronym': 'GENK',
#   'slug': 'krc-genk-esports'},
#  {'team_id': '108448995754333242',
#   'name': 'webidoo Gaming',
#   'acronym': 'WBD',
#   'slug': 'webidoo-gaming'},
#  {'team_id': '107603596915629288',
#   'name': 'Spirituals',
#   'acronym': 'STS',
#   'slug': 'spirituals'},
#  {'team_id': '107598780504331406',
#   'name': 'Maycam Evolve',
#   'acronym': 'EV',
#   'slug': 'maycam-evolve'},
#  {'team_id': '100289931264192378',
#   'name': 'Team Spirit',
#   'acronym': 'TSPT',
#   'slug': 'team-spirit'},
#  {'team_id': '98767991940181526',
#   'name': 'Misfits Gaming',
#   'acronym': 'MSF',
#   'slug': 'misfits-gaming'},
#  {'team_id': '102787200155434012',
#   'name': 'JD|XL',
#   'acronym': 'JDXL',
#   'slug': 'jdxl'},
#  {'team_id': '109783149221216052',
#   'name': 'Lit Esports',
#   'acronym': 'LIT',
#   'slug': 'lit-esports'},
#  {'team_id': '106371141659311452',
#   'name': 'Valiance PRO GAME',
#   'acronym': 'VPG',
#   'slug': 'valiance-pro-game'},
#  {'team_id': '105520784254806142',
#   'name': 'ION SQUAD',
#   'acronym': 'ION',
#   'slug': 'ion-squad'},
#  {'team_id': '108203154514683518',
#   'name': 'T1 Rookies',
#   'acronym': 'T1',
#   'slug': 't1-rookies'},
#  {'team_id': '105520816474194464',
#   'name': 'Dynasty',
#   'acronym': 'DYN',
#   'slug': 'dynasty'},
#  {'team_id': '99566408219409348',
#   'name': 'Vivo Keyd Stars',
#   'acronym': 'VKS',
#   'slug': 'vivo-keyd'},
#  {'team_id': '104710354840711661',
#   'name': 'Riddle Esports',
#   'acronym': 'RDL',
#   'slug': 'riddle'},
#  {'team_id': '107582613263241138',
#   'name': 'Deliverance Esports',
#   'acronym': 'DVE',
#   'slug': 'deliverance-esports'},
#  {'team_id': '105709099258505657',
#   'name': 'PEACE',
#   'acronym': 'PCE',
#   'slug': 'peace'},
#  {'team_id': '101157821401338955',
#   'name': 'Peanut',
#   'acronym': 'KR3',
#   'slug': 'peanut'},
#  {'team_id': '107760667929003738',
#   'name': 'Frank Esports',
#   'acronym': 'FAK',
#   'slug': 'frank-esports'},
#  {'team_id': '107565493716773932',
#   'name': 'Nativz',
#   'acronym': 'NTZ',
#   'slug': 'nativz'},
#  {'team_id': '109783136441695429',
#   'name': 'Mirage',
#   'acronym': 'MRGE',
#   'slug': 'mirage'},
#  {'team_id': '105519945593890595',
#   'name': 'KOVA Esports',
#   'acronym': 'KOVA',
#   'slug': 'kova-esports'},
#  {'team_id': '107603554304287575',
#   'name': 'King of Goats',
#   'acronym': 'KOG',
#   'slug': 'king-of-goats'},
#  {'team_id': '105520826536746180',
#   'name': 'Team THRLL',
#   'acronym': 'TRL',
#   'slug': 'team-thrll'},
#  {'team_id': '110534696811298545',
#   'name': 'Apex Mission Impossible',
#   'acronym': 'AMI',
#   'slug': 'apex-mission-impossible'},
#  {'team_id': '110506938087991033',
#   'name': 'FL Academy',
#   'acronym': 'FL',
#   'slug': 'fl-academy'},
#  {'team_id': '107580475800733004',
#   'name': 'Third Party',
#   'acronym': '3P',
#   'slug': 'third-party'},
#  {'team_id': '109480204628225868',
#   'name': 'Los Grandes',
#   'acronym': 'LOS',
#   'slug': 'los-grandes'},
#  {'team_id': '110383487456480967',
#   'name': 'Vertex ESC',
#   'acronym': 'VTX',
#   'slug': 'vertex-esc'},
#  {'team_id': '110425157952111645',
#   'name': 'Fourth Wall',
#   'acronym': '4W',
#   'slug': 'fourth-wall'},
#  {'team_id': '104841890701948065',
#   'name': 'Estral Esports',
#   'acronym': 'EST',
#   'slug': 'estral-esports'},
#  {'team_id': '108573042084687884',
#   'name': 'TEAM WHALES',
#   'acronym': 'TW',
#   'slug': 'team-whales'},
#  {'team_id': '105543843212923183',
#   'name': 'Goskilla',
#   'acronym': 'GSK',
#   'slug': 'goskilla'},
#  {'team_id': '99124844353216570',
#   'name': 'LCK All-Stars',
#   'acronym': 'LCK',
#   'slug': 'lck-allstars'},
#  {'team_id': '103495716836203404',
#   'name': '5 Ronin',
#   'acronym': '5R',
#   'slug': '5-ronin'},
#  {'team_id': '99566406332987990',
#   'name': 'The Chiefs',
#   'acronym': 'CHF',
#   'slug': 'the-chiefs'},
#  {'team_id': '102141671181705193',
#   'name': 'Michigan State University',
#   'acronym': 'MSU',
#   'slug': 'michigan-state-university'},
#  {'team_id': '105521451717484016',
#   'name': 'Hive Athens EC',
#   'acronym': 'HIVE',
#   'slug': 'hive-athens-ec'},
#  {'team_id': '102787200123059082',
#   'name': 'Team LDLC',
#   'acronym': 'LDLX',
#   'slug': 'team-ldlc'},
#  {'team_id': '103240746441194143',
#   'name': 'Fofo',
#   'acronym': 'LMS1',
#   'slug': 'fofo'},
#  {'team_id': '109696138543579708',
#   'name': '3BL Esports',
#   'acronym': '3BL',
#   'slug': 'ebl-esports'},
#  {'team_id': '108404211655217274',
#   'name': 'Partizan Esports',
#   'acronym': 'PAR',
#   'slug': 'partizan-esports'},
#  {'team_id': '107067065368380132',
#   'name': 'Wild Panthers Esports',
#   'acronym': 'WPE',
#   'slug': 'wild-panther-esports'},
#  {'team_id': '99566404853058754',
#   'name': 'WeiboGaming FAW AUDI',
#   'acronym': 'WBG',
#   'slug': 'weibo-gaming'},
#  {'team_id': '105521674055625312',
#   'name': 'Gamespace Mediterranean College Esports',
#   'acronym': 'GSMC',
#   'slug': 'gamespace-mediterranean-college-esports'},
#  {'team_id': '107581750701049485',
#   'name': 'Janus Esports',
#   'acronym': 'JNS',
#   'slug': 'janus-esports'},
#  {'team_id': '107581212180071788',
#   'name': 'Peek Gaming',
#   'acronym': 'PK',
#   'slug': 'peek-gaming'},
#  {'team_id': '107597870621708485',
#   'name': 'Cyber Wolves Esports',
#   'acronym': 'CWE',
#   'slug': 'cyber-wolves-esports'},
#  {'team_id': '105357804699574324',
#   'name': 'CoreJJ Dream Team',
#   'acronym': 'CJJ',
#   'slug': 'corejj-dream-team'},
#  {'team_id': '107251245690956393',
#   'name': 'Saigon Buffalo Esports',
#   'acronym': 'SGB',
#   'slug': 'saigon-buffalo-esports'},
#  {'team_id': '107450819235010833',
#   'name': 'BK ROG Esports',
#   'acronym': 'BKR',
#   'slug': 'bkrog-gamerorigin'},
#  {'team_id': '105594116005157262',
#   'name': 'OFFSET Esports',
#   'acronym': 'OFF7',
#   'slug': 'offset-esports'},
#  {'team_id': '103935567188806885',
#   'name': 'Energypot Wizards',
#   'acronym': 'EWIZ',
#   'slug': 'energypot-wizards'},
#  {'team_id': '102825747707503563',
#   'name': 'MAD Lions E.C. Colombia',
#   'acronym': 'MADC',
#   'slug': 'mad-lions-ec-colombia'},
#  {'team_id': '103240746416552563',
#   'name': 'Team URF C',
#   'acronym': 'UFC',
#   'slug': 'team-urf-c'},
#  {'team_id': '109981678167856017',
#   'name': 'Miracle',
#   'acronym': 'MRC',
#   'slug': 'miracle'},
#  {'team_id': '99566404855553726',
#   'name': 'FunPlus Phoenix',
#   'acronym': 'FPX',
#   'slug': 'funplus-phoenix'},
#  {'team_id': '105537149834356301',
#   'name': 'Anc Outplayed',
#   'acronym': 'OP',
#   'slug': 'anc-outplayed'},
#  {'team_id': '105537444152141556',
#   'name': 'Herbalife Real Betis',
#   'acronym': 'BTS',
#   'slug': 'herbalife-real-betis'},
#  {'team_id': '108203164850614211',
#   'name': 'NS REDFORCE Academy',
#   'acronym': 'NS',
#   'slug': 'ns-redforce-academy'},
#  {'team_id': '108078422885368642',
#   'name': 'Panathinaikos Esports',
#   'acronym': 'PAO',
#   'slug': 'panathinaikos-esports'},
#  {'team_id': '109523293035238887',
#   'name': 'Aegis',
#   'acronym': 'AEG',
#   'slug': 'aegis'},
#  {'team_id': '99566408561605102',
#   'name': 'XTEN Esports',
#   'acronym': 'XTN',
#   'slug': 'xten-esports'},
#  {'team_id': '108361550364038935',
#   'name': 'AOE Randoms',
#   'acronym': 'AOER',
#   'slug': 'aoe-randoms'},
#  {'team_id': '105193571520283762',
#   'name': 'OPL All-Stars',
#   'acronym': 'OPLO',
#   'slug': 'opl-all-stars'},
#  {'team_id': '105553606349477427',
#   'name': 'Zero Tenacity',
#   'acronym': 'Z10',
#   'slug': 'zero-tenacity'},
#  {'team_id': '105549997263803379',
#   'name': 'LOUD Academy',
#   'acronym': 'LLL',
#   'slug': 'loud-academy'},
#  {'team_id': '108361563004344389',
#   'name': 'The Last Dance',
# ...
#   'slug': 'atomic-esports'},
#  {'team_id': '107599188771591359',
#   'name': 'Wolf Club Gaming',
#   'acronym': 'WCE',
#   'slug': 'wolf-club-gaming'},
#  {'team_id': '107456419134134246',
#   'name': 'Astralis Talent',
#   'acronym': 'ASTL',
#   'slug': 'astralis-talent'},
#  {'team_id': '103240746393642312',
#   'name': 'All-Stars Blue',
#   'acronym': 'ASB',
#   'slug': 'pro-showdown-a'},
#  {'team_id': '99566404852189289',
#   'name': 'Beijing JDG Intel Esports Club',
#   'acronym': 'JDG',
#   'slug': 'jd-gaming'},
#  {'team_id': '106827839261303409',
#   'name': 'CGA  Academy',
#   'acronym': 'CGA',
#   'slug': 'cga-academy'},
#  {'team_id': '109695924147263860',
#   'name': 'Triple Esports',
#   'acronym': 'TE',
#   'slug': 'triple-esports'},
#  {'team_id': '100205576949530558',
#   'name': 'Bursaspor Esports',
#   'acronym': 'BURA',
#   'slug': 'bursaspor-esports'},
#  {'team_id': '101157821397865543',
#   'name': 'Faker',
#   'acronym': 'KR1',
#   'slug': 'faker'},
#  {'team_id': '106382545123328648',
#   'name': 'Dynamo Eclot',
#   'acronym': 'DNE',
#   'slug': 'dynamo-eclot'},
#  {'team_id': '105549991104165282',
#   'name': 'FURIA Academy',
#   'acronym': 'FUR',
#   'slug': 'furia-academy'},
#  {'team_id': '107598982142057588',
#   'name': 'Cruzados Esports',
#   'acronym': 'UC',
#   'slug': 'cruzados-esports'},
#  {'team_id': '104228817622043824',
#   'name': 'The French Zoo',
#   'acronym': 'FZO',
#   'slug': 'the-french-zoo'},
#  {'team_id': '99566404579461230',
#   'name': 'kt Rolster',
#   'acronym': 'KT',
#   'slug': 'kt-rolster'},
#  {'team_id': '105550001032913831',
#   'name': 'RED Academy',
#   'acronym': 'RED',
#   'slug': 'red-academy'},
#  {'team_id': '98926509887041994',
#   'name': 'Echo Fox',
#   'acronym': 'FOX2',
#   'slug': 'echo-fox'},
#  {'team_id': '102747101565183056',
#   'name': 'NongShim REDFORCE',
#   'acronym': 'NS',
#   'slug': 'nongshim-redforce'},
#  {'team_id': '105554088239949229',
#   'name': 'x25 Esports',
#   'acronym': 'X25',
#   'slug': 'x25-esports'},
#  {'team_id': '103240746396067146',
#   'name': 'All-Stars Red',
#   'acronym': 'ASR',
#   'slug': 'pro-showdown-b'},
#  {'team_id': '104212455500985426',
#   'name': 'LEC Kings',
#   'acronym': 'RITO',
#   'slug': 'lec-team'},
#  {'team_id': '98767991877340524',
#   'name': 'Cloud9',
#   'acronym': 'C9',
#   'slug': 'cloud9'},
#  {'team_id': '103461966981927044',
#   'name': 'Dignitas Challengers',
#   'acronym': 'DIG',
#   'slug': 'dig-academy'},
#  {'team_id': '107580481273119961',
#   'name': 'Taco Gaming',
#   'acronym': 'TG',
#   'slug': 'taco-gaming'},
#  {'team_id': '102787200132955066',
#   'name': 'FTW Esports',
#   'acronym': 'FTW',
#   'slug': 'for-the-win-esports'},
#  {'team_id': '103495716886587312',
#   'name': 'BeÅŸiktaÅŸ',
#   'acronym': 'BJK',
#   'slug': 'besiktas'},
#  {'team_id': '108361552741927561',
#   'name': 'Cincinnati Fear',
#   'acronym': 'FEAR',
#   'slug': 'cincinnati-fear'},
#  {'team_id': '107597866344501908',
#   'name': 'Auxesis Esports',
#   'acronym': 'AUX',
#   'slug': 'auxesis-esports'},
#  {'team_id': '105532840001188717',
#   'name': 'S2V Esports',
#   'acronym': 'S2V',
#   'slug': 's2v-esports'},
#  {'team_id': '105549995617170853',
#   'name': 'KaBuM! Academy',
#   'acronym': 'KBM',
#   'slug': 'kabum-academy'},
#  {'team_id': '108565997404381643',
#   'name': 'Tempest Gaming',
#   'acronym': 'TPG',
#   'slug': 'tempest-gaming'},
#  {'team_id': '107597875833524424',
#   'name': 'Diamant Esports',
#   'acronym': 'DIA',
#   'slug': 'diamant-esports'},
#  {'team_id': '107423075317119707',
#   'name': 'X7',
#   'acronym': 'X7',
#   'slug': 'x7'},
#  {'team_id': '108203161924300737',
#   'name': 'DRX Academy',
#   'acronym': 'DRX',
#   'slug': 'drx-academy'},
#  {'team_id': '102787200134790084',
#   'name': 'HMA Fnatic Rising',
#   'acronym': 'FNCR',
#   'slug': 'hma-fnatic-rising'},
#  {'team_id': '105663527959374033',
#   'name': 'CTRL PLAY Team',
#   'acronym': 'CPT',
#   'slug': 'ctrl-play-team'},
#  {'team_id': '103240746442308257',
#   'name': 'Optimus',
#   'acronym': 'VCS1',
#   'slug': 'optimus'},
#  {'team_id': '110733864366329081',
#   'name': 'Team E Turner',
#   'acronym': 'TET',
#   'slug': 'team-e-turner'},
#  {'team_id': '105957640798249312',
#   'name': 'Barrage.NA',
#   'acronym': 'BRG',
#   'slug': 'barragena'},
#  {'team_id': '100205573496804586',
#   'name': 'Hanwha Life Esports',
#   'acronym': 'HLE',
#   'slug': 'hanwha-life-esports'},
#  {'team_id': '107648168744912288',
#   'name': 'DREN Esports',
#   'acronym': 'DREN',
#   'slug': 'dren-esports'},
#  {'team_id': '106827848618374543',
#   'name': 'BC Academy',
#   'acronym': 'BC',
#   'slug': 'bc-academy'},
#  {'team_id': '107437032053655867',
#   'name': 'Kanga Esports',
#   'acronym': 'KNG',
#   'slug': 'kanga-esports'},
#  {'team_id': '105520788833075738',
#   'name': 'KV Mechelen Esports',
#   'acronym': 'KVM',
#   'slug': 'kv-mechelen-esports'},
#  {'team_id': '109699038581250169',
#   'name': 'Red Eyes Esports',
#   'acronym': 'RDY',
#   'slug': 'red-eyes-esports'},
#  {'team_id': '105550047979361273',
#   'name': 'HLE Challengers',
#   'acronym': 'HLE',
#   'slug': 'hle-challengers'},
#  {'team_id': '105553729458550723',
#   'name': 'Nexus KTRL',
#   'acronym': 'NXK',
#   'slug': 'nexus-ktrl'},
#  {'team_id': '102141671187668983',
#   'name': 'NC State University',
#   'acronym': 'NCSU',
#   'slug': 'nc-state-university'},
#  {'team_id': '102787200151698443',
#   'name': 'Vitality.Bee',
#   'acronym': 'VITB',
#   'slug': 'vitalitybee'},
#  {'team_id': '110428362822825796',
#   'name': 'Disguised',
#   'acronym': 'DSG',
#   'slug': 'disguised'},
#  {'team_id': '107580455322240324',
#   'name': 'No Team',
#   'acronym': 'NOT',
#   'slug': 'no-team'},
#  {'team_id': '108160026618060825',
#   'name': 'UCI Esports',
#   'acronym': 'UCI',
#   'slug': 'uci-esports'},
#  {'team_id': '103240746417732213',
#   'name': 'Team Urf D',
#   'acronym': 'UFD',
#   'slug': 'team-urf-d'},
#  {'team_id': '109671193729027761',
#   'name': 'FLY FAM',
#   'acronym': 'FLYF',
#   'slug': 'fly-fam'},
#  {'team_id': '108159917648031455',
#   'name': 'UST Esports',
#   'acronym': 'USTE',
#   'slug': 'ust-esports'},
#  {'team_id': '106827815539026710',
#   'name': 'RJ Academy',
#   'acronym': 'RJ',
#   'slug': 'rj-academy'},
#  {'team_id': '109539873500788632',
#   'name': 'EXEED',
#   'acronym': 'EXD',
#   'slug': 'exeed'},
#  {'team_id': '107597858964689090',
#   'name': 'SOVEJA',
#   'acronym': 'SVJ',
#   'slug': 'soveja'},
#  {'team_id': '101978171843206569',
#   'name': 'Vega Squadron',
#   'acronym': 'VEG',
#   'slug': 'vega-squadron'},
#  {'team_id': '99566408220213759',
#   'name': 'CNB e-Sports Club',
#   'acronym': 'CNB',
#   'slug': 'cnb-e-sports-club'},
#  {'team_id': '99566404585387054',
#   'name': 'DRX',
#   'acronym': 'DRX',
#   'slug': 'drx'},
#  {'team_id': '107582641798795198',
#   'name': 'Spectacled Bears',
#   'acronym': 'SB',
#   'slug': 'spectacled-bears'},
#  {'team_id': '106827832203113865',
#   'name': 'SHG Academy',
#   'acronym': 'SHG',
#   'slug': 'shg-academy'},
#  {'team_id': '98926509884398584',
#   'name': 'CLG',
#   'acronym': 'CLG',
#   'slug': 'clg'},
#  {'team_id': '107598651997213225',
#   'name': '9z Gaming',
#   'acronym': '9Z',
#   'slug': '9z-gaming'},
#  {'team_id': '99566406069969565',
#   'name': 'Info YatÄ±rÄ±m Aurora',
#   'acronym': 'AUR',
#   'slug': 'info-yatrm-aurora'},
#  {'team_id': '99566406070802758',
#   'name': 'Royal Youth',
#   'acronym': 'RYL',
#   'slug': 'royal-bandits-e-sports'},
#  {'team_id': '102235771678061291',
#   'name': 'DenizBank Ä°stanbul Wildcats',
#   'acronym': 'IW',
#   'slug': 'fastpay-wildcats'},
#  {'team_id': '107251231972989211',
#   'name': 'SBTC ESPORTS',
#   'acronym': 'SE',
#   'slug': 'sbtc-esports'},
#  {'team_id': '98767991921462763',
#   'name': 'Dire Wolves',
#   'acronym': 'DW',
#   'slug': 'dire-wolves'},
#  {'team_id': '105536773074826367',
#   'name': 'GGEsports',
#   'acronym': 'GGE',
#   'slug': 'ggesports'},
#  {'team_id': '108566004579728490',
#   'name': 'LARGE',
#   'acronym': 'LRG',
#   'slug': 'large'},
#  {'team_id': '102141671182557163',
#   'name': 'Redbird Esports',
#   'acronym': 'UI',
#   'slug': 'redbird-esports'},
#  {'team_id': '101157821427356777',
#   'name': 'Seiya',
#   'acronym': 'LLA2',
#   'slug': 'seiya'},
#  {'team_id': '109695910533747910',
#   'name': 'RAAD',
#   'acronym': 'RAAD',
#   'slug': 'raad'},
#  {'team_id': '109675490370327425',
#   'name': 'Ground Zero',
#   'acronym': 'GZ',
#   'slug': 'ground-zero'},
#  {'team_id': '104710359142494900',
#   'name': 'Samsung Morning Stars',
#   'acronym': 'SMS',
#   'slug': 'samsung-morning-stars'},
#  {'team_id': '104367072827489994',
#   'name': 'Berjaya Dragons',
#   'acronym': 'BJD',
#   'slug': 'berjaya-dragons'},
#  {'team_id': '99566406495581481',
#   'name': 'G-Rex',
#   'acronym': 'GRX',
#   'slug': 'g-rex'},
#  {'team_id': '102787200143309800',
#   'name': 'eNsure',
#   'acronym': 'EN',
#   'slug': 'ensure'},
#  {'team_id': '98767991902391669',
#   'name': 'Flash Wolves',
#   'acronym': 'FWS',
#   'slug': 'flash-wolves'},
#  {'team_id': '110733877357854829',
#   'name': 'Gentle Hearts Gaming',
#   'acronym': 'GHG',
#   'slug': 'gentle-hearts-gaming'},
#  {'team_id': '105550051809743868',
#   'name': 'Liiv SANDBOX Youth',
#   'acronym': 'LSB',
#   'slug': 'lsb-challengers'},
#  {'team_id': '103240746419960441',
#   'name': 'Team Assassin B',
#   'acronym': 'TAB',
#   'slug': 'team-assassin-b'},
#  {'team_id': '102141671185047537',
#   'name': 'UCI Esports',
#   'acronym': 'UCI',
#   'slug': 'uci-esports'},
#  {'team_id': '98767991935149427',
#   'name': 'Movistar R7',
#   'acronym': 'R7',
#   'slug': 'rainbow7'},
#  {'team_id': '109697689430777005',
#   'name': 'Ankora Gaming',
#   'acronym': 'ANK',
#   'slug': 'ankora-gaming'},
#  {'team_id': '102787200120306562',
#   'name': 'Mousesports',
#   'acronym': 'MOUZ',
#   'slug': 'mousesports'},
#  {'team_id': '109783170393931575',
#   'name': 'Conviction',
#   'acronym': 'CNV',
#   'slug': 'conviction'},
#  {'team_id': '106269818143576465',
#   'name': 'BOOM Esports',
#   'acronym': 'BME',
#   'slug': 'boom-esports'},
#  {'team_id': '104367099322647716',
#   'name': 'Liyab Esports',
#   'acronym': 'LYB',
#   'slug': 'liyab-esports'},
#  {'team_id': '103877951616192529',
#   'name': 'Cyber Gaming',
#   'acronym': 'CG',
#   'slug': 'cyber-gaming'},
#  {'team_id': '101157821430895725',
#   'name': 'Evi',
#   'acronym': 'JP1',
#   'slug': 'evi'},
#  {'team_id': '104234144258996303',
#   'name': 'POLSKA GUROM',
#   'acronym': 'POL',
#   'slug': 'polska-gurom'},
#  {'team_id': '109800832177252614',
#   'name': 'Orbit Anonymo',
#   'acronym': 'OAE',
#   'slug': 'szaty-bobra'},
#  {'team_id': '107635420167535818',
#   'name': 'SEM9',
#   'acronym': 'S9',
#   'slug': 'sem9'},
#  {'team_id': '107582184905264520',
#   'name': 'Waia Snikt',
#   'acronym': 'WS',
#   'slug': 'waia-snikt'},
#  {'team_id': '110534751905120040',
#   'name': 'Young Buffalos',
#   'acronym': 'YB',
#   'slug': 'young-buffalos'},
#  {'team_id': '107456355516438414',
#   'name': 'Eintracht Frankfurt',
#   'acronym': 'SGE',
#   'slug': 'eintracht-frankfurt'},
#  {'team_id': '104710678170825211',
#   'name': 'SINNERS Esports',
#   'acronym': 'SIN',
#   'slug': 'sinners-esports'},
#  {'team_id': '108361545122797332',
#   'name': 'AOE Ginger Turmeric',
#   'acronym': 'AGT',
#   'slug': 'aoe-ginger-turmeric'},
#  {'team_id': '107599156601411192',
#   'name': 'Movistar Optix',
#   'acronym': 'MOX',
#   'slug': 'movistar-optix'},
#  {'team_id': '98767991897792379',
#   'name': 'Hong Kong Attitude',
#   'acronym': 'HKA',
#   'slug': 'hong-kong-attitude'},
#  {'team_id': '105503778424809514',
#   'name': 'EURONICS Gaming',
#   'acronym': 'ESG',
#   'slug': 'euronics-gaming'},
#  {'team_id': '107251307514079872',
#   'name': 'LXE ESPORTS',
#   'acronym': 'LX',
#   'slug': 'lxe-esports'},
#  {'team_id': '103240746429004425',
#   'name': 'Jankos',
#   'acronym': 'EU2',
#   'slug': 'jankos'},
#  {'team_id': '101978171845303729',
#   'name': 'MEGA Esports',
#   'acronym': 'MG',
#   'slug': 'mega-esports'},
#  {'team_id': '108131965235538611',
#   'name': 'Antares Esports',
#   'acronym': 'ANT',
#   'slug': 'antares-esports'},
#  {'team_id': '99322214684939974',
#   'name': 'Unicorns of Love',
#   'acronym': 'UOL',
#   'slug': 'unicorns-of-love'},
#  {'team_id': '103535282158162659',
#   'name': 'DenizBank Ä°stanbul Wildcats Akademi',
#   'acronym': 'IW',
#   'slug': 'fastpay-wildcats-akademi'},
#  {'team_id': '105521504308341229',
#   'name': 'Team Refuse',
#   'acronym': 'RFS',
#   'slug': 'team-refuse'},
#  {'team_id': '103535282148790975',
#   'name': 'GALAKTICOS Akademi',
#   'acronym': 'GAL',
#   'slug': 'galakticos-akademi'},
#  {'team_id': '105549993449477104',
#   'name': 'INTZ Academy',
#   'acronym': 'ITZ',
#   'slug': 'intz-academy'},
#  {'team_id': '107598712583969458',
#   'name': 'EBRO',
#   'acronym': 'EBG',
#   'slug': 'ebro-gaming'},
#  {'team_id': '105521402545275594',
#   'name': "Gentlemen's Gaming",
#   'acronym': 'GGM',
#   'slug': 'gentlemens-gaming'},
#  {'team_id': '107258254469504696',
#   'name': 'Team Flash',
#   'acronym': 'TF',
#   'slug': 'team-flash'},
#  {'team_id': '103535282113853330',
#   'name': '5 Ronin Akademi',
#   'acronym': '5R',
#   'slug': '5-ronin-akademi'},
#  {'team_id': '105520819263036609',
#   'name': 'The Agency',
#   'acronym': 'AGC',
#   'slug': 'echo-zulu'},
#  {'team_id': '99566408562477641',
#   'name': 'INFINITY',
#   'acronym': 'INF',
#   'slug': 'infinity'},
#  {'team_id': '108361570687544399',
#   'name': "Jake's Kittens",
#   'acronym': 'JK',
#   'slug': 'jakes-kittens'},
#  {'team_id': '109669678317817381',
#   'name': 'FUT ESPORTS',
#   'acronym': 'FUT',
#   'slug': 'fut-team'},
#  {'team_id': '99566404578577099',
#   'name': 'Jin Air Green Wings',
#   'acronym': 'JAG',
#   'slug': 'jin-air-green-wings'},
#  {'team_id': '107456284318482723',
#   'name': 'Mirage-Elyandra',
#   'acronym': 'ME',
#   'slug': 'mirage-elyandra'},
#  {'team_id': '107582615829368757',
#   'name': 'Fantasy Gaming',
#   'acronym': 'FSY',
#   'slug': 'fantasy-gaming'},
#  {'team_id': '103743162394217975',
#   'name': 'Santos HotForex',
#   'acronym': 'SAN',
#   'slug': 'santos-hotforex'},
#  {'team_id': '99566405123587075',
#   'name': 'CLG Challengers',
#   'acronym': 'CLG',
#   'slug': 'clg-academy'},
#  {'team_id': '107603600826620492',
#   'name': 'Zeus Kralik',
#   'acronym': 'Z5K',
#   'slug': 'zeu5-bogota'},
#  {'team_id': '103935530333072898',
#   'name': 'AGO Rogue',
#   'acronym': 'RGO',
#   'slug': 'ago-rogue'},
#  {'team_id': '102787200141016030',
#   'name': 'Rogue Esports Club',
#   'acronym': 'REC1',
#   'slug': 'rogue-esports-club'},
#  {'team_id': '99124844356912967',
#   'name': 'LPL All-Stars',
#   'acronym': 'LPL',
#   'slug': 'lpl-allstars'},
#  {'team_id': '105351724613755142',
#   'name': 'LPL Queue Kings',
#   'acronym': 'LPLQ',
#   'slug': 'lpl-queue-kings'},
#  {'team_id': '99566408356697119',
#   'name': 'Furious Gaming',
#   'acronym': 'FG',
#   'slug': 'furious-gaming'},
#  {'team_id': '99871276356460471',
#   'name': 'Griffin',
#   'acronym': 'GFF',
#   'slug': 'griffin'},
#  {'team_id': '105357803054359120',
#   'name': 'Bwipo Dream Team',
#   'acronym': 'BWI',
#   'slug': 'bwipo-dream-team'},
#  {'team_id': '105594163014588871',
#   'name': 'Boavista F.C',
#   'acronym': 'BFC',
#   'slug': 'boavista-fc'},
#  {'team_id': '107581296208168309',
#   'name': 'Tomorrow Esports',
#   'acronym': 'TMR',
#   'slug': 'tomorrow-esports'},
#  {'team_id': '108361565719424734',
#   'name': 'DK Crew',
#   'acronym': 'DKC',
#   'slug': 'dk-crew'},
#  {'team_id': '105521293297166647',
#   'name': 'Hell Zerolag Esports',
#   'acronym': 'HELL',
#   'slug': 'zerolag-esports'},
#  {'team_id': '101383793572656373',
#   'name': 'EXCEL',
#   'acronym': 'XL',
#   'slug': 'excel'},
#  {'team_id': '109698757443650056',
#   'name': 'Mad Kings',
#   'acronym': 'MKE',
#   'slug': 'mad-kings'},
#  {'team_id': '98767991846127102',
#   'name': 'ahq eSports Club',
#   'acronym': 'AHQ',
#   'slug': 'ahq-esports-club'},
#  {'team_id': '105301877841257613',
#   'name': 'VCS All Stars',
#   'acronym': 'VCS',
#   'slug': 'vcs-all-stars'},
#  {'team_id': '108361578564310810',
#   'name': 'Team Pending',
#   'acronym': 'TBA',
#   'slug': 'team-pending'},
#  {'team_id': '105594101461473671',
#   'name': 'Karma Clan Esports',
#   'acronym': 'KRM',
#   'slug': 'karma-clan-esports'},
#  {'team_id': '105550033967461806',
#   'name': 'DRX Challengers',
#   'acronym': 'DRX',
#   'slug': 'drx-challengers'},
#  {'team_id': '99294153824386385',
#   'name': 'Golden Guardians',
#   'acronym': 'GG',
#   'slug': 'golden-guardians'},
#  {'team_id': '105593278887024877',
#   'name': 'Inaequalis',
#   'acronym': 'INAE',
#   'slug': 'inaequalis'},
#  {'team_id': '105559480124455983',
#   'name': 'SK Gaming Prime',
#   'acronym': 'SKP',
#   'slug': 'sk-gaming-prime'},
#  {'team_id': '103240746425727619',
#   'name': 'Levi',
#   'acronym': 'VCS2',
#   'slug': 'levi'}]
